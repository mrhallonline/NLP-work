# %% [markdown]
# <a href="https://colab.research.google.com/github/mrhallonline/NLP-work/blob/main/Sustained_Uncertainty_Natural_Language_Toolkit_(NLTK)_Workshop_V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **General Overview**

# %% [markdown]
# # 1. Connect your Google doc files to be used in Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Installing NLTK dependencies and libraries
#
# 1. NLTK
# 2.   [Matplotlib](https://matplotlib.org/) library: Library for creating data visualizations.
# 3.   [Beautiful Soup](https://pypi.org/project/beautifulsoup4/) library: Pulls information from HTML and XML files.
# 4.   [Gensim](https://pypi.org/project/gensim/) library: Natural language processing tool
# 5.   [PyPDF2](https://pypdf2.readthedocs.io/en/3.0.0/index.html#) library: NLTK normally works with text files, PyPDF2 will allow you to read, write, convert to text, and merge pdf files
# 6. Numpy
# 7. SciPy
# 8. Pandas
# 9. Scikit
# 10. Autocorrect

# %%
# !pip install nltk
# !pip install matplotlib
# !pip install beautifulsoup4
# !pip install gensim
# !pip install PyPDF2
# !pip install numpy
# !pip install scipy
# !pip install pandas
# !pip install scikit-learn
# !pip install autocorrect
import nltk
nltk.download('popular')

# %% [markdown]
# # 3. Import text corpus to your Google Drive current folder.
# This is needed to occur in order to use the same data. The cell will download the text file and save it in your Google Drive so it can be accessed by this Colab document. You can use this same code to download any file that you have sharing access with, just change the file_id with the new one.

# %%
import requests

# This is the full shared Drive link, the file id starts at 1-6A...
#https://drive.google.com/file/d/1-6AkzKuyfY9Oj__MWQFCP_Yo-TSzMS0F/view?usp=drive_link

# get the file ID from the shareable link and paste below
file_id = "1-6AkzKuyfY9Oj__MWQFCP_Yo-TSzMS0F"

# construct the download URL
download_url = f"https://docs.google.com/uc?export=download&id={file_id}"

# send a GET request to the download URL and save the response content
response = requests.get(download_url)

# The next line names the file after download. If you change it here, you will also need to change in the subsequent fields.
with open("OPSEMERGED.txt", "wb") as f:
    f.write(response.content)

# %% [markdown]
# # Working with csv Files

# %%
# !pip install pandas openpyxl nltk

import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')

# Specify the path to the Excel file
excel_file_path = '/content/drive/MyDrive/educativeData/PAGEScoded_segments_level2.xlsx'

# Specify the column name you want to tokenize
column_name = 'Segment'

# Read the Excel file and extract the specified column
data = pd.read_excel(excel_file_path, engine='openpyxl')
text_column = data[column_name]


tokenized_csv = []

for text in text_column:
    tokens = word_tokenize(text)
    tokenized_csv.append(tokens)
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
tokenized_csv
# Out:
# [['-', 'estimated', 'time', ':', '15', 'minutes'],
#  ['.',
#   'The',
#   'purpose',
#   'of',
#   'this',
#   'is',
#   'to',
#   'develop',
#   'a',
#   'shared',
#   'understanding',
#   'of',
#   'each',
#   'norm'],
#  ['.',
#   'This',
#   'is',
#   'an',
#   'excellent',
#   'out',
#   'of',
#   'class',
#   'home-learning',
#   'assignment',
#   'to',
#   'have',
#   'students',
#   'complete',
#   'before',
#   'the',
#   'start',
#   'of',
#   'the',
#   'next',
#   'class'],
#  ['[', '2', 'min', ']'],
#  ['[', '2', 'min', ']'],
#  ['[', '3', 'min', ']'],
#  ['[', '3', 'min', ']'],
#  ['[', '5', 'min', ']'],
#  ['[', '6', 'min', ']'],
#  ['[', '10', 'min', ']'],
#  ['[', '10', 'min', ']'],
#  ['[',
#   '15',
#   'min',
#   '+',
#   '5',
#   'min',
#   'if',
#   'first',
#   'time',
#   'talking',
#   'through',
#   'norms',
#   ']',
#   'It',
#   'is',
#   'important',
#   'to',
#   'have',
#   'chart',
#   'paper',
#   'with',
#   'an',
#   'enlarged',
#   'version',
#   'of',
#   'the',
#   'template',
#   'students',
#   'have',
#   'just',
#   'filled',
#   'in',
#   'to',
#   'use',
#   'to',
#   'develop',
#   'an',
#   'initial',
#   'class',
#   'consensus',
#   'model',
#   '.',
#   'This',
#   'model',
#   'will',
#   'be',
#   'used',
#   'as',
#   'the',
#   'driving',
#   'question',
#   'board',
#   '(',
#   'DQB',
#   ')',
#   'later',
#   'in',
#   'this',
#   'lesson',
#   '(',
#   'Samples',
#   'can',
#   'be',
#   'seen',
#   'in',
#   'later',
#   'steps',
#   'in',
#   'this',
#   'teacher',
#   'guide',
#   '.',
#   ')'],
#  ['[', '15', 'min', ']'],
#  ['[', '15', 'min', ']'],
#  ['[',
#   '15',
#   'min',
#   ']',
#   'Prepare',
#   'students',
#   'to',
#   'develop',
#   'their',
#   'initial',
#   'model',
#   'for',
#   'what',
#   'they',
#   'think',
#   'is',
#   'different',
#   'about',
#   'an',
#   'egg',
#   'that',
#   'hatches',
#   'into',
#   'a',
#   'chicken',
#   'and',
#   'an',
#   'egg',
#   'that',
#   'doesn',
#   '’',
#   't',
#   'ever',
#   'hatch',
#   '.'],
#  ['[', '40', 'min', ']'],
#  ['●', 'Group', 'size', ':', 'Whole', 'class'],
#  ['●',
#   'Heat',
#   'can',
#   'enter',
#   'the',
#   'cup',
#   'system',
#   'and/or',
#   'cold',
#   'can',
#   'leave',
#   'the',
#   'cup',
#   'system',
#   ',',
#   'and',
#   'maybe',
#   'gases',
#   'can',
#   'escape',
#   'the',
#   'system',
#   'too',
#   '.'],
#  ['✱', 'ATTENDING', 'TO', 'EQUITY'],
#  ['✱',
#   'ATTENDING',
#   'TO',
#   'EQUITY',
#   'A',
#   'DQB',
#   'provides',
#   'a',
#   'public',
#   'representation',
#   'of',
#   'the',
#   'class',
#   '’',
#   's',
#   'joint',
#   'mission',
#   '.',
#   'Students',
#   'can',
#   'share',
#   'their',
#   'questions',
#   'and',
#   'wonderings',
#   'with',
#   'one',
#   'another',
#   ',',
#   'and',
#   'the',
#   'visual',
#   'representation',
#   'offers',
#   'another',
#   'modality',
#   'for',
#   'students',
#   'to',
#   'access',
#   'science',
#   'in',
#   'the',
#   'classroom',
#   '.',
#   'The',
#   'DQB',
#   'should',
#   'be',
#   'centrally',
#   'located',
#   'in',
#   'the',
#   'classroom',
#   'so',
#   'that',
#   'it',
#   'can',
#   'be',
#   'referenced',
#   'and',
#   'added',
#   'to',
#   'throughout',
#   'the',
#   'unit',
#   '.'],
#  ['✱',
#   'ATTENDING',
#   'TO',
#   'EQUITY',
#   'A',
#   'key',
#   'element',
#   'of',
#   'the',
#   'Anchoring',
#   'Phenomenon',
#   'routine',
#   'is',
#   'letting',
#   'students',
#   'share',
#   'their',
#   'experiences',
#   'with',
#   'related',
#   'phenomena',
#   '.',
#   'By',
#   'doing',
#   'this',
#   ',',
#   'students',
#   'can',
#   'connect',
#   'their',
#   'diverse',
#   'experiences',
#   'with',
#   'a',
#   'shared',
#   'phenomenon',
#   'that',
#   'is',
#   'the',
#   'focus',
#   'of',
#   'the',
#   'unit',
#   '.'],
#  ['✱',
#   'ATTENDING',
#   'TO',
#   'EQUITY',
#   'First',
#   'and',
#   'foremost',
#   'during',
#   'the',
#   'formation',
#   'of',
#   'the',
#   'DQB',
#   'is',
#   'reinforcing',
#   'a',
#   'classroom',
#   'community',
#   'wherein',
#   'all',
#   'ideas',
#   'are',
#   'valued',
#   'and',
#   'everyone',
#   'has',
#   'a',
#   'question',
#   'up',
#   'on',
#   'the',
#   'board',
#   '.',
#   'Use',
#   'your',
#   'judgement',
#   'on',
#   'how',
#   'to',
#   'press',
#   'students',
#   'to',
#   'form',
#   '“',
#   'how',
#   '”',
#   'and',
#   '“',
#   'why',
#   '”',
#   'questions',
#   '.',
#   'If',
#   'a',
#   'student',
#   'struggles',
#   'with',
#   'sharing',
#   ',',
#   'encourage',
#   'them',
#   'to',
#   'go',
#   'public',
#   'with',
#   'questions',
#   'rather',
#   'than',
#   'focusing',
#   'specifically',
#   'on',
#   'forming',
#   'a',
#   '“',
#   'how',
#   '”',
#   'or',
#   '“',
#   'why',
#   '”',
#   'question',
#   '.'],
#  ['✱',
#   'ATTENDING',
#   'TO',
#   'EQUITY',
#   'Students',
#   'will',
#   'find',
#   'the',
#   'anchoring',
#   'phenomenon',
#   'more',
#   'compelling',
#   'if',
#   'it',
#   'is',
#   'presented',
#   'in',
#   'a',
#   'meaningful',
#   'context',
#   '.',
#   'Additionally',
#   ',',
#   'throughout',
#   'Lessons',
#   '2-5',
#   ',',
#   'there',
#   'are',
#   'opportunities',
#   'to',
#   'weave',
#   'your',
#   'community',
#   '’',
#   's',
#   'story',
#   'into',
#   'the',
#   'overall',
#   'storyline',
#   '.',
#   'Therefore',
#   ',',
#   'adding',
#   'a',
#   'local',
#   'story',
#   'or',
#   'local',
#   'connection',
#   'now',
#   'will',
#   'serve',
#   'to',
#   'increase',
#   'relevance',
#   'and',
#   'interest',
#   'for',
#   'your',
#   'students',
#   'and',
#   'will',
#   'engage',
#   'them',
#   'in',
#   'a',
#   'deeper',
#   'study',
#   'of',
#   'their',
#   'community',
#   'across',
#   'the',
#   'first',
#   'lesson',
#   'set',
#   '.'],
#  ['✱',
#   'ATTENDING',
#   'TO',
#   'EQUITY',
#   'Supporting',
#   'Emergent',
#   'Multilingual',
#   'Students',
#   ':',
#   'Asking',
#   'questions',
#   'in',
#   'everyday',
#   'language',
#   'allows',
#   'students',
#   'to',
#   'share',
#   'their',
#   'thinking',
#   'or',
#   'experiences',
#   ',',
#   'even',
#   'if',
#   'they',
#   'do',
#   'not',
#   'have',
#   'the',
#   'appropriate',
#   'scientific',
#   'vocabulary',
#   'yet',
#   '.',
#   'This',
#   'is',
#   'helpful',
#   'for',
#   'emergent',
#   'multilingual',
#   'students',
#   'because',
#   'by',
#   'not',
#   'requiring',
#   'scientific',
#   'words',
#   'at',
#   'the',
#   'onset',
#   ',',
#   'you',
#   'do',
#   'not',
#   'limit',
#   'their',
#   'participation',
#   'in',
#   'classroom',
#   'discourse',
#   '.'],
#  ['✱',
#   'ATTENDING',
#   'TO',
#   'EQUITY',
#   'Supporting',
#   'Emerging',
#   'Multilingual',
#   'Students',
#   ':',
#   'When',
#   'developing',
#   'new',
#   'vocabulary',
#   ',',
#   'strategies',
#   'that',
#   'may',
#   'benefit',
#   'emergent',
#   'multilingual',
#   'learners',
#   'include',
#   'using',
#   'student-friendly',
#   'definitions',
#   ',',
#   'making',
#   'connections',
#   'to',
#   'cognate',
#   'words',
#   'when',
#   'possible',
#   ',',
#   'and',
#   'showing',
#   'a',
#   'visual',
#   'representation',
#   'of',
#   'the',
#   'word',
#   '.',
#   'These',
#   'strategies',
#   'apply',
#   'to',
#   'both',
#   '“',
#   'words',
#   'we',
#   'earn',
#   '”',
#   'and',
#   '“',
#   'words',
#   'we',
#   'encounter',
#   '.',
#   '”'],
#  ['✱',
#   'ATTENDING',
#   'TO',
#   'EQUITY',
#   'This',
#   'is',
#   'an',
#   'important',
#   'opportunity',
#   'to',
#   'emphasize',
#   'that',
#   'each',
#   'individual',
#   'has',
#   'contributions',
#   'to',
#   'make',
#   'to',
#   'their',
#   'community',
#   'of',
#   'learners',
#   '.',
#   'It',
#   'is',
#   'through',
#   'differences',
#   'in',
#   'thinking',
#   'that',
#   'the',
#   'class',
#   'will',
#   'grow',
#   'their',
#   'knowledge'],
#  ['✱',
#   'ATTENDING',
#   'TO',
#   'EQUITY',
#   'Universal',
#   'Design',
#   'for',
#   'Learning',
#   ':',
#   'This',
#   'home',
#   'learning',
#   'is',
#   'used',
#   'to',
#   'broaden',
#   'students',
#   '’',
#   'thinking',
#   'to',
#   'related',
#   'phenomena',
#   'and',
#   'leverage',
#   'these',
#   'everyday',
#   'science',
#   'experiences',
#   'they',
#   'have',
#   'outside',
#   'of',
#   'school',
#   'to',
#   'augment',
#   'the',
#   'learning',
#   'that',
#   'happens',
#   'in',
#   'the',
#   'classroom',
#   '.',
#   'Locating',
#   'the',
#   'anchoring',
#   'phenomena',
#   'in',
#   'the',
#   'context',
#   'of',
#   'their',
#   'community',
#   'helps',
#   'the',
#   'phenomenon',
#   'become',
#   'more',
#   'personally'],
#  ['✱',
#   'ATTENDING',
#   'TO',
#   'EQUITY',
#   'Universal',
#   'Design',
#   'for',
#   'Learning',
#   ':',
#   'To',
#   'promote',
#   'student',
#   'engagement',
#   'you',
#   'may',
#   'choose',
#   'to',
#   'differentiate',
#   'the',
#   'degree',
#   'of',
#   'difficulty',
#   'or',
#   'complexity',
#   'of',
#   'the',
#   'task',
#   'by',
#   'giving',
#   'some',
#   'groups',
#   'both',
#   'sets',
#   'of',
#   'headlines',
#   '.',
#   'Learners',
#   'vary',
#   'not',
#   'only',
#   'in',
#   'their',
#   'skills',
#   'and',
#   'abilities',
#   ',',
#   'but',
#   'also',
#   'in',
#   'the',
#   'kinds',
#   'of',
#   'challenges',
#   'that',
#   'motivate',
#   'them',
#   'to',
#   'do',
#   'their',
#   'best',
#   'work',
#   '.'],
#  ['✱',
#   'ATTENDING',
#   'TO',
#   'EQUITY',
#   'Universal',
#   'Design',
#   'for',
#   'Learning',
#   ':',
#   'You',
#   'may',
#   'use',
#   'color',
#   'coding',
#   'to',
#   'foreground',
#   'parts',
#   'of',
#   'the',
#   'model',
#   '.',
#   'Although',
#   'color',
#   'coding',
#   'is',
#   'a',
#   'useful',
#   'way',
#   'to',
#   'quickly',
#   'reference',
#   'the',
#   'parts',
#   'of',
#   'the',
#   'model',
#   ',',
#   'letter',
#   'or',
#   'number',
#   'coding',
#   'helps',
#   'ensure',
#   'accessibility',
#   'for',
#   'any',
#   'student',
#   'who',
#   'may',
#   'be',
#   'color-blind',
#   '.',
#   'Create',
#   'a',
#   'key',
#   'to',
#   'track',
#   'what',
#   'colors',
#   ',',
#   'symbols',
#   ',',
#   'numbers',
#   ',',
#   'or',
#   'letters',
#   'represent',
#   'different',
#   'parts',
#   'of',
#   'the',
#   'system',
#   '.',
#   'Keep',
#   'this',
#   'in',
#   'mind',
#   'as',
#   'students',
#   'begin',
#   'to',
#   'develop',
#   'their',
#   'Earth',
#   '’',
#   's',
#   'Water',
#   'System',
#   'Model',
#   'in',
#   'L2',
#   'and',
#   'later',
#   'when',
#   'students',
#   'develop',
#   'their',
#   'Carbon',
#   'System',
#   'Model',
#   'in',
#   'lesson',
#   'set',
#   '2',
#   '.'],
#  ['✱',
#   'SUPPORTING',
#   'STUDENTS',
#   'IN',
#   'ENGAGING',
#   'IN',
#   'ARGUMENT',
#   'FROM',
#   'EVIDENCE',
#   'As',
#   'students',
#   'engage',
#   'in',
#   'this',
#   'discussion',
#   ',',
#   'focus',
#   'them',
#   'on',
#   'how',
#   'their',
#   'evidence',
#   'can',
#   'be',
#   'useful',
#   'for',
#   'evaluating',
#   'claims',
#   'and',
#   'persuading',
#   'others',
#   'about',
#   'the',
#   'validity',
#   'of',
#   'their',
#   'ideas',
#   '.',
#   'When',
#   'students',
#   'are',
#   'engaged',
#   'in',
#   'the',
#   'work',
#   'of',
#   'argumentation',
#   'and',
#   'explanation',
#   ',',
#   'they',
#   'should',
#   'explicitly',
#   'build',
#   'from',
#   'evidence',
#   ',',
#   'past',
#   'experiences',
#   ',',
#   'and/or',
#   'shared',
#   'observations',
#   'to',
#   'support',
#   'their',
#   'conclusions',
#   '.'],
#  ['✱',
#   'SUPPORTING',
#   'STUDENTS',
#   'IN',
#   'ENGAGING',
#   'IN',
#   'DEVELOPING',
#   'AND',
#   'USING',
#   'MODELS'],
#  ['✱',
#   'SUPPORTING',
#   'STUDENTS',
#   'IN',
#   'THREE-DIMENSIONAL',
#   'LEARNING',
#   'Students',
#   'will',
#   'engage',
#   'in',
#   'modeling',
#   'to',
#   'explain',
#   'what',
#   'caused',
#   'the',
#   'temperature',
#   'to',
#   'change',
#   'inside',
#   'the',
#   'cups',
#   '.',
#   'The',
#   'students',
#   'will',
#   'be',
#   'identifying',
#   'causes',
#   'that',
#   'are',
#   'unobservable',
#   'mechanisms',
#   'or',
#   'processes',
#   'happening',
#   'within',
#   'the',
#   'system',
#   '.',
#   'As',
#   'students',
#   'develop',
#   'these',
#   'models',
#   ',',
#   'make',
#   'certain',
#   'they',
#   'represent',
#   'the',
#   'full',
#   'system',
#   ',',
#   'including',
#   '(',
#   '1',
#   ')',
#   'structural',
#   'parts',
#   'of',
#   'the',
#   'cup',
#   '(',
#   'also',
#   'called',
#   'cup',
#   'features',
#   ')',
#   'and',
#   '(',
#   '2',
#   ')',
#   'what',
#   'is',
#   'inside',
#   'the',
#   'cup',
#   '(',
#   'include',
#   'the',
#   'water',
#   ',',
#   'ice',
#   ',',
#   'and',
#   'air',
#   ')',
#   '.',
#   'They',
#   'may',
#   'want',
#   'to',
#   'include',
#   'what',
#   'is',
#   'outside',
#   'the',
#   'cup',
#   ',',
#   'though',
#   'the',
#   'air',
#   'outside',
#   'is',
#   'a',
#   'separate',
#   'system',
#   'that',
#   'interacts',
#   'with',
#   'the',
#   'cup',
#   'system',
#   '.',
#   'Leverage',
#   'the',
#   'systems',
#   'models',
#   'students',
#   'develop',
#   'as',
#   'they',
#   'begin',
#   'to',
#   'investigate',
#   'and',
#   'manipulate',
#   'parts',
#   'of',
#   'the',
#   'system',
#   'to',
#   'figure',
#   'out',
#   'what',
#   'causes',
#   'the',
#   'change',
#   'in',
#   'temperature',
#   'of',
#   'the',
#   'liquid',
#   'inside',
#   '.'],
#  ['✱',
#   'SUPPORTING',
#   'STUDENTS',
#   'IN',
#   'THREE-DIMENSIONAL',
#   'LEARNING',
#   'Students',
#   'are',
#   'asking',
#   'questions',
#   'about',
#   'phenomena',
#   'that',
#   'will',
#   'lead',
#   'to',
#   'investigations',
#   ',',
#   'specifically',
#   'on',
#   'how',
#   'the',
#   'temperature',
#   'change',
#   'inside',
#   'a',
#   'system',
#   'happens',
#   'more',
#   'quickly',
#   'or',
#   'slowly',
#   'based',
#   'on',
#   'structural',
#   'features',
#   'of',
#   'the',
#   'system',
#   '.',
#   'Use',
#   'these',
#   'crosscutting',
#   'concepts',
#   'lenses',
#   'to',
#   'help',
#   'students',
#   'generate',
#   'questions',
#   'if',
#   'they',
#   'get',
#   'stuck',
#   ':',
#   '(',
#   '1',
#   ')',
#   'the',
#   'different',
#   'identified',
#   'structural',
#   'components',
#   'and',
#   'how',
#   'those',
#   'parts',
#   'work',
#   'to',
#   'maintain',
#   'the',
#   'temperature',
#   'of',
#   'the',
#   'substance',
#   'inside',
#   '(',
#   'Structure',
#   'and',
#   'Function',
#   ')',
#   ',',
#   '(',
#   '2',
#   ')',
#   'the',
#   'different',
#   'parts',
#   'of',
#   'the',
#   'system',
#   'and',
#   'whether',
#   'anything',
#   'is',
#   'moving',
#   'into',
#   'or',
#   'out',
#   'of',
#   'the',
#   'system',
#   '(',
#   'Systems',
#   ')',
#   ',',
#   'and',
#   '(',
#   '3',
#   ')',
#   'patterns',
#   'they',
#   'identified',
#   'across',
#   'related',
#   'phenomena',
#   'that'],
#  ['✱',
#   'SUPPORTING',
#   'STUDENTS',
#   'IN',
#   'DEVELOPING',
#   'AND',
#   'USING',
#   'SYSTEMS',
#   'AND',
#   'SYSTEM',
#   'MODELS',
#   'Throughout',
#   'the',
#   'unit',
#   ',',
#   'the',
#   'focal',
#   'crosscutting',
#   'concept',
#   'of',
#   'Systems',
#   'and',
#   'System',
#   'Models',
#   'will',
#   'be',
#   'used',
#   'to',
#   'help',
#   'students',
#   'generate',
#   'questions',
#   'about',
#   'phenomena',
#   'and',
#   'to',
#   'guide',
#   'them',
#   'in'],
#  ['✱',
#   'SUPPORTING',
#   'STUDENTS',
#   'IN',
#   'ENGAGING',
#   'IN',
#   'PLANNING',
#   'AND',
#   'CARRYING',
#   'OUT',
#   'INVESTIGATIONS'],
#  ['✱',
#   'SUPPORTING',
#   'STUDENTS',
#   'IN',
#   'ENGAGING',
#   'IN',
#   'PLANNING',
#   'AND',
#   'CARRYING',
#   'OUT',
#   'INVESTIGATIONS',
#   'This',
#   'initial',
#   'investigation',
#   'should',
#   'have',
#   'some',
#   'controls',
#   'in',
#   'place',
#   ',',
#   'but',
#   'it',
#   'should',
#   'also',
#   'reflect',
#   'the',
#   'real-life',
#   'anchor',
#   'scenario',
#   '.',
#   'Students',
#   'will',
#   'get',
#   'to',
#   'set',
#   'up',
#   'more',
#   'systematic',
#   'investigations',
#   'where',
#   'they',
#   'identify',
#   'independent',
#   ',',
#   'dependent',
#   ',',
#   'and',
#   'control',
#   'variables',
#   'over',
#   'the',
#   'course',
#   'of',
#   'the',
#   'unit',
#   '.',
#   'However',
#   ',',
#   'they',
#   'must',
#   'first',
#   'recognize',
#   'a',
#   'need',
#   'for',
#   'setting',
#   'up',
#   'controlled',
#   'experiments',
#   'after',
#   'they',
#   'have',
#   'done',
#   'some',
#   '“',
#   'messing',
#   'around',
#   '”',
#   'with',
#   'the',
#   'system',
#   '.'],
#  ['1',
#   '·',
#   'INTRODUCE',
#   'STUDENTS',
#   'TO',
#   'THE',
#   'REGULAR',
#   'CUP',
#   'AND',
#   'FANCY',
#   'CUP'],
#  ['1',
#   '5',
#   'min',
#   'INTRODUCE',
#   'STUDENTS',
#   'TO',
#   'THE',
#   'REGULAR',
#   'CUP',
#   'AND',
#   'FANCY',
#   'CUP',
#   'Introduce',
#   'students',
#   'to',
#   'the',
#   'warming',
#   'up',
#   'of',
#   'an',
#   'iced',
#   'drink',
#   'in',
#   'a',
#   'regular',
#   'plastic',
#   'cup',
#   '.',
#   'Show',
#   'students',
#   'the',
#   'fancy',
#   'cup',
#   'that',
#   'is',
#   'claimed',
#   'to',
#   'keep',
#   'the',
#   'drink',
#   'colder',
#   'longer',
#   '.',
#   'A',
#   '1',
#   '16-oz',
#   'regular',
#   'plastic',
#   'cup',
#   ',',
#   '1',
#   '16-oz',
#   'fancy',
#   'plastic',
#   'cup',
#   '2',
#   '5',
#   'min',
#   'BRAINSTORM',
#   'HOW',
#   'TO',
#   'TEST',
#   'THE',
#   'TWO',
#   'CUPS',
#   'Elicit',
#   'students',
#   '’',
#   'ideas',
#   'about',
#   'how',
#   'to',
#   'test',
#   'whether',
#   'the',
#   'fancy',
#   'cup',
#   'keeps',
#   'a',
#   'drink',
#   'colder',
#   'for',
#   'longer',
#   'than',
#   'the',
#   'regular',
#   'cup',
#   '.'],
#  ['1',
#   'SETTING',
#   'UP',
#   'OUR',
#   'SCIENCE',
#   'JOURNALS',
#   '[',
#   '2',
#   'min',
#   ']',
#   'Have',
#   'students',
#   'set',
#   'up',
#   'their',
#   'science',
#   'notebooks',
#   'for',
#   'the',
#   'unit',
#   'so',
#   'their',
#   'evidence',
#   'and',
#   'sense-making',
#   'will',
#   'be',
#   'organized',
#   '.',
#   '2',
#   'INTRODUCING',
#   'AN',
#   'INTERESTING',
#   'PHENOMENON',
#   '[',
#   '3',
#   'min',
#   ']',
#   'Introduce',
#   'students',
#   'to',
#   'the',
#   'first',
#   'video',
#   ':',
#   'a',
#   'news',
#   'report',
#   'of',
#   'chickens',
#   'being',
#   'raised',
#   'in',
#   'residential',
#   'backyards',
#   '.',
#   'Have',
#   'students',
#   'brainstorm',
#   'why',
#   'they',
#   'think',
#   'people',
#   'raise',
#   'chickens',
#   '.',
#   'Make',
#   'sure',
#   'they',
#   'include',
#   'their',
#   'own',
#   'experiences',
#   '.',
#   'Have',
#   'them',
#   'discuss',
#   'drawbacks',
#   'and',
#   'benefits',
#   'to',
#   'raising',
#   'chickens',
#   '.',
#   'A',
#   '3',
#   'MAKING',
#   'OBSERVATIONS',
#   '[',
#   '8',
#   'min',
#   ']',
#   'Show',
#   'the',
#   'second',
#   'video',
#   '-',
#   'people',
#   'raising',
#   'chickens',
#   'in',
#   'their',
#   'own',
#   'backyards',
#   '.',
#   'Have',
#   'students',
#   'write',
#   'down',
#   'what',
#   'they',
#   'wonder',
#   'and',
#   'notice',
#   'in',
#   'a',
#   'Notice-Wonder',
#   'routine',
#   '.',
#   'B-C',
#   'Notice-Wonder',
#   'graphic',
#   'organizer',
#   '(',
#   'optional',
#   ')',
#   '4',
#   'MAKING',
#   'ADDITIONAL',
#   'OBSERVATIONS',
#   '[',
#   '6',
#   'min',
#   ']',
#   'Show',
#   'the',
#   'third',
#   'video',
#   '-',
#   'montage',
#   'of',
#   'chickens',
#   'and',
#   'eggs',
#   '.',
#   'Have',
#   'students',
#   'write',
#   'down',
#   'what',
#   'they',
#   'wonder',
#   'and',
#   'notice',
#   'in',
#   'a',
#   'Notice-Wonder',
#   'routine',
#   '.',
#   'D',
#   'Notice-Wonder',
#   'graphic',
#   'organizer',
#   '(',
#   'optional',
#   ')',
#   '5',
#   'DEVELOPING',
#   'AN',
#   'INITIAL',
#   'MODEL',
#   '[',
#   '10',
#   'min',
#   ']',
#   'Have',
#   'students',
#   'develop',
#   'an',
#   'initial',
#   'model',
#   'to',
#   'explain',
#   'what',
#   'is',
#   'going',
#   'on',
#   'with',
#   'eggs',
#   'that',
#   'hatch',
#   ',',
#   'and',
#   'eggs',
#   'that',
#   'don',
#   '’',
#   't',
#   'hatch',
#   '.',
#   'E-F',
#   'Lesson',
#   '1',
#   'Initial',
#   'student',
#   'model',
#   'student',
#   'handout',
#   '6',
#   'COMPARING',
#   'INITIAL',
#   'MODELS',
#   '[',
#   '10',
#   'min',
#   ']',
#   'Have',
#   'students',
#   'use',
#   'the',
#   'talking',
#   'stick',
#   'protocol',
#   'to',
#   'share',
#   'their',
#   'initial',
#   'model',
#   'with',
#   '2',
#   'other',
#   'people',
#   'in',
#   'the',
#   'class',
#   '.',
#   'As',
#   'peers',
#   'share',
#   'their',
#   'models',
#   ',',
#   'other',
#   'students',
#   'record',
#   'similarities',
#   'and',
#   'differences',
#   'between',
#   'the',
#   'models',
#   '.',
#   'G-H',
#   'Large',
#   'index',
#   'cards',
#   'Suggested',
#   'break',
#   '-',
#   'end',
#   'of',
#   'day',
#   '1',
#   '7',
#   'CLASS',
#   'CONSENSUS',
#   'MODEL',
#   '[',
#   '15',
#   'min',
#   ']',
#   'As',
#   'a',
#   'whole',
#   'group',
#   ',',
#   'have',
#   'students',
#   'share',
#   'similarities',
#   'and',
#   'differences',
#   'in',
#   'their',
#   'models',
#   'and',
#   'keep',
#   'track',
#   'of',
#   'these',
#   'ideas',
#   'on',
#   'the',
#   'board',
#   'or',
#   'large',
#   'chart',
#   'paper',
#   '.',
#   'I-J',
#   'Chart',
#   'paper',
#   'and',
#   'markers',
#   ',',
#   'discussion',
#   'norms',
#   'poster',
#   '8',
#   'CONNECTING',
#   'TO',
#   'RELATED',
#   'PHENOMENA',
#   '[',
#   '10',
#   'min',
#   ']',
#   'Ask',
#   'students',
#   'to',
#   'brainstorm',
#   'and',
#   'identify',
#   'other',
#   'organisms',
#   'that',
#   'lay',
#   'eggs',
#   ',',
#   'and',
#   'to',
#   'consider',
#   'how',
#   'understanding',
#   'what',
#   'happens',
#   'inside',
#   'the',
#   'chicken',
#   'egg',
#   'might',
#   'help',
#   'them',
#   'understand',
#   'other',
#   'phenomena',
#   ',',
#   'especially',
#   'by',
#   'brainstorming',
#   'the',
#   'similarities',
#   'and',
#   'differences',
#   'between',
#   'various',
#   'egg-laying',
#   'animals',
#   '.',
#   'Record',
#   'the',
#   'name',
#   'of',
#   'each',
#   'organism',
#   'they',
#   'suggest',
#   'on',
#   'an',
#   'index',
#   'card',
#   '(',
#   'or',
#   'sticky',
#   ')',
#   'and',
#   'post',
#   'on',
#   'the',
#   'board',
#   '.',
#   'K',
#   'Chart',
#   'paper',
#   'and',
#   'markers',
#   '9',
#   'INITIAL',
#   'QUESTIONS',
#   'AND',
#   'IDEAS',
#   'FOR',
#   'INVESTIGATIONS',
#   '[',
#   '15',
#   'min',
#   ']',
#   'Have',
#   'students',
#   'generate',
#   'ideas',
#   'for',
#   'investigations',
#   'that',
#   'the',
#   'class',
#   'could',
#   'do',
#   'to',
#   'figure',
#   'out',
#   'what',
#   'is',
#   'going',
#   'on',
#   'inside',
#   'the',
#   'chicken',
#   'eggs',
#   '.',
#   'Have',
#   'students',
#   'record',
#   'their',
#   'findings',
#   'in',
#   'their',
#   'science',
#   'notebooks',
#   '.',
#   'L-M',
#   'Index',
#   'cards',
#   '(',
#   'or',
#   'sticky',
#   'notes',
#   ')',
#   'and',
#   'markers'],
#  ['1',
#   'SETTING',
#   'UP',
#   'OUR',
#   'SCIENCE',
#   'JOURNALS',
#   '[',
#   '2',
#   'min',
#   ']',
#   'Have',
#   'students',
#   'set',
#   'up',
#   'their',
#   'science',
#   'notebooks',
#   'for',
#   'the',
#   'unit',
#   'so',
#   'their',
#   'evidence',
#   'and',
#   'sense-making',
#   'will',
#   'be',
#   'organized',
#   '.',
#   'A',
#   '2',
#   'INTRODUCING',
#   'AN',
#   'INTERESTING',
#   'PHENOMENON',
#   'AND',
#   'MAKING',
#   'OBSERVATIONS',
#   '[',
#   '10',
#   'min',
#   ']',
#   'Show',
#   'initial',
#   'puppies',
#   'at',
#   'the',
#   'vet',
#   'video',
#   'B-E',
#   '1-1',
#   'Puppy',
#   'at',
#   'the',
#   'vet',
#   'video',
#   '3',
#   'PRELIMINARY',
#   'OPEN',
#   'DIAGNOSIS',
#   'AND',
#   'LINKING',
#   'TO',
#   'THE',
#   'OPENING',
#   'NARRATIVE',
#   '[',
#   '40',
#   'min',
#   ']',
#   'Show',
#   'students',
#   'their',
#   'first',
#   'concrete',
#   'case',
#   'with',
#   'actual',
#   'symptoms',
#   'and',
#   'have',
#   'them',
#   'prepare',
#   'questions',
#   'for',
#   'the',
#   'owner',
#   'and',
#   'veterinarian',
#   '.',
#   'The',
#   'class',
#   'also',
#   'establishes',
#   'a',
#   'driving',
#   'question',
#   'board',
#   '.',
#   'F-J',
#   '1-2',
#   'Coughing',
#   'dog',
#   'video',
#   ',',
#   'sticky',
#   'notes',
#   ',',
#   'butcher',
#   'paper',
#   '4',
#   'ORGANIZING',
#   'AND',
#   'FORMALIZING',
#   'OBSERVATIONS',
#   '[',
#   '10',
#   'min',
#   ']',
#   'Examine',
#   'agreement',
#   'between',
#   'open',
#   'questions',
#   'and',
#   'items',
#   'on',
#   'the',
#   'formalized',
#   'diagnostic',
#   'sheet',
#   '.',
#   'K',
#   '1-3',
#   'Vet',
#   'diagnostic',
#   'overview',
#   'sheet',
#   ',',
#   'highlighters',
#   '5',
#   'NEXT',
#   'STEPS',
#   '[',
#   '5',
#   'min',
#   ']',
#   'Identify',
#   'what',
#   'students',
#   'figured',
#   'out',
#   'and',
#   'what',
#   'they',
#   'still',
#   'need',
#   'to',
#   'figure',
#   'out',
#   '.',
#   'L'],
#  ['1.A',
#   'Develop',
#   'an',
#   'initial',
#   'model',
#   'to',
#   'describe',
#   'a',
#   'phenomenon',
#   'in',
#   'which',
#   'a',
#   'substance',
#   'changes',
#   'temperature',
#   'and',
#   'identify',
#   'structural',
#   'parts',
#   'of',
#   'the',
#   'system',
#   'that',
#   'slow',
#   'down',
#   'or',
#   'speed',
#   'up',
#   'the',
#   'temperature',
#   'change',
#   '(',
#   'function',
#   ')',
#   '.',
#   '1.B',
#   'Ask',
#   'questions',
#   'that',
#   'arise',
#   'from',
#   'careful',
#   'observation',
#   'and',
#   'can',
#   'be',
#   'investigated',
#   'in',
#   'the',
#   'classroom',
#   'to',
#   'test',
#   'how',
#   'parts',
#   'of',
#   'the',
#   'cup',
#   'systems',
#   'contribute',
#   'to',
#   'warming',
#   'up',
#   'or',
#   'maintaining',
#   'the',
#   'temperature',
#   'of',
#   'the',
#   'substance',
#   'inside',
#   '.',
#   'What',
#   'students',
#   'will',
#   'figure',
#   'out',
#   '●',
#   'The',
#   'cup',
#   'system',
#   'includes',
#   'the',
#   'different',
#   'parts',
#   'of',
#   'the',
#   'cup',
#   'and',
#   'the',
#   'water',
#   'and',
#   'air',
#   'inside',
#   'the',
#   'cup',
#   '.',
#   'All',
#   'of',
#   'these',
#   'parts',
#   'work',
#   'together',
#   '(',
#   'interact',
#   ')',
#   'to',
#   'form',
#   'the',
#   'system',
#   '.',
#   '●',
#   'Some',
#   'systems',
#   'have',
#   'structural',
#   'features',
#   'that',
#   'help',
#   'maintain',
#   'the',
#   'temperature',
#   'of',
#   'a',
#   'substance',
#   'inside',
#   'the',
#   'system',
#   ',',
#   'keeping',
#   'the',
#   'substance',
#   'hot',
#   'or',
#   'cold',
#   'longer',
#   'compared',
#   'with',
#   'other',
#   'systems',
#   '.'],
#  ['1.A',
#   'If',
#   'your',
#   'students',
#   'struggle',
#   'with',
#   'identifying',
#   'important',
#   'parts',
#   '(',
#   'components',
#   ')',
#   'and',
#   'processes',
#   'for',
#   'the',
#   'cycling',
#   'of',
#   'water',
#   ',',
#   'you',
#   'may',
#   'need',
#   'to',
#   'spend',
#   'additional',
#   'time',
#   'reviewing',
#   'those',
#   'key',
#   'processes',
#   'before',
#   'they',
#   'develop',
#   'their',
#   'individual',
#   'models',
#   '.',
#   'If',
#   'students',
#   'don',
#   '’',
#   't',
#   'explain',
#   'how',
#   'the',
#   'change',
#   'in',
#   'temperature',
#   'is',
#   'causing',
#   'the',
#   'changes',
#   'to',
#   'the',
#   'processes',
#   'and',
#   'components',
#   'that',
#   'the',
#   'class',
#   'identified',
#   ',',
#   'use',
#   'prompts',
#   'to',
#   'solicit',
#   'those',
#   'connections',
#   '(',
#   'e.g.',
#   ',',
#   'I',
#   'see',
#   'you',
#   'are',
#   'showing',
#   'that',
#   'evaporation',
#   'is',
#   'changing',
#   ',',
#   'can',
#   'you',
#   'add',
#   'some',
#   'words',
#   'to',
#   'explain',
#   'how',
#   'that',
#   'is',
#   'connected',
#   'to',
#   'the',
#   'increased',
#   'temperatures',
#   '?',
#   ')',
#   '.',
#   '●',
#   '1.B',
#   'If',
#   'students',
#   'use',
#   'language',
#   'they',
#   'have',
#   'heard',
#   'connected',
#   'to',
#   'increased',
#   'temperatures',
#   '(',
#   'e.g.',
#   ',',
#   'climate',
#   'change',
#   ',',
#   'greenhouse',
#   'effect',
#   ',',
#   'pollution',
#   ',',
#   'global',
#   'warming',
#   ')',
#   'but',
#   'don',
#   '’',
#   't',
#   'explain',
#   'how',
#   'this',
#   'could',
#   'cause',
#   'increased',
#   'temperatures',
#   ',',
#   'prompt',
#   'them',
#   'to',
#   'use',
#   'words',
#   'or',
#   'images',
#   'to',
#   'explain',
#   'what',
#   'the',
#   'words',
#   'they',
#   'use',
#   'mean',
#   'to',
#   'them',
#   ',',
#   'how',
#   'those',
#   'processes',
#   ',',
#   'such',
#   'as',
#   'climate',
#   'change',
#   ',',
#   'work',
#   ',',
#   'and',
#   'how',
#   'they',
#   'lead',
#   'to',
#   'increased',
#   'temperatures',
#   '.'],
#  ['1-2', 'classes', '-', '45', 'minutes', 'each'],
#  ['2', '·', 'BRAINSTORM', 'HOW', 'TO', 'TEST', 'THE', 'TWO', 'CUPS'],
#  ['3',
#   '·',
#   'GATHER',
#   'IN',
#   'A',
#   'SCIENTISTS',
#   'CIRCLE',
#   'FOR',
#   'THE',
#   'COLD',
#   'CUP',
#   'TEST'],
#  ['3',
#   '20',
#   'min',
#   'GATHER',
#   'IN',
#   'A',
#   'SCIENTISTS',
#   'CIRCLE',
#   'FOR',
#   'THE',
#   'COLD',
#   'CUP',
#   'TEST',
#   'Convene',
#   'a',
#   'Scientists',
#   'Circle',
#   'to',
#   'collect',
#   'observational',
#   'data',
#   'and',
#   'temperature',
#   'data',
#   'on',
#   'the',
#   'two',
#   'cups',
#   '.',
#   'During',
#   'the',
#   'test',
#   ',',
#   'compare',
#   'the',
#   'two',
#   'cups',
#   '’',
#   'structural',
#   'features',
#   '.'],
#  ['4',
#   '12',
#   'min',
#   'DEVELOP',
#   'SYSTEMS',
#   'MODELS',
#   'FOR',
#   'THE',
#   'TWO',
#   'CUPS',
#   'Have',
#   'students',
#   'work',
#   'individually',
#   'to',
#   'draw',
#   'systems',
#   'models',
#   'to',
#   'explain',
#   'why',
#   'the',
#   'water',
#   'in',
#   'the',
#   'regular',
#   'cup',
#   'warms',
#   'up',
#   'more',
#   'quickly',
#   'than',
#   'the',
#   'water',
#   'in',
#   'the',
#   'fancy',
#   'cup',
#   '.'],
#  ['5',
#   '5',
#   'min',
#   'SHARE',
#   'INITIAL',
#   'CONCLUSIONS',
#   'AND',
#   'ASSIGN',
#   'HOME',
#   'LEARNING',
#   'Have',
#   'students',
#   'return',
#   'to',
#   'the',
#   'claim',
#   'and',
#   'share',
#   'initial',
#   'conclusions',
#   '.',
#   'Pose',
#   'the',
#   'lesson',
#   'question',
#   'and',
#   'assign',
#   'students',
#   'to',
#   'identify',
#   'related',
#   'phenomena',
#   'at',
#   'home',
#   '.',
#   'F',
#   'End',
#   'of',
#   'day',
#   '1',
#   '6',
#   '8',
#   'min',
#   'NAVIGATION',
#   'Have',
#   'students',
#   'review',
#   'the',
#   'temperature',
#   'data',
#   'and',
#   'observations',
#   'from',
#   'the',
#   'Cold',
#   'Cup',
#   'Test',
#   '.',
#   'Prompt',
#   'students',
#   'to',
#   'write',
#   'conclusions',
#   'from',
#   'the',
#   'data',
#   'and',
#   'be',
#   'prepared',
#   'to',
#   'share',
#   'with',
#   'partners',
#   'and',
#   'then',
#   'the',
#   'whole',
#   'class',
#   '.',
#   'G',
#   '7',
#   '5',
#   'min',
#   'REVIEW',
#   'NORMS',
#   'AND',
#   'SET',
#   'EXPECTATIONS',
#   'Have',
#   'students',
#   'review',
#   'the',
#   'classroom',
#   'norms',
#   'and',
#   'set',
#   'expectations',
#   'for',
#   'their',
#   'work',
#   'together',
#   'on',
#   'a',
#   'consensus',
#   'model',
#   '.',
#   'Prompt',
#   'students',
#   'to',
#   'pick',
#   'one',
#   'norm',
#   'to',
#   'focus',
#   'on',
#   'for',
#   'today',
#   '.'],
#  ['8',
#   '15',
#   'min',
#   'DEVELOP',
#   'A',
#   'CONSENSUS',
#   'MODEL',
#   'FOR',
#   'THE',
#   'TWO',
#   'CUPS',
#   'Convene',
#   'a',
#   'Scientists',
#   'Circle',
#   'to',
#   'develop',
#   'a',
#   'consensus',
#   'model',
#   'to',
#   'explain',
#   'why',
#   'the',
#   'two',
#   'cup',
#   'systems',
#   'work',
#   'the',
#   'way',
#   'they',
#   'do'],
#  ['8', 'min'],
#  ['9',
#   '10',
#   'min',
#   'BRAINSTORM',
#   'RELATED',
#   'PHENOMENA',
#   'Record',
#   'students',
#   '’',
#   'ideas',
#   'of',
#   'related',
#   'phenomena',
#   'and',
#   'related',
#   'objects',
#   'that',
#   'do',
#   'a',
#   'good',
#   'job',
#   'at',
#   'maintaining',
#   'the',
#   'temperature',
#   'of',
#   'the',
#   'stuff',
#   'inside',
#   'them',
#   '.'],
#  ['10',
#   '8',
#   'min',
#   'NAVIGATION',
#   'Have',
#   'students',
#   'use',
#   'their',
#   'ideas',
#   'from',
#   'the',
#   'consensus',
#   'model',
#   'to',
#   'develop',
#   'a',
#   'model',
#   'for',
#   'one',
#   'of',
#   'the',
#   'related',
#   'systems',
#   '.',
#   'M',
#   'End',
#   'of',
#   'day',
#   '2',
#   '11',
#   '8',
#   'min',
#   'CONDUCT',
#   'A',
#   'GALLERY',
#   'WALK',
#   'TO',
#   'EXAMINE',
#   'MODELS',
#   'Have',
#   'students',
#   'open',
#   'their',
#   'science',
#   'notebooks',
#   'to',
#   'their',
#   'related',
#   'phenomenon',
#   'model',
#   'and',
#   'complete',
#   'a',
#   'gallery',
#   'walk',
#   'to',
#   'view',
#   'their',
#   'classmates',
#   '’',
#   'work',
#   '.',
#   'N',
#   '12',
#   '5',
#   'min',
#   'DEVELOP',
#   'QUESTIONS',
#   'FOR',
#   'THE',
#   'DRIVING',
#   'QUESTION',
#   'BOARD',
#   'Direct',
#   'students',
#   'to',
#   'look',
#   'at',
#   'their',
#   'models',
#   'for',
#   'the',
#   'cup',
#   'systems',
#   'and',
#   'their',
#   'model',
#   'for',
#   'the',
#   'related',
#   'phenomenon',
#   'to',
#   'develop',
#   'questions',
#   'about',
#   'structures',
#   'and',
#   'mechanisms',
#   'that',
#   'seem',
#   'important',
#   'to',
#   'figure',
#   'out',
#   '.'],
#  ['10',
#   'DRIVING',
#   'QUESTION',
#   'BOARD',
#   '[',
#   '25–30',
#   'min',
#   ']',
#   'Develop',
#   'a',
#   'Driving',
#   'Question',
#   'Board',
#   '(',
#   'sample',
#   'on',
#   'page',
#   '15',
#   ')',
#   'to',
#   'document',
#   'student',
#   'questions',
#   'about',
#   'why',
#   'some',
#   'eggs',
#   'hatch',
#   'into',
#   'chickens',
#   'and',
#   'other',
#   'related',
#   'phenomena',
#   '.',
#   'N-O',
#   'DQB',
#   ',',
#   'index',
#   'cards',
#   'or',
#   'sticky',
#   'notes',
#   '(',
#   '2+',
#   'per',
#   'student',
#   ')',
#   ',',
#   'markers',
#   '11',
#   'INVESTIGATION',
#   'IDEAS',
#   '[',
#   '15',
#   'min',
#   ']',
#   'Students',
#   'will',
#   'brainstorm',
#   'investigations',
#   'that',
#   'can',
#   'be',
#   'done',
#   'to',
#   'answer',
#   'two',
#   'questions',
#   'they',
#   'heard',
#   'during',
#   'the',
#   'DQB',
#   'set',
#   'up',
#   '.',
#   'Then',
#   'as',
#   'a',
#   'class',
#   ',',
#   'a',
#   'record',
#   'of',
#   'these',
#   'investigation',
#   'ideas',
#   'will',
#   'be',
#   'recorded',
#   'on',
#   'chart',
#   'or',
#   'poster',
#   'paper',
#   'for',
#   'reference',
#   'throughout',
#   'the',
#   'unit',
#   '.',
#   'P',
#   'Chart',
#   'or',
#   'Poster',
#   'paper',
#   ',',
#   'and',
#   'markers',
#   '12',
#   'WHERE',
#   'SHOULD',
#   'WE',
#   'GO',
#   'NEXT',
#   '?',
#   'EXIT',
#   'SLIP',
#   '[',
#   '8',
#   'min',
#   ']',
#   'Students',
#   'record',
#   'what',
#   'we',
#   'should',
#   'investigate',
#   'first',
#   'and',
#   'why',
#   'on',
#   'an',
#   'index',
#   'card',
#   'and',
#   'turn',
#   'this',
#   'in',
#   'on',
#   'their',
#   'way',
#   'out',
#   'the',
#   'door',
#   '.',
#   'Q',
#   'Index',
#   'cards',
#   ',',
#   'and',
#   'pencils',
#   ','],
#  ['10', 'min', ']'],
#  ['10', 'min', ']'],
#  ['13',
#   '20',
#   'min',
#   'DEVELOP',
#   'THE',
#   'DRIVING',
#   'QUESTION',
#   'BOARD',
#   'Convene',
#   'a',
#   'Scientists',
#   'Circle',
#   'to',
#   'construct',
#   'the',
#   'Driving',
#   'Question',
#   'Board',
#   '(',
#   'DQB',
#   ')',
#   'around',
#   'students',
#   '’',
#   'questions',
#   '.'],
#  ['14',
#   '10',
#   'min',
#   'PLAN',
#   'IDEAS',
#   'FOR',
#   'INVESTIGATIONS',
#   'Create',
#   'an',
#   'Ideas',
#   'for',
#   'Investigations',
#   'poster',
#   'and',
#   'record',
#   'the',
#   'class',
#   '’',
#   's',
#   'thoughts',
#   'on',
#   'how',
#   'to',
#   'figure',
#   'out',
#   'the',
#   'answers',
#   'to',
#   'our',
#   'initial',
#   'questions',
#   'as',
#   'we',
#   'move',
#   'forward',
#   '.'],
#  ['15',
#   '2',
#   'min',
#   'NAVIGATION',
#   'Work',
#   'with',
#   'students',
#   'to',
#   'brainstorm',
#   'how',
#   'to',
#   'investigate',
#   'the',
#   'cups',
#   'next',
#   'to',
#   'gather',
#   'more',
#   'data',
#   '.'],
#  ['20-25', 'min', ']'],
#  ['ADDITIONAL',
#   'GUIDANCE',
#   'During',
#   'this',
#   'discussion',
#   ',',
#   'students',
#   'will',
#   'share',
#   'vocabulary',
#   'words',
#   'that',
#   'the',
#   'class',
#   'will',
#   'continue',
#   'to',
#   'develop',
#   'and',
#   'use',
#   'throughout',
#   'the',
#   'unit',
#   '.',
#   'Avoid',
#   'defining',
#   'these',
#   'words',
#   'now',
#   ',',
#   'but',
#   'probe',
#   'students',
#   '’',
#   'understanding',
#   'of',
#   'what',
#   'they',
#   'mean',
#   'when',
#   'students',
#   'use',
#   'them',
#   '.',
#   'Keep',
#   'these',
#   'words',
#   'on',
#   'your',
#   'radar',
#   'for',
#   'further',
#   'development',
#   'and',
#   'plan',
#   'to',
#   'add',
#   'them',
#   'to',
#   'the',
#   'word',
#   'wall',
#   'when',
#   'students',
#   'develop',
#   'a',
#   'deeper',
#   'understanding',
#   'of',
#   'them',
#   'in',
#   'later',
#   'lessons',
#   '.',
#   'Students',
#   'will',
#   'earn',
#   'these',
#   'words',
#   'throughout',
#   'the',
#   'unit',
#   ':',
#   'heat',
#   ',',
#   'cold',
#   ',',
#   'temperature',
#   ',',
#   'insulate',
#   ',',
#   'vacuum',
#   ',',
#   'absorb',
#   ',',
#   'and',
#   'claim',
#   '.',
#   'More',
#   'words',
#   'will',
#   'be',
#   'added',
#   'to',
#   'this',
#   'list',
#   'as',
#   'they',
#   'come',
#   'up',
#   'during',
#   'discussion',
#   '.'],
#  ['ADDITIONAL',
#   'GUIDANCE',
#   'The',
#   'Driving',
#   'Question',
#   'Board',
#   'will',
#   'be',
#   'central',
#   'to',
#   'the',
#   'sensemaking',
#   'that',
#   'happens',
#   'in',
#   'the',
#   'unit',
#   '.',
#   'There',
#   'are',
#   'a',
#   'variety',
#   'of',
#   'ways',
#   'to',
#   'set',
#   'up',
#   'the',
#   'DQB',
#   'depending',
#   'on',
#   'your',
#   'classroom',
#   'resources',
#   ',',
#   'use',
#   'of',
#   'technology',
#   ',',
#   'and',
#   'the',
#   'number',
#   'of',
#   'students',
#   'you',
#   'see',
#   'each',
#   'day',
#   '.',
#   'What',
#   'works',
#   'for',
#   'some',
#   'will',
#   'not',
#   'work',
#   'for',
#   'others',
#   '.',
#   'Most',
#   'important',
#   'is',
#   'that',
#   'the',
#   'DQB',
#   'is',
#   'visible',
#   'to',
#   'students',
#   'each',
#   'day',
#   'and',
#   'represents',
#   '“',
#   'our',
#   'shared',
#   'mission',
#   '”',
#   '.',
#   'Students',
#   'will',
#   'be',
#   'using',
#   'the',
#   'DQB',
#   'to',
#   'assess',
#   'what',
#   'they',
#   '’',
#   've',
#   'figured',
#   'out',
#   'and',
#   'identify',
#   'next',
#   'steps',
#   '.'],
#  ['ADDITIONAL',
#   'GUIDANCE',
#   'This',
#   'lesson',
#   '(',
#   'and',
#   'this',
#   'unit',
#   ')',
#   'builds',
#   'on',
#   'ideas',
#   'that',
#   'students',
#   'figured',
#   'out',
#   'in',
#   'OpenSciEd',
#   'Unit',
#   '6.3',
#   ':',
#   'Why',
#   'does',
#   'a',
#   'lot',
#   'of',
#   'hail',
#   ',',
#   'rain',
#   ',',
#   'or',
#   'snow',
#   'fall',
#   'at',
#   'some',
#   'times',
#   'and',
#   'not',
#   'others',
#   '?',
#   '(',
#   'Storms',
#   'Unit',
#   ')',
#   'about',
#   'how',
#   'water',
#   'cycles',
#   'through',
#   'the',
#   'atmosphere',
#   '.',
#   'In',
#   'that',
#   'unit',
#   ',',
#   'students',
#   'figured',
#   'out',
#   'that',
#   'air',
#   'particles',
#   'near',
#   'the',
#   'ground',
#   'get',
#   'warmed',
#   'up',
#   'by',
#   'the',
#   'sun',
#   'and',
#   'that',
#   'this',
#   'energy',
#   'is',
#   'transferred',
#   'from',
#   'the',
#   'particles',
#   'in',
#   'the',
#   'ground',
#   'to',
#   'the',
#   'air',
#   'through',
#   'conduction',
#   '.',
#   'The',
#   'temperature',
#   'of',
#   'water',
#   'or',
#   'soil',
#   'increases',
#   'as',
#   'energy',
#   'is',
#   'added',
#   'to',
#   'them/the',
#   'substance',
#   '.',
#   'As',
#   'more',
#   'energy',
#   'is',
#   'added',
#   ',',
#   'some',
#   'water',
#   'molecules',
#   'turn',
#   'into',
#   'a',
#   'gas',
#   'and',
#   'become',
#   'water',
#   'vapor',
#   '(',
#   'evaporation',
#   ')',
#   '.',
#   'As',
#   'water',
#   'vapor',
#   'rises',
#   'in',
#   'the',
#   'atmosphere',
#   ',',
#   'it',
#   'cools',
#   'and',
#   'will',
#   'turn',
#   'back',
#   'into',
#   'liquid',
#   '.',
#   'It',
#   'condenses',
#   'on',
#   'dust',
#   'particles',
#   'or',
#   'other',
#   'things',
#   'in',
#   'the',
#   'air',
#   'and',
#   'begins',
#   'to',
#   'form',
#   'clouds',
#   'and',
#   'eventually',
#   'falls',
#   'as',
#   'precipitation',
#   '.',
#   'Students',
#   'may',
#   'also',
#   'recall',
#   'the',
#   'role',
#   'of',
#   'wind',
#   'in',
#   'moving',
#   'parcels',
#   'of',
#   'air',
#   'around',
#   '.',
#   'If',
#   'your',
#   'students',
#   'have',
#   'not',
#   'experienced',
#   'the',
#   'Storms',
#   'Unit',
#   ',',
#   'you',
#   'may',
#   'need',
#   'to',
#   'spend',
#   'additional',
#   'time',
#   'developing',
#   'these',
#   'ideas',
#   'with',
#   'your',
#   'students',
#   '.'],
#  ['Additional',
#   'Guidance',
#   '-A-',
#   'It',
#   'can',
#   'be',
#   'helpful',
#   'to',
#   'keep',
#   'a',
#   'public',
#   'record',
#   'of',
#   'the',
#   'Table',
#   'of',
#   'Contents',
#   'on',
#   'poster',
#   'paper',
#   'in',
#   'the',
#   'room',
#   'for',
#   'students',
#   'who',
#   'might',
#   'forget',
#   'to',
#   'update',
#   'their',
#   'Table',
#   'of',
#   'Contents',
#   'and',
#   'for',
#   'students',
#   'who',
#   'have',
#   'been',
#   'absent',
#   '.'],
#  ['Additional',
#   'Guidance',
#   '-B-',
#   'There',
#   'are',
#   'two',
#   'goals',
#   'for',
#   'this',
#   'turn',
#   'and',
#   'talk',
#   ':',
#   '(',
#   '1',
#   ')',
#   'to',
#   'prepare',
#   'students',
#   'to',
#   'think',
#   'about',
#   'why',
#   'people',
#   'may',
#   'want',
#   'to',
#   'raise',
#   'chickens',
#   'and',
#   '(',
#   '2',
#   ')',
#   'to',
#   'help',
#   'students',
#   'build',
#   'confidence',
#   'in',
#   'sharing',
#   'their',
#   'ideas',
#   'publicly',
#   '.'],
#  ['Additional',
#   'Guidance',
#   '-E-',
#   'It',
#   'is',
#   'possible',
#   'that',
#   'some',
#   'students',
#   'might',
#   'think',
#   'of',
#   'heartworm',
#   'as',
#   'a',
#   'possible',
#   'cause',
#   'already',
#   'based',
#   'on',
#   'past',
#   'experience',
#   '.',
#   'This',
#   'should',
#   'be',
#   'treated',
#   'as',
#   'any',
#   'other',
#   'prediction',
#   'and',
#   'the',
#   'following',
#   'lessons',
#   'aren',
#   '’',
#   't',
#   '“',
#   'spoiled',
#   '”',
#   'by',
#   'an',
#   'early',
#   'suggestion',
#   'of',
#   'heartworm',
#   '.'],
#  ['Additional',
#   'Guidance',
#   '-G-',
#   'There',
#   'are',
#   'a',
#   'lot',
#   'of',
#   'words',
#   'that',
#   'may',
#   'be',
#   'unfamiliar',
#   'to',
#   'students',
#   'in',
#   'the',
#   'checkup',
#   'sheet',
#   '.',
#   'One',
#   'way',
#   'to',
#   'support',
#   'students',
#   '’',
#   'comprehension',
#   'is',
#   'to',
#   'prompt',
#   'them',
#   'to',
#   'look',
#   'up',
#   'words',
#   'they',
#   'don',
#   '’',
#   't',
#   'know',
#   'and',
#   'create',
#   'their',
#   'own',
#   'vocabulary',
#   'list',
#   'in',
#   'their',
#   'science'],
#  ['Additional',
#   'Guidance',
#   '-I-',
#   'These',
#   'index',
#   'cards',
#   'or',
#   'images',
#   'will',
#   'be',
#   'useful',
#   'for',
#   'moving',
#   'around',
#   'on',
#   'this',
#   'poster',
#   '.',
#   'You',
#   'will',
#   'be',
#   'able',
#   'to',
#   'space',
#   'these',
#   'index',
#   'cards',
#   'out',
#   'and',
#   'add',
#   'photographs',
#   'next',
#   'to',
#   'each',
#   'of',
#   'these',
#   'before',
#   'forming',
#   'the',
#   'Driving',
#   'Question',
#   'Board',
#   '.',
#   'This',
#   'will',
#   'help',
#   'foreground',
#   'that',
#   'coming',
#   'up',
#   'with',
#   'questions',
#   'about',
#   'all',
#   'sorts',
#   'of',
#   'organisms',
#   'that',
#   'come',
#   'from',
#   'eggs',
#   'is',
#   'fair',
#   'game',
#   '(',
#   'and',
#   'desirable',
#   ')',
#   'for',
#   'the',
#   'Driving',
#   'Question',
#   'Board',
#   '.'],
#  ['ADDITIONAL',
#   'GUIDANCE',
#   'If',
#   'you',
#   'want',
#   'to',
#   'modify',
#   'the',
#   'anchor',
#   ',',
#   'keep',
#   'the',
#   'following',
#   'questions',
#   'in',
#   'mind',
#   'as',
#   'you',
#   'brainstorm',
#   'ways',
#   'to',
#   'approach',
#   'the',
#   'anchor',
#   'scenario',
#   ':',
#   '●',
#   'Is',
#   'it',
#   'going',
#   'to',
#   'be',
#   'meaningful',
#   'for',
#   'my',
#   'students',
#   '?',
#   '●',
#   'Is',
#   'it',
#   'going',
#   'to',
#   'motivate',
#   'students',
#   'to',
#   'want',
#   'to',
#   'explain',
#   'how',
#   'things',
#   'warm',
#   'up',
#   ',',
#   'cool',
#   'down',
#   ',',
#   'or',
#   'maintain',
#   'their',
#   'temperature',
#   'over',
#   'time',
#   'in',
#   'the',
#   'given',
#   'context',
#   '?',
#   '●',
#   'Is',
#   'it',
#   'going',
#   'to',
#   'help',
#   'students',
#   'connect',
#   'their',
#   'observations',
#   'of',
#   'the',
#   'cups',
#   'to',
#   'their',
#   'experiences',
#   'with',
#   'related',
#   'phenomena',
#   'and',
#   'related',
#   'systems',
#   '?',
#   'An',
#   'example',
#   'modification',
#   ':',
#   'If',
#   'reducing',
#   'single-use',
#   'plastic',
#   'is',
#   'an',
#   'important',
#   'issue',
#   'for',
#   'your',
#   'students',
#   ',',
#   'set',
#   'up',
#   'the',
#   'anchor',
#   'around',
#   'avoiding',
#   'non-recyclable',
#   'straws',
#   '.',
#   'Without',
#   'a',
#   'straw',
#   ',',
#   'the',
#   'lid',
#   'on',
#   'the',
#   'regular',
#   'cup',
#   'must',
#   'be',
#   'removed',
#   'to',
#   'take',
#   'a',
#   'sip',
#   ',',
#   'but',
#   'then',
#   'the',
#   'drink',
#   'warms',
#   'up',
#   'more',
#   'quickly',
#   ',',
#   'thus',
#   'the',
#   'need',
#   'for',
#   'a',
#   'reusable',
#   'cup',
#   'and',
#   'straw',
#   '.',
#   'This',
#   'version',
#   'of',
#   'the',
#   'anchor',
#   'is',
#   'well-connected',
#   'to',
#   'the',
#   'content',
#   'of',
#   'the',
#   'unit',
#   ',',
#   'and',
#   'could',
#   'be',
#   'motivational',
#   'to',
#   'students',
#   '.'],
#  ['ADDITIONAL',
#   'GUIDANCE',
#   'Refer',
#   'to',
#   'the',
#   'cups',
#   'as',
#   'the',
#   'regular',
#   'cup',
#   'and',
#   'the',
#   'fancy',
#   'cup',
#   '.',
#   'Avoid',
#   'using',
#   'the',
#   'terms',
#   'single-wall',
#   'and',
#   'double-wall',
#   'during',
#   'today',
#   '’',
#   's',
#   'lesson',
#   '.',
#   'Wait',
#   'until',
#   'your',
#   'students',
#   'have',
#   'established',
#   'that',
#   'the',
#   'regular',
#   'cup',
#   'has',
#   'only',
#   '1',
#   'wall',
#   'and',
#   'the',
#   'fancy',
#   'cup',
#   'has',
#   '2',
#   'walls',
#   'before',
#   'describing',
#   'the',
#   'cups',
#   'as',
#   'single-wall',
#   'and',
#   'double-wall',
#   '.'],
#  ['ALTERNATE',
#   'ACTIVITY',
#   'You',
#   'may',
#   'wish',
#   'to',
#   'change',
#   'the',
#   'order',
#   'of',
#   'the',
#   'stories',
#   'that',
#   'you',
#   'show',
#   'to',
#   'connect',
#   'to',
#   'the',
#   'situation',
#   'that',
#   'is',
#   'more',
#   'closely',
#   'connected',
#   'to',
#   'what',
#   'your',
#   'community',
#   'has',
#   'experienced',
#   '.',
#   'For',
#   'example',
#   ',',
#   'if',
#   'your',
#   'community',
#   'has',
#   'experienced',
#   'flooding',
#   ',',
#   'you',
#   'may',
#   'want',
#   'to',
#   'start',
#   'with',
#   'the',
#   'Vicksburg',
#   ',',
#   'MS',
#   ',',
#   'story',
#   'and',
#   'then',
#   'show',
#   'the',
#   'drought',
#   'story',
#   '.',
#   'If',
#   'the',
#   'story',
#   'order',
#   'is',
#   'changed',
#   ',',
#   'you',
#   'will',
#   'also',
#   'need',
#   'to',
#   'change',
#   'the',
#   'Notice',
#   'and',
#   'Wonder',
#   'titles',
#   'on',
#   'slides',
#   'A',
#   ',',
#   'B',
#   ',',
#   'C',
#   ',',
#   'D',
#   ',',
#   'and',
#   'F',
#   '.'],
#  ['Anchoring', 'Phenomenon'],
#  ['As',
#   'students',
#   'share',
#   ',',
#   'probe',
#   'their',
#   'thinking',
#   'about',
#   'what',
#   'each',
#   'part',
#   'does',
#   'in',
#   'the',
#   'system',
#   ',',
#   'focusing',
#   'particularly',
#   'on',
#   'parts',
#   'that',
#   'they',
#   'have',
#   'identified',
#   'as',
#   'slightly',
#   'different',
#   'between',
#   'the',
#   'two',
#   'cup',
#   'systems',
#   '.'],
#  ['As',
#   'students',
#   'work',
#   ',',
#   'circulate',
#   'around',
#   'the',
#   'classroom',
#   'to',
#   'make',
#   'sure',
#   'they',
#   'are',
#   'not',
#   'just',
#   'sketching',
#   'the',
#   'cups',
#   'but',
#   'are',
#   'explaining',
#   'parts',
#   'of',
#   'the',
#   'cups',
#   'that',
#   'help/do',
#   'not',
#   'help',
#   'keep',
#   'the',
#   'drink',
#   'cold',
#   '.'],
#  ['Attending',
#   'to',
#   'Equity',
#   '-L-',
#   'The',
#   'central',
#   'goal',
#   'during',
#   'the',
#   'formation',
#   'of',
#   'the',
#   'DQB',
#   'is',
#   'reinforcing',
#   'a',
#   'classroom',
#   'community',
#   'where',
#   'all',
#   'ideas',
#   'are',
#   'valued',
#   'and',
#   'everyone',
#   'has',
#   'a',
#   'question',
#   'up',
#   'on',
#   'the',
#   'board',
#   '.',
#   'Use',
#   'your',
#   'judgement',
#   'on',
#   'how',
#   'to',
#   'press',
#   'students',
#   'to',
#   'form',
#   'how',
#   'and',
#   'why'],
#  ['build',
#   'a',
#   'sense',
#   'of',
#   'pride',
#   'in',
#   'their',
#   'work',
#   '.',
#   'You',
#   'may',
#   'want',
#   'to',
#   'inform',
#   'students',
#   'that',
#   'professional',
#   'scientists',
#   'collaborate',
#   'with',
#   'one',
#   'another',
#   'to',
#   'brainstorm',
#   ',',
#   'discuss',
#   ',',
#   'and',
#   'review',
#   'their',
#   'work',
#   'also',
#   '.'],
#  ['but',
#   'keep',
#   'in',
#   'mind',
#   'we',
#   'will',
#   'not',
#   'return',
#   'to',
#   'these',
#   'questions',
#   'until',
#   'later',
#   'in',
#   'the',
#   'unit',
#   '(',
#   'Lessons',
#   '8',
#   'and',
#   '15',
#   ')',
#   '.'],
#  ['Classroom',
#   'Artifact',
#   '-D-',
#   'Sample',
#   'driving',
#   'question',
#   'board',
#   'layout',
#   'positioned',
#   'at',
#   'the',
#   'front',
#   'of',
#   'the',
#   'classroom',
#   'for',
#   'two',
#   'sections',
#   '(',
#   'left',
#   'and',
#   'right',
#   'side',
#   ')',
#   '.',
#   'This',
#   'is',
#   'a',
#   'permanent',
#   'board',
#   'but',
#   'could',
#   'also',
#   'be',
#   'placed',
#   'on',
#   'butcher',
#   'paper',
#   'or',
#   'sticky',
#   'sheets',
#   'for',
#   'mobility',
#   'when',
#   'multiple',
#   'class',
#   'sections',
#   'are',
#   'engaging',
#   'with',
#   'the',
#   'unit',
#   '.',
#   '(',
#   'Click',
#   'image',
#   'below',
#   'to',
#   'see',
#   'a',
#   'larger',
#   'version',
#   '.',
#   ')'],
#  ['Develop',
#   'an',
#   'initial',
#   'model',
#   'to',
#   'describe',
#   'the',
#   'phenomena',
#   'and',
#   'mechanisms',
#   'that',
#   'cause',
#   'one',
#   'chicken',
#   'egg',
#   'to',
#   'hatch',
#   'and',
#   'another',
#   'not',
#   'to',
#   'hatch',
#   '(',
#   'effect',
#   ')',
#   ',',
#   'showing',
#   'structures',
#   'and',
#   'mechanisms',
#   ',',
#   'both',
#   'observable',
#   'and',
#   'unobservable',
#   ',',
#   'inside',
#   'the',
#   'egg',
#   '(',
#   'system',
#   ')',
#   'and',
#   'in',
#   'the',
#   'environment',
#   'outside',
#   'the',
#   'egg',
#   '(',
#   'system',
#   ')',
#   '.',
#   'Ask',
#   'questions',
#   'that',
#   'can',
#   'be',
#   'investigated',
#   'in',
#   'the',
#   'scope',
#   'of',
#   'the',
#   'classroom',
#   'that',
#   'arise',
#   'from',
#   'careful',
#   'observation',
#   'of',
#   'phenomena',
#   'and',
#   'gaps',
#   'in',
#   'our',
#   'current',
#   'models',
#   'to',
#   'clarify',
#   'and',
#   'seek',
#   'additional',
#   'information',
#   'about',
#   'structures',
#   'and',
#   'mechanisms',
#   'both',
#   'inside',
#   'and',
#   'around',
#   'organisms',
#   '(',
#   'systems',
#   ')',
#   'that',
#   'cause',
#   'some',
#   'organisms',
#   'to',
#   'grow',
#   'and',
#   'develop',
#   '.'],
#  ['developing',
#   'explanations',
#   '.',
#   'Students',
#   'should',
#   'build',
#   'on',
#   'what',
#   'they',
#   'learned',
#   'about',
#   'systems',
#   'when',
#   'they',
#   'studied',
#   'light',
#   'and',
#   'matter',
#   '.',
#   'Help',
#   'students',
#   'set',
#   'up',
#   'their',
#   'initial',
#   'models',
#   'as',
#   'systems',
#   'models',
#   ',',
#   'identifying',
#   'the',
#   'important',
#   'parts',
#   'of',
#   'each',
#   'system',
#   'and',
#   'how',
#   'those',
#   'parts',
#   'work',
#   'together',
#   'to',
#   'keep',
#   'a',
#   'drink',
#   'cold',
#   '.',
#   'On',
#   'day',
#   '2',
#   'of',
#   'this',
#   'lesson',
#   ',',
#   'students',
#   'will',
#   'think',
#   'about',
#   'what',
#   'is',
#   'happening',
#   'inside',
#   'the',
#   'cup',
#   'systems',
#   'and',
#   'with',
#   'the',
#   'cups',
#   '’',
#   'structural',
#   'parts',
#   'as',
#   'the',
#   'drink',
#   'warms',
#   'up',
#   '.'],
#  ['development',
#   'of',
#   'embryos',
#   '.',
#   'This',
#   'occurs',
#   'in',
#   'Lesson',
#   '4',
#   '.',
#   'A',
#   'simple',
#   'model',
#   'for',
#   'cell',
#   'reproduction',
#   '(',
#   'mitosis',
#   'lite',
#   ')',
#   'is',
#   'developed',
#   'later',
#   'in',
#   'this',
#   'unit',
#   '(',
#   'after',
#   'lesson',
#   '9',
#   ')',
#   'to',
#   'account',
#   'for',
#   'how',
#   'a',
#   'single',
#   'cell',
#   'can',
#   'develop',
#   'into',
#   'many',
#   ',',
#   'forming',
#   'bigger',
#   'and',
#   'bigger',
#   'tissues',
#   'and',
#   'organs',
#   'in',
#   'the',
#   'embryo',
#   'over',
#   'time',
#   '.',
#   'In',
#   'addition',
#   ',',
#   'the',
#   'idea',
#   'that',
#   'when',
#   'cells',
#   'form',
#   'new',
#   'cells',
#   'they',
#   'first',
#   'produce',
#   'additional',
#   'cell',
#   'parts',
#   '.',
#   'This',
#   'is',
#   'a',
#   'simplified',
#   'introduction',
#   'to',
#   'mitosis',
#   '(',
#   'a',
#   'target',
#   'idea',
#   'for',
#   'high',
#   'school',
#   ')',
#   '.',
#   'In',
#   'addition',
#   ',',
#   'the',
#   'idea',
#   'that',
#   'newly-formed',
#   'cells',
#   'can',
#   'form',
#   'new',
#   'shapes',
#   'and',
#   'structures',
#   'is',
#   'introduced',
#   '.',
#   'This',
#   'is',
#   'a',
#   'simplified',
#   'introduction',
#   'to',
#   'the',
#   'idea',
#   'that',
#   'cells',
#   'differentiate',
#   ',',
#   'but',
#   'no',
#   'attempt',
#   'to',
#   'explain',
#   'what',
#   'causes',
#   'the',
#   'differentiation',
#   'or',
#   'how',
#   'it',
#   'is',
#   'done',
#   'in',
#   'this',
#   'unit',
#   '.',
#   'The',
#   'fuller',
#   'exploration',
#   'of',
#   'differentiation',
#   'is',
#   'saved',
#   'for',
#   'high',
#   'school',
#   '.',
#   'The',
#   'unit',
#   'introduces',
#   'the',
# ...
#   '-',
#   'friends',
#   ',',
#   'family',
#   ',',
#   'and',
#   'strangers',
#   ',',
#   'both',
#   'nearby',
#   'and',
#   'far',
#   'away',
#   '-',
#   'have',
#   'also',
#   'been',
#   'affected',
#   'by',
#   'COVID-19',
#   '.',
#   'Students',
#   'will',
#   'build',
#   'a',
#   'timeline',
#   'of',
#   'the',
#   'pandemic',
#   'that',
#   'will',
#   'help',
#   'them',
#   'think',
#   'about',
#   'how',
#   'the',
#   'changes',
#   'in',
#   'their',
#   'lives',
#   'fit',
#   'in',
#   'with',
#   'the',
#   'pandemic',
#   'itself',
#   'and',
#   'important',
#   'social',
#   'events',
#   '.'],
#  ['Figure',
#   'out',
#   'where',
#   'to',
#   'go',
#   'next',
#   ',',
#   'helping',
#   'students',
#   'navigate',
#   'into',
#   'the',
#   'next',
#   'day',
#   '’',
#   's',
#   'ideas'],
#  ['Helpful',
#   'teacher',
#   'notes',
#   'for',
#   'the',
#   'Driving',
#   'Question',
#   'Board',
#   '●',
#   'This',
#   'early',
#   'in',
#   'the',
#   'unit',
#   ',',
#   'it',
#   'is',
#   'important',
#   'to',
#   'make',
#   'sure',
#   'everyone',
#   'has',
#   'a',
#   'chance',
#   'to',
#   'share',
#   '.',
#   'Especially',
#   'if',
#   'students',
#   'are',
#   'not',
#   'used',
#   'to',
#   'having',
#   'a',
#   'lot',
#   'of',
#   'class',
#   'discussions',
#   ',',
#   'this',
#   'is',
#   'an',
#   'easy',
#   'and',
#   'low-risk',
#   'way',
#   'to',
#   'contribute',
#   'to',
#   'the',
#   'intellectual',
#   'work',
#   'of',
#   'the',
#   'class',
#   'while',
#   'building',
#   'a',
#   'classroom',
#   'culture',
#   'in',
#   'which',
#   'all',
#   'students',
#   'feel',
#   'safe',
#   'sharing',
#   'ideas',
#   '.',
#   '●',
#   'If',
#   'a',
#   'student',
#   'question',
#   'is',
#   'not',
#   'easy',
#   'to',
#   'understand',
#   ',',
#   'use',
#   'talk',
#   'moves',
#   'to',
#   'attempt',
#   'to',
#   'clarify',
#   'their',
#   'thinking',
#   ',',
#   'but',
#   'don',
#   '’',
#   't',
#   'just',
#   'summarize',
#   'or',
#   'change',
#   'a',
#   'question',
#   'for',
#   'the',
#   'student',
#   '-',
#   'make',
#   'sure',
#   'their',
#   'ideas',
#   'are',
#   'represented',
#   'authentically',
#   '.',
#   '●',
#   'If',
#   'a',
#   'student',
#   'forgets',
#   'to',
#   'explain',
#   'why',
#   'or',
#   'how',
#   'their',
#   'question',
#   'is',
#   'linked',
#   'to',
#   'someone',
#   'else',
#   '’',
#   's',
#   'question',
#   ',',
#   'press',
#   'that',
#   'student',
#   'to',
#   'try',
#   'to',
#   'talk',
#   'through',
#   'their',
#   'own',
#   'thinking',
#   '.',
#   'This',
#   'is',
#   'a',
#   'key',
#   'way',
#   'to',
#   'emphasize',
#   'the',
#   'importance',
#   'of',
#   'listening',
#   'to',
#   'and',
#   'building',
#   'off',
#   'each',
#   'other',
#   '’',
#   's',
#   'ideas',
#   'and',
#   'to',
#   'help',
#   'scaffold',
#   'student',
#   'thinking',
#   '.',
#   '●',
#   'Don',
#   '’',
#   't',
#   'worry',
#   'if',
#   'some',
#   'questions',
#   'are',
#   'raised',
#   'that',
#   'are',
#   'not',
#   'part',
#   'of',
#   'topics',
#   'in',
#   'this',
#   'unit',
#   '.',
#   'Over',
#   'time',
#   ',',
#   'students',
#   'will',
#   'get',
#   'better',
#   'and',
#   'better',
#   'at',
#   'forming',
#   'testable',
#   'questions',
#   'in',
#   'the',
#   'scope',
#   'of',
#   'the',
#   'driving',
#   'question',
#   '.',
#   'This',
#   'type',
#   'of',
#   'activity',
#   'gives',
#   'them',
#   'practice',
#   'at',
#   'doing',
#   'that',
#   '.',
#   '●',
#   'If',
#   'students',
#   'can',
#   '’',
#   't',
#   'figure',
#   'out',
#   'which',
#   'question',
#   'to',
#   'connect',
#   'theirs',
#   'to',
#   ',',
#   'encourage',
#   'them',
#   'to',
#   'ask',
#   'the',
#   'class',
#   'for',
#   'help',
#   '.',
#   'After',
#   'an',
#   'idea',
#   'is',
#   'shared',
#   ',',
#   'ask',
#   'the',
#   'original',
#   'presenter',
#   'if',
#   'there',
#   'is',
#   'agreement',
#   'and',
#   'why',
#   ',',
#   'and',
#   'then',
#   'post',
#   'the',
#   'question',
#   '.',
#   '●',
#   'If',
#   'a',
#   'question',
#   'is',
#   'similar',
#   'to',
#   '(',
#   'or',
#   'the',
#   'same',
#   'as',
#   ')',
#   'another',
#   'one',
#   ',',
#   'have',
#   'the',
#   'student',
#   'place',
#   'it',
#   'on',
#   'top',
#   'of',
#   'the',
#   'question',
#   'that',
#   'is',
#   'similar',
#   'so',
#   'other',
#   'students',
#   'can',
#   'visually',
#   'see',
#   'how',
#   'many',
#   'of',
#   'the',
#   'questions',
#   'are',
#   'the',
#   'same',
#   'or',
#   'related',
#   '.',
#   'Emphasize',
#   'that',
#   'this',
#   'provides',
#   'us',
#   'with',
#   'evidence',
#   'of',
#   'where',
#   'many',
#   'people',
#   'are',
#   'thinking',
#   'about',
#   'similar',
#   'things',
#   '.'],
#  ['Here',
#   '’',
#   's',
#   'a',
#   'secret',
#   '-',
#   'in',
#   'Lesson',
#   '3',
#   ',',
#   'students',
#   'will',
#   'work',
#   'with',
#   'a',
#   'similar',
#   'timeline',
#   'for',
#   'the',
#   '1918',
#   'influenza',
#   'pandemic',
#   '.',
#   'The',
#   'Lesson',
#   '1',
#   'and',
#   'Lesson',
#   '3',
#   'timelines',
#   'will',
#   'both',
#   'play',
#   'a',
#   'role',
#   'later',
#   'in',
#   'the',
#   'unit',
#   '.'],
#  ['In',
#   'the',
#   'next',
#   'lesson',
#   ',',
#   'you',
#   'will',
#   'begin',
#   'by',
#   'sharing',
#   'with',
#   'students',
#   'a',
#   'few',
#   'of',
#   'their',
#   'comments',
#   'about',
#   'the',
#   'video',
#   'and',
#   'discuss',
#   'a',
#   'general',
#   'phenomenon',
#   'of',
#   'developing',
#   'nations',
#   '’',
#   'success',
#   'relative',
#   'to',
#   'other',
#   'countries',
#   'in',
#   'handling',
#   'the',
#   'COVID-19',
#   'pandemic',
#   '.'],
#  ['In',
#   'the',
#   'unit',
#   'introduction',
#   'and',
#   'pre-writing',
#   ',',
#   'we',
#   'reflected',
#   'on',
#   'the',
#   'impact',
#   'that',
#   'the',
#   'COVID-19',
#   'pandemic',
#   'has',
#   'had',
#   'on',
#   'our',
#   'lives',
#   'and',
#   'the',
#   'lives',
#   'of',
#   'other',
#   'people',
#   '.'],
#  ['MATERIALS',
#   ':',
#   'chart',
#   'paper',
#   'and',
#   'sticky',
#   'notes',
#   '(',
#   'or',
#   'virtual',
#   'replacement',
#   ')'],
#  ['MATERIALS',
#   ':',
#   'chart',
#   'paper',
#   ',',
#   'two',
#   'colors',
#   'of',
#   'sticky',
#   'notes',
#   '(',
#   'or',
#   'virtual',
#   'replacement',
#   ')'],
#  ['MATERIALS',
#   ':',
#   'COVID-19',
#   'Data',
#   'handout',
#   '(',
#   'or',
#   'virtual',
#   'replacement',
#   ')'],
#  ['MATERIALS',
#   ':',
#   'COVID-19',
#   'Timeline',
#   'handout',
#   '(',
#   'or',
#   'virtual',
#   'replacement',
#   ')'],
#  ['MATERIALS',
#   ':',
#   'video',
#   '(',
#   's',
#   ')',
#   ',',
#   'sticky',
#   'notes',
#   'or',
#   'virtual',
#   'replacement'],
#  ['On',
#   'this',
#   'first',
#   'full',
#   'day',
#   'of',
#   'the',
#   'unit',
#   ',',
#   'we',
#   'discuss',
#   'as',
#   'a',
#   'group',
#   'the',
#   'changes',
#   'in',
#   'our',
#   'lives',
#   'and',
#   'the',
#   'lives',
#   'of',
#   'other',
#   'people',
#   '.',
#   'We',
#   'introduce',
#   'the',
#   'basic',
#   'vocabulary',
#   'of',
#   'how',
#   'we',
#   '’',
#   'll',
#   'refer',
#   'to',
#   'COVID-19',
#   'and',
#   'the',
#   'COVID-19',
#   'virus',
#   '.',
#   'We',
#   'analyze',
#   'data',
#   'from',
#   'the',
#   'COVID-19',
#   'pandemic',
#   'around',
#   'the',
#   'world',
#   'and',
#   'then',
#   'develop',
#   'a',
#   'timeline',
#   'of',
#   'what',
#   'has',
#   'happened',
#   'in',
#   'our',
#   'area',
#   ',',
#   'the',
#   'country',
#   ',',
#   'and',
#   'the',
#   'world',
#   'since',
#   'the',
#   'pandemic',
#   'began',
#   '.',
#   'We',
#   'add',
#   'personal',
#   'events',
#   'to',
#   'this',
#   'timeline',
#   'at',
#   'home',
#   '.',
#   'We',
#   'discuss',
#   'our',
#   'timeline',
#   'and',
#   'realize',
#   'one',
#   'of',
#   'the',
#   'most',
#   'important',
#   'events',
#   'is',
#   'missing',
#   ':',
#   'how',
#   'the',
#   'pandemic',
#   'ends',
#   '.',
#   'We',
#   'develop',
#   'a',
#   'Driving',
#   'Question',
#   'Board',
#   'with',
#   'our',
#   'questions',
#   'about',
#   'the',
#   'COVID-19',
#   'pandemic',
#   'and',
#   'how',
#   'it',
#   'will',
#   'end',
#   '.',
#   'Our',
#   'teacher',
#   'points',
#   'out',
#   'that',
#   'this',
#   'is',
#   'not',
#   'the',
#   'first',
#   'pandemic',
#   'that',
#   'has',
#   'ever',
#   'happened',
#   ',',
#   'and',
#   'we',
#   'watch',
#   'a',
#   'video',
#   'about',
#   'success',
#   'in',
#   'addressing',
#   'the',
#   'pandemic',
#   'in',
#   'Africa',
#   'that',
#   'leaves',
#   'us',
#   'with',
#   'thoughts',
#   'and',
#   'questions',
#   'for',
#   'Lesson',
#   '2',
#   '.'],
#  ['Orient',
#   'students',
#   'to',
#   'the',
#   'idea',
#   'of',
#   'making',
#   'a',
#   'timeline',
#   '.'],
#  ['Part',
#   'Duration',
#   'Summary',
#   'Slide',
#   'Materials',
#   '1',
#   '15',
#   'min',
#   'DISCUSSION',
#   '-',
#   'WHAT',
#   'HAS',
#   'CHANGED',
#   'BECAUSE',
#   'OF',
#   'THE',
#   'COVID-19',
#   'PANDEMIC',
#   '?',
#   'Students',
#   'discuss',
#   'the',
#   'changes',
#   'that',
#   'have',
#   'happened',
#   'for',
#   'both',
#   'them',
#   'and',
#   'other',
#   'people',
#   'because',
#   'of',
#   'the',
#   'pandemic',
#   '.',
#   'A-D',
#   'chart',
#   'paper',
#   '(',
#   '2',
#   'pieces',
#   ')',
#   '2',
#   '5',
#   'min',
#   'DEFINING',
#   'VOCABULARY',
#   'We',
#   'define',
#   'vocabulary',
#   'for',
#   'the',
#   'disease',
#   '(',
#   '“',
#   'COVID-19',
#   '”',
#   ')',
#   'and',
#   'the',
#   'virus',
#   'that',
#   'causes',
#   'it',
#   '(',
#   '“',
#   'COVID-19',
#   'virus',
#   '”',
#   ')',
#   '.',
#   'E-F',
#   'physical',
#   'or',
#   'virtual',
#   'space',
#   'and',
#   'materials',
#   'for',
#   'Word',
#   'Wall',
#   '3',
#   '10',
#   'min',
#   'ANALYZING',
#   'DATA',
#   'FROM',
#   'THE',
#   'PANDEMIC',
#   'Students',
#   'briefly',
#   'examine',
#   'and',
#   'discuss',
#   'data',
#   'showing',
#   'how',
#   'COVID-19',
#   'deaths',
#   'and',
#   'vaccinations',
#   'have',
#   'varied',
#   'through',
#   'the',
#   'pandemic',
#   'on',
#   'each',
#   'continent',
#   '.',
#   'G-N',
#   'COVID-19',
#   'Data',
#   'handout',
#   '(',
#   'or',
#   'virtual',
#   'replacement',
#   ')',
#   '4',
#   '15',
#   'min',
#   'DEVELOPING',
#   'A',
#   'TIMELINE',
#   'Students',
#   'select',
#   'different',
#   'events',
#   'since',
#   'COVID-19',
#   'began',
#   'spreading',
#   'and',
#   'add',
#   'to',
#   'a',
#   'timeline',
#   '.',
#   'O-S',
#   'COVID-19',
#   'Timeline',
#   'handout',
#   '(',
#   'or',
#   'virtual',
#   'replacement',
#   ')',
#   'End',
#   'of',
#   'day',
#   '1',
#   '5',
#   '15',
#   'min',
#   'REFLECTING',
#   'ON',
#   'OUR',
#   'TIMELINE',
#   'Students',
#   'collectively',
#   'reflect',
#   'on',
#   'their',
#   'timelines',
#   'and',
#   'begin',
#   'to',
#   'think',
#   'about',
#   'how',
#   'an',
#   'important',
#   'piece',
#   '-',
#   'the',
#   'end',
#   'of',
#   'the',
#   'pandemic',
#   '-',
#   'is',
#   'missing',
#   '.',
#   'T-V',
#   'chart',
#   'paper',
#   '(',
#   '4',
#   'pieces',
#   ')',
#   ',',
#   'two',
#   'colors',
#   'of',
#   'sticky',
#   'notes',
#   '(',
#   'or',
#   'virtual',
#   'replacement',
#   ')',
#   '6',
#   '15',
#   'min',
#   'DRIVING',
#   'QUESTION',
#   'BOARD',
#   'Students',
#   'ask',
#   'questions',
#   'about',
#   'the',
#   'COVID-19',
#   'pandemic',
#   'and',
#   'add',
#   'to',
#   'a',
#   'Driving',
#   'Question',
#   'Board',
#   'that',
#   'will',
#   'help',
#   'determine',
#   'future',
#   'investigations',
#   '.',
#   'W-Y',
#   'chart',
#   'paper',
#   '(',
#   '1',
#   'piece',
#   ')',
#   'and',
#   'sticky',
#   'notes',
#   '(',
#   'or',
#   'virtual',
#   'replacement',
#   ')',
#   '7',
#   '10',
#   'min',
#   'NAVIGATION',
#   'Students',
#   'discuss',
#   'how',
#   'pandemics',
#   'are',
#   'new',
#   'to',
#   'most',
#   'of',
#   'us',
#   ',',
#   'but',
#   'watch',
#   'a',
#   'brief',
#   'video',
#   'that',
#   'shows',
#   'that',
#   'this',
#   'is',
#   'not',
#   'the',
#   'first',
#   'pandemic',
#   'in',
#   'history',
#   '.',
#   'Z-AA',
#   'video',
#   '(',
#   's',
#   ')',
#   ',',
#   'sticky',
#   'notes',
#   '(',
#   'or',
#   'virtual',
#   'replacement',
#   ')',
#   'End',
#   'of',
#   'day',
#   '2Lesson',
#   '1',
#   '•',
#   'Materials',
#   'List',
#   'per',
#   'student',
#   'per',
#   'group',
#   'per',
#   'class',
#   'Lesson',
#   'materials',
#   '●',
#   'COVID-19',
#   'Data',
#   'handout',
#   '●',
#   'COVID-19',
#   'Timeline',
#   'handout',
#   '(',
#   'or',
#   'virtual',
#   'replacement',
#   ')',
#   '●',
#   'at',
#   'least',
#   'four',
#   'sticky',
#   'notes',
#   'each',
#   'of',
#   'two',
#   'different',
#   'colors',
#   '●',
#   'n/a',
#   '●',
#   'chart',
#   'paper',
#   'for',
#   'changes',
#   'and',
#   'norms',
#   '(',
#   '1',
#   'piece',
#   'each',
#   ')',
#   '●',
#   'physical',
#   'or',
#   'virtual',
#   'space',
#   'and',
#   'materials',
#   'for',
#   'Word',
#   'Wall',
#   '●',
#   'chart',
#   'paper',
#   'for',
#   'timeline',
#   '(',
#   '4',
#   'pieces',
#   ')',
#   '●',
#   'chart',
#   'paper',
#   'for',
#   'Driving',
#   'Question',
#   'Board',
#   '(',
#   '1',
#   'piece',
#   ')'],
#  ['Student',
#   'questions',
#   'are',
#   'an',
#   'opportunity',
#   'to',
#   'see',
#   'what',
#   'types',
#   'of',
#   'questions',
#   'students',
#   'are',
#   'asking',
#   'and',
#   'how',
#   'relevant',
#   'they',
#   'are',
#   'to',
#   'our',
#   'driving',
#   'question',
#   ':',
#   'How',
#   'has',
#   'the',
#   'COVID-19',
#   'virus',
#   'impacted',
#   'people',
#   'in',
#   'different',
#   'communities',
#   '?',
#   'Listen',
#   'for',
#   'questions',
#   'that',
#   'are',
#   'open',
#   '(',
#   'how/why',
#   ')',
#   'versus',
#   'closed',
#   '(',
#   'yes/no',
#   ')',
#   '.',
#   'As',
#   'students',
#   'are',
#   'sharing',
#   'questions',
#   ',',
#   'you',
#   'can',
#   'ask',
#   'them',
#   'to',
#   'rephrase',
#   'questions',
#   'into',
#   'a',
#   'how/why',
#   'questions',
#   'if',
#   'they',
#   'have',
#   'experience',
#   'doing',
#   'this',
#   '.',
#   'It',
#   'is',
#   'better',
#   'to',
#   'have',
#   'more',
#   'how',
#   'and',
#   'why',
#   'questions',
#   'on',
#   'the',
#   'Driving',
#   'Question',
#   'Board',
#   ',',
#   'but',
#   'you',
#   'don',
#   '’',
#   't',
#   'need',
#   'all',
#   'questions',
#   'to',
#   'be',
#   'open',
#   'questions',
#   '.'],
#  ['Student',
#   'responses',
#   'will',
#   'vary',
#   ',',
#   'but',
#   'may',
#   'include',
#   'the',
#   'following',
#   '.',
#   'Redirect',
#   'students',
#   'away',
#   'from',
#   'responses',
#   'that',
#   'are',
#   'derogatory',
#   'toward',
#   'people',
#   'in',
#   'other',
#   'places',
#   'or',
#   'that',
#   'assign',
#   'blame',
#   'to',
#   'people',
#   'in',
#   'places',
#   'where',
#   'the',
#   'pandemic',
#   'happens',
#   'to',
#   'be',
#   'bad',
#   'at',
#   'the',
#   'moment',
#   'or',
#   'was',
#   'particularly',
#   'bad',
#   'in',
#   'the',
#   'past',
#   '.'],
#  ['This',
#   'large',
#   'amount',
#   'of',
#   'chart',
#   'paper',
#   'is',
#   'recommended',
#   'so',
#   'students',
#   'have',
#   'a',
#   'good',
#   'deal',
#   'of',
#   'space',
#   'in',
#   'which',
#   'to',
#   'make',
#   'their',
#   'class',
#   'timeline',
#   '.',
#   'There',
#   'is',
#   'a',
#   'virtual',
#   'Google',
#   'slide',
#   'version',
#   'of',
#   'Part',
#   '5',
#   'available',
#   'in',
#   'the',
#   'folder',
#   '.'],
#  ['This',
#   'lesson',
#   'is',
#   'about',
#   'putting',
#   'students',
#   '’',
#   'experiences',
#   'of',
#   'the',
#   'COVID-19',
#   'pandemic',
#   'in',
#   'a',
#   'context',
#   'of',
#   'others',
#   '’',
#   'experiences',
#   'and',
#   'local',
#   ',',
#   'national',
#   ',',
#   'and',
#   'global',
#   'events',
#   ',',
#   'and',
#   'then',
#   'asking',
#   'questions',
#   'about',
#   'where',
#   'the',
#   'pandemic',
#   'is',
#   'going',
#   '.',
#   'Students',
#   'will',
#   'reflect',
#   'on',
#   'what',
#   'has',
#   'happened',
#   'so',
#   'far',
#   'to',
#   'both',
#   'them',
#   'and',
#   'others',
#   '.',
#   'They',
#   'will',
#   'also',
#   'gain',
#   'an',
#   'idea',
#   'of',
#   'how',
#   'these',
#   'experiences',
#   'fit',
#   'into',
#   'a',
#   'broader',
#   'picture',
#   'of',
#   'events',
#   'outside',
#   'their',
#   'control',
#   '-',
#   'both',
#   'pandemic-related',
#   'events',
#   'and',
#   'events',
#   'reflecting',
#   'more',
#   'societal',
#   'changes/norms',
#   '.'],
#  ['We',
#   'will',
#   'examine',
#   'different',
#   'pandemics',
#   'and',
#   'epidemics',
#   'throughout',
#   'history',
#   'to',
#   'determine',
#   'which',
#   'might',
#   'tell',
#   'us',
#   'the',
#   'most',
#   'about',
#   'where',
#   'the',
#   'COVID-19',
#   'pandemic',
#   'is',
#   'going',
#   '.'],
#  ['We',
#   '’',
#   'll',
#   'post',
#   'any',
#   'new',
#   'or',
#   'confusing',
#   'terms',
#   'here',
#   'so',
#   'we',
#   'can',
#   'easily',
#   'remember',
#   'them.✱'],
#  ['You',
#   'may',
#   'wish',
#   'to',
#   'group',
#   'students',
#   '’',
#   'comments',
#   'so',
#   'you',
#   'can',
#   'talk',
#   'about',
#   'groups',
#   'of',
#   'comments',
#   ',',
#   'instead',
#   'of',
#   'specific',
#   'ones',
#   ',',
#   'in',
#   'Lesson',
#   '2',
#   'and',
#   'thereby',
#   'include',
#   'as',
#   'many',
#   'student',
#   'ideas',
#   'as',
#   'possible',
#   '.'],
#  ['You',
#   'may',
#   'wish',
#   'to',
#   'use',
#   'the',
#   'Word',
#   'Wall',
#   'to',
#   'not',
#   'only',
#   'remind',
#   'students',
#   'of',
#   'important',
#   'vocabulary',
#   'from',
#   'the',
#   'unit',
#   ',',
#   'but',
#   'also',
#   'help',
#   'students',
#   'remember',
#   'connections',
#   'between',
#   'big',
#   'ideas',
#   '.',
#   'This',
#   'could',
#   'be',
#   'done',
#   'on',
#   'a',
#   'poster',
#   'by',
#   'drawing',
#   'lines',
#   'between',
#   'words',
#   ',',
#   'in',
#   'a',
#   'digital',
#   'setting',
#   'by',
#   'moving',
#   'words',
#   'around',
#   'into',
#   'groups',
#   'or',
#   'a',
#   'web',
#   ',',
#   'or',
#   'on',
#   'a',
#   'wall',
#   'or',
#   'cork',
#   'board',
#   'by',
#   'using',
#   'string',
#   'to',
#   'connect',
#   'related',
#   'words',
#   '.']]

# %% [markdown]
# # 4. Working with Text Files
# Text files can be used directly and don't need to be converted in order to be imported into NLTK. Many other file types, other than raw text and downloaded corpora, will need to be first initially converted to text files in order to be used in our NLTK data flow

# %% [markdown]
# #5. Merging multiple text files

# %%
import os
import nltk
nltk.download('punkt')

# Specify the source folders containing text files
source_folders = [
    '/content/drive/MyDrive/transcripts/teacher101',
 #   '/content/drive/MyDrive/transcripts/teacher102',
 #   '/content/drive/MyDrive/transcripts/teacher103'
]

# Specify the output folder path
output_folder = '/content/drive/MyDrive/transcripts/'

def merge_text_files(folder_path, output_folder):
    # Initialize an empty string to hold the merged text
    merged_text = ""

    # Iterate through all files in the source folder
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        if os.path.isfile(file_path) and filename.endswith('.txt'):
            with open(file_path, 'r', encoding='utf-8') as file:
                text = file.read()
                merged_text += text + "\n"  # Add text from the file to the merged_text

    # Determine the output file path
    output_path = os.path.join(output_folder, os.path.basename(folder_path) + '_merged.txt')

    # Write the merged text to the output file
    with open(output_path, 'w', encoding='utf-8') as output:
        output.write(merged_text)

if __name__ == '__main__':
    for folder in source_folders:
        merge_text_files(folder, output_folder)
        print(f"All text files from {folder} merged into {output_folder}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# All text files from /content/drive/MyDrive/transcripts/teacher101 merged into /content/drive/MyDrive/transcripts/
# All text files from /content/drive/MyDrive/transcripts/teacher102 merged into /content/drive/MyDrive/transcripts/
# All text files from /content/drive/MyDrive/transcripts/teacher103 merged into /content/drive/MyDrive/transcripts/

# %% [markdown]
# # 6. Loading text file for processing

# %%
# load data from existing text file
filename = '/content/drive/MyDrive/transcripts/merged/teacher101_merged.txt'
textfile = open(filename, 'rt', encoding='utf-8', errors='replace')

text_file = textfile.read()
textfile.close()

# %% [markdown]
# Now the merged texts can be processed using nltk

# %% [markdown]
# #7. View the contents of the variable

# %%
print(type(text_file)) # variable type is string
print(text_file[0:200]) # print first 200 characters of a string
# Out:
# <class 'str'>
# He has like a... I'm one of the chair people. Oh really? Also, are you ready for faces? Swimming faces. He has good facials. Okay, so... Shut up. Never ever say that again. I'm gonna be creepy. He's g

# %% [markdown]
# # 9. Tokenize data corpus

# %%
import nltk
nltk.download('punkt')

text_tokens = text_file

# Word Tokenization
text_wordTokens = nltk.word_tokenize(text_tokens)

# Sentence Tokenization
text_sentTokens = nltk.sent_tokenize(text_tokens)

# Convert the tokens to an nltk.Text object
text_Objects = nltk.Text(text_wordTokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Regex

# %%
# Regular expression tokenizing Gaps =False
pattern = r'\w+'
text_regexTokensWT = nltk.regexp_tokenize(text_tokens, pattern, gaps=True)

#Regex Gaps=True
pattern = r'\w+'
text_regexTokensWF = nltk.regexp_tokenize(text_tokens, pattern, gaps=False)

# Regular expression tokenizing Gaps =False
pattern = r'\s+'
text_regexTokensST = nltk.regexp_tokenize(text_tokens, pattern, gaps=True)

#Regex Gaps=True
pattern = r'\s+'
text_regexTokensSF = nltk.regexp_tokenize(text_tokens, pattern, gaps=False)

print("Length =", len(text_regexTokensWT)," Characters", text_regexTokensWT[0:200])
print("Length =", len(text_regexTokensWF)," Characters", text_regexTokensWF[0:200])
print("Length =", len(text_regexTokensST)," Characters", text_regexTokensST[0:200])
print("Length =", len(text_regexTokensSF)," Characters", text_regexTokensSF[0:200])
# Out:
# Length = 90128  Characters [' ', ' ', ' ', '... ', "'", ' ', ' ', ' ', ' ', ' ', '. ', ' ', '? ', ', ', ' ', ' ', ' ', ' ', '? ', ' ', '. ', ' ', ' ', ' ', '. ', ', ', '... ', ' ', '. ', ' ', ' ', ' ', ' ', '. ', "'", ' ', ' ', ' ', '. ', "'", ' ', ' ', '. ', "'", ' ', ' ', '. ', ' ', ' ', ' ', ' ', '? ', ', ', ', ', ' ', "'", ' ', '. ', ' ', ', ', ' ', ' ', '. ', ' ', "'", ' ', ' ', ', ', ' ', ' ', ' ', '. ', ' ', "'", ' ', ' ', ', ', "'", ' ', ' ', ' ', ' ', ' ', '. ', ' ', "'", ' ', ' ', ', ', "'", ' ', ' ', ' ', ' ', ' ', '. ', ' ', ', ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '. ', ' ', "'", ' ', '. ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '? ', ', ', ' ', '... ', ' ', ' ', ' ', ' ', ' ', ' ', ', ', ' ', "'", ' ', ' ', ' ', ' ', ' ', '. ', ', ', ' ', '. ', '. ', ', ', ' ', ' ', ' ', '? ', ' ', ', ', ', ', '? ', "'", ' ', ' ', ' ', ' ', ' ', '. ', ' ', ' ', ' ', ' ', ' ', ' ', '? ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '. ', ' ', ' ', '. ', ' ', ' ', ' ', ' ', "'", ' ', ' ', ' ', ' ', '. ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '. ', "'", ' ', ', ']
# Length = 90128  Characters ['He', 'has', 'like', 'a', 'I', 'm', 'one', 'of', 'the', 'chair', 'people', 'Oh', 'really', 'Also', 'are', 'you', 'ready', 'for', 'faces', 'Swimming', 'faces', 'He', 'has', 'good', 'facials', 'Okay', 'so', 'Shut', 'up', 'Never', 'ever', 'say', 'that', 'again', 'I', 'm', 'gonna', 'be', 'creepy', 'He', 's', 'gonna', 'die', 'You', 're', 'gonna', 'die', 'Do', 'you', 'have', 'any', 'food', 'Uh', 'yeah', 'but', 'it', 's', 'fine', 'Go', 'away', 'I', 'have', 'coffee', 'I', 'don', 't', 'have', 'cheese', 'but', 'I', 'have', 'coffee', 'If', 'he', 's', 'here', 'today', 'he', 's', 'gonna', 'have', 'a', 'bald', 'head', 'If', 'he', 's', 'here', 'today', 'he', 's', 'gonna', 'have', 'a', 'shaved', 'head', 'Oh', 'yeah', 'he', 'requested', 'permission', 'to', 'wear', 'his', 'hat', 'during', 'a', 'trade', 'this', 'year', 'Maybe', 'he', 's', 'here', 'Oh', 'is', 'that', 'why', 'everyone', 'shaved', 'their', 'heads', 'Yeah', 'swimming', 'or', 'I', 'thought', 'it', 'was', 'cancer', 'or', 'something', 'because', 'that', 's', 'what', 'he', 'said', 'last', 'week', 'Yeah', 'I', 'know', 'Wow', 'Oh', 'is', 'this', 'for', 'Drake', 'I', 'mean', 'uh', 'Precoc', 'I', 'm', 'gonna', 'go', 'reach', 'for', 'presents', 'Can', 'I', 'seriously', 'do', 'it', 'next', 'time', 'Cause', 'seriously', 'I', 'did', 'really', 'bad', 'on', 'this', 'one', 'So', 'did', 'I', 'No', 'seriously', 'I', 'promise', 'I', 'll', 'do', 'it', 'next', 'time', 'We', 'all', 'did', 'really', 'bad', 'on', 'this', 'one', 'I', 'm', '24']
# Length = 85538  Characters ['He', 'has', 'like', 'a...', "I'm", 'one', 'of', 'the', 'chair', 'people.', 'Oh', 'really?', 'Also,', 'are', 'you', 'ready', 'for', 'faces?', 'Swimming', 'faces.', 'He', 'has', 'good', 'facials.', 'Okay,', 'so...', 'Shut', 'up.', 'Never', 'ever', 'say', 'that', 'again.', "I'm", 'gonna', 'be', 'creepy.', "He's", 'gonna', 'die.', "You're", 'gonna', 'die.', 'Do', 'you', 'have', 'any', 'food?', 'Uh,', 'yeah,', 'but', "it's", 'fine.', 'Go', 'away,', 'I', 'have', 'coffee.', 'I', "don't", 'have', 'cheese,', 'but', 'I', 'have', 'coffee.', 'If', "he's", 'here', 'today,', "he's", 'gonna', 'have', 'a', 'bald', 'head.', 'If', "he's", 'here', 'today,', "he's", 'gonna', 'have', 'a', 'shaved', 'head.', 'Oh', 'yeah,', 'he', 'requested', 'permission', 'to', 'wear', 'his', 'hat', 'during', 'a', 'trade', 'this', 'year.', 'Maybe', "he's", 'here.', 'Oh', 'is', 'that', 'why', 'everyone', 'shaved', 'their', 'heads?', 'Yeah,', 'swimming', 'or...', 'I', 'thought', 'it', 'was', 'cancer', 'or', 'something,', 'because', "that's", 'what', 'he', 'said', 'last', 'week.', 'Yeah,', 'I', 'know.', 'Wow.', 'Oh,', 'is', 'this', 'for', 'Drake?', 'I', 'mean,', 'uh,', 'Precoc?', "I'm", 'gonna', 'go', 'reach', 'for', 'presents.', 'Can', 'I', 'seriously', 'do', 'it', 'next', 'time?', 'Cause', 'seriously', 'I', 'did', 'really', 'bad', 'on', 'this', 'one.', 'So', 'did', 'I.', 'No', 'seriously', 'I', 'promise', "I'll", 'do', 'it', 'next', 'time.', 'We', 'all', 'did', 'really', 'bad', 'on', 'this', 'one.', "I'm", '24,', 'I', "don't", 'really', 'care.', 'Are', 'we', 'eight', 'or', 'five?', 'Are', 'we', 'eight', 'or', 'five?', 'No,']
# Length = 85538  Characters [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %% [markdown]
# # 10. Examples of different types of regex tokenizers

# %%
# Word Tokens
pattern1 = r'\w+'
text_regexTokens1 = nltk.regexp_tokenize(text_tokens, pattern1)

#Non-Word Tokens
pattern2 = r'\W+'
text_regexTokens2 = nltk.regexp_tokenize(text_tokens, pattern2)

#Words with capital letters
pattern3 = r'[A-Z]\w+'
text_regexTokens3 = nltk.regexp_tokenize(text_tokens, pattern3)

#Sentences
pattern4 = r'[A-Z][^.!?]*[.!?]'
text_regexTokens4 = nltk.regexp_tokenize(text_tokens, pattern4)

#Email Addresses
pattern5 = r'\S+@\S+'
text_regexTokens = nltk.regexp_tokenize(text_tokens, pattern5)

#Digits
pattern6 = r'\d+'
text_regexTokens6 = nltk.regexp_tokenize(text_tokens, pattern6)

#URLs
pattern7 = r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
text_regexTokens7 = nltk.regexp_tokenize(text_tokens, pattern7)

#Custom Patterns - Abbreviations with following period
pattern8 = r'\b[A-Za-z]\.(\s)?'
text_regexTokens8 = nltk.regexp_tokenize(text_tokens, pattern8)


#Words with hyphens non-violent
pattern9 = r'\w+(?:-\w+)*'
text_regexTokens9 = nltk.regexp_tokenize(text_tokens, pattern9)


#Contractions (can't, won't)
pattern10 = r'\b\w+\'\w+\b'
text_regexTokens10 = nltk.regexp_tokenize(text_tokens, pattern10)

#Hashtags
pattern11 = r'#\w+'
text_regexTokens11 = nltk.regexp_tokenize(text_tokens, pattern11)


#Custom Pattern- Parenthesized expressions
pattern12 = r'\(.*?\)'
text_regexTokens12 = nltk.regexp_tokenize(text_tokens, pattern12)

#Custom Pattern - Phone number
pattern13 = r'\d{3}-\d{3}-\d{4}'
text_regexTokens13 = nltk.regexp_tokenize(text_tokens, pattern13)

# %% [markdown]
# 10. Importance of checking the type of variable you are working with. If not it can be very confusing.

# %%
#What types of variables are these
print(type(text_file))
print(type(text_tokens))
print(type(text_wordTokens))
print(type(text_sentTokens))
print(type(text_regexTokensT))
print(type(text_regexTokensF))
print(type(text_Objects))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'nltk.text.Text'>

# %%
print(len(text_file))
print(len(text_tokens))
print(len(text_wordTokens))
print(len(text_sentTokens))
print(len(text_regexTokens))
print(len(text_Objects))

# %% [markdown]
# 11. Examples of each variables listed

# %%
print(text_file[0:200])

print(text_tokens[0:200])
print(text_wordTokens[0:200])

print(text_sentTokens[0:200])
print(text_regexTokensT[0:200])
print(text_regexTokensF[0:200])
print(text_Objects[0:200])
# Out:
# He has like a... I'm one of the chair people. Oh really? Also, are you ready for faces? Swimming faces. He has good facials. Okay, so... Shut up. Never ever say that again. I'm gonna be creepy. He's g
# He has like a... I'm one of the chair people. Oh really? Also, are you ready for faces? Swimming faces. He has good facials. Okay, so... Shut up. Never ever say that again. I'm gonna be creepy. He's g
# ['He', 'has', 'like', 'a', '...', 'I', "'m", 'one', 'of', 'the', 'chair', 'people', '.', 'Oh', 'really', '?', 'Also', ',', 'are', 'you', 'ready', 'for', 'faces', '?', 'Swimming', 'faces', '.', 'He', 'has', 'good', 'facials', '.', 'Okay', ',', 'so', '...', 'Shut', 'up', '.', 'Never', 'ever', 'say', 'that', 'again', '.', 'I', "'m", 'gon', 'na', 'be', 'creepy', '.', 'He', "'s", 'gon', 'na', 'die', '.', 'You', "'re", 'gon', 'na', 'die', '.', 'Do', 'you', 'have', 'any', 'food', '?', 'Uh', ',', 'yeah', ',', 'but', 'it', "'s", 'fine', '.', 'Go', 'away', ',', 'I', 'have', 'coffee', '.', 'I', 'do', "n't", 'have', 'cheese', ',', 'but', 'I', 'have', 'coffee', '.', 'If', 'he', "'s", 'here', 'today', ',', 'he', "'s", 'gon', 'na', 'have', 'a', 'bald', 'head', '.', 'If', 'he', "'s", 'here', 'today', ',', 'he', "'s", 'gon', 'na', 'have', 'a', 'shaved', 'head', '.', 'Oh', 'yeah', ',', 'he', 'requested', 'permission', 'to', 'wear', 'his', 'hat', 'during', 'a', 'trade', 'this', 'year', '.', 'Maybe', 'he', "'s", 'here', '.', 'Oh', 'is', 'that', 'why', 'everyone', 'shaved', 'their', 'heads', '?', 'Yeah', ',', 'swimming', 'or', '...', 'I', 'thought', 'it', 'was', 'cancer', 'or', 'something', ',', 'because', 'that', "'s", 'what', 'he', 'said', 'last', 'week', '.', 'Yeah', ',', 'I', 'know', '.', 'Wow', '.', 'Oh', ',', 'is', 'this', 'for', 'Drake', '?', 'I', 'mean', ',', 'uh', ',', 'Precoc', '?']
# ['He has like a...', "I'm one of the chair people.", 'Oh really?', 'Also, are you ready for faces?', 'Swimming faces.', 'He has good facials.', 'Okay, so...', 'Shut up.', 'Never ever say that again.', "I'm gonna be creepy.", "He's gonna die.", "You're gonna die.", 'Do you have any food?', "Uh, yeah, but it's fine.", 'Go away, I have coffee.', "I don't have cheese, but I have coffee.", "If he's here today, he's gonna have a bald head.", "If he's here today, he's gonna have a shaved head.", 'Oh yeah, he requested permission to wear his hat during a trade this year.', "Maybe he's here.", 'Oh is that why everyone shaved their heads?', 'Yeah, swimming or...', "I thought it was cancer or something, because that's what he said last week.", 'Yeah, I know.', 'Wow.', 'Oh, is this for Drake?', 'I mean, uh, Precoc?', "I'm gonna go reach for presents.", 'Can I seriously do it next time?', 'Cause seriously I did really bad on this one.', 'So did I.', "No seriously I promise I'll do it next time.", 'We all did really bad on this one.', "I'm 24, I don't really care.", 'Are we eight or five?', 'Are we eight or five?', "No, we're eight.", 'Are you sure?', "We're going to take it in the back.", "It's easy, it's really easy.", 'Nah, seriously.', 'Nah, seriously.', "I'll do it on Thursday, seriously.", "I don't want to do it.", 'Not today, please.', 'It was really easy.', 'Just put our number up there.', 'Just put our number.', '24 number 1.', "I'm okay.", '24 number 1.', 'You get 10,500, 25,2105, 423,070, and 15,000 times 0.72.', "I did it wrong, I'm pretty sure.", "Instead of doing 10.7, I did divide it by 1.3, which doesn't make sense now that I think about it.", 'So yeah, I was wrong.', 'Yeah, I got it wrong, man.', 'Hold on.', "I'm going to go ahead and get some more.", 'Wait.', "Now don't pan.", "Nobody's panning.", 'I should have run by Italy.', "I can't seem to find this class of Hennigans.", "I don't know where that one is.", 'What are you following?', 'So the chance to actually... Make sure you get all your stuff out.', 'Yeah.', 'Yeah, and you had to act as somebody, right?', 'Alright, um, where was that list?', "Let's see here.", 'Thank you.', 'Look at this.', 'Nothing too special, just a very quick lap.', 'This is good.', "So really what I meant by that is let's label the x-axis.", 'The y-axis does not need to be labeled.', "You can if you want, but it's not important.", "And I think we'll do the x as soon as this comes out.", "Okay, so let's do this.", 'Negative 2, negative 5, and negative 7.', 'Okay, so you can work on this together, for sure.', 'By mathematical notation, what I mean is, I think I want you to do it with an equality.', "They don't want to leave him.", 'This one has x to equal.', "Look at that, they're in the calculus folder.", 'They are not graded.', 'Why, you want to grade them or you operate them?', 'He really needs to get a GoPro.', 'He really needs to get a GoPro.', 'So it looks to me like we might need a little recursion on how to write these inequalities.', "Tell you what, as the inequality, oh, there's a typo if you didn't see it.", 'One of those should be positive, right?', 'Someone with an A can be noble.', 'I mean, it makes sense.', "So maybe I'll take you through this.", 'When f prime is, you know what?', 'Before we do this, can somebody come and mark up the graph and show us visually?', 'Come on up and show us.', 'Yeah, where is the positive and negative squared?', 'It.', "says it's okay to not be perfect.", 'What do you think?', "We'll do it again?", "Now that we see it, I'm pretty sure you all on your papers, some of us use pluses and minuses, I like that, it's good too, just has to be very clear what's going on.", 'Now that we see it, for the derivative greater than zero, what values of x correspond with that?', 'Mackenzie?', 'X is greater than negative 6 and less than negative 3.5.', "That's what you have.", 'And so in between those two numbers is where the derivative is positive.', 'Do you concur?', ' ...
# [' ', ' ', ' ', '... ', "'", ' ', ' ', ' ', ' ', ' ', '. ', ' ', '? ', ', ', ' ', ' ', ' ', ' ', '? ', ' ', '. ', ' ', ' ', ' ', '. ', ', ', '... ', ' ', '. ', ' ', ' ', ' ', ' ', '. ', "'", ' ', ' ', ' ', '. ', "'", ' ', ' ', '. ', "'", ' ', ' ', '. ', ' ', ' ', ' ', ' ', '? ', ', ', ', ', ' ', "'", ' ', '. ', ' ', ', ', ' ', ' ', '. ', ' ', "'", ' ', ' ', ', ', ' ', ' ', ' ', '. ', ' ', "'", ' ', ' ', ', ', "'", ' ', ' ', ' ', ' ', ' ', '. ', ' ', "'", ' ', ' ', ', ', "'", ' ', ' ', ' ', ' ', ' ', '. ', ' ', ', ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '. ', ' ', "'", ' ', '. ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '? ', ', ', ' ', '... ', ' ', ' ', ' ', ' ', ' ', ' ', ', ', ' ', "'", ' ', ' ', ' ', ' ', ' ', '. ', ', ', ' ', '. ', '. ', ', ', ' ', ' ', ' ', '? ', ' ', ', ', ', ', '? ', "'", ' ', ' ', ' ', ' ', ' ', '. ', ' ', ' ', ' ', ' ', ' ', ' ', '? ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '. ', ' ', ' ', '. ', ' ', ' ', ' ', ' ', "'", ' ', ' ', ' ', ' ', '. ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '. ', "'", ' ', ', ']
# ['He', 'has', 'like', 'a', 'I', 'm', 'one', 'of', 'the', 'chair', 'people', 'Oh', 'really', 'Also', 'are', 'you', 'ready', 'for', 'faces', 'Swimming', 'faces', 'He', 'has', 'good', 'facials', 'Okay', 'so', 'Shut', 'up', 'Never', 'ever', 'say', 'that', 'again', 'I', 'm', 'gonna', 'be', 'creepy', 'He', 's', 'gonna', 'die', 'You', 're', 'gonna', 'die', 'Do', 'you', 'have', 'any', 'food', 'Uh', 'yeah', 'but', 'it', 's', 'fine', 'Go', 'away', 'I', 'have', 'coffee', 'I', 'don', 't', 'have', 'cheese', 'but', 'I', 'have', 'coffee', 'If', 'he', 's', 'here', 'today', 'he', 's', 'gonna', 'have', 'a', 'bald', 'head', 'If', 'he', 's', 'here', 'today', 'he', 's', 'gonna', 'have', 'a', 'shaved', 'head', 'Oh', 'yeah', 'he', 'requested', 'permission', 'to', 'wear', 'his', 'hat', 'during', 'a', 'trade', 'this', 'year', 'Maybe', 'he', 's', 'here', 'Oh', 'is', 'that', 'why', 'everyone', 'shaved', 'their', 'heads', 'Yeah', 'swimming', 'or', 'I', 'thought', 'it', 'was', 'cancer', 'or', 'something', 'because', 'that', 's', 'what', 'he', 'said', 'last', 'week', 'Yeah', 'I', 'know', 'Wow', 'Oh', 'is', 'this', 'for', 'Drake', 'I', 'mean', 'uh', 'Precoc', 'I', 'm', 'gonna', 'go', 'reach', 'for', 'presents', 'Can', 'I', 'seriously', 'do', 'it', 'next', 'time', 'Cause', 'seriously', 'I', 'did', 'really', 'bad', 'on', 'this', 'one', 'So', 'did', 'I', 'No', 'seriously', 'I', 'promise', 'I', 'll', 'do', 'it', 'next', 'time', 'We', 'all', 'did', 'really', 'bad', 'on', 'this', 'one', 'I', 'm', '24']
# ['He', 'has', 'like', 'a', '...', 'I', "'m", 'one', 'of', 'the', 'chair', 'people', '.', 'Oh', 'really', '?', 'Also', ',', 'are', 'you', 'ready', 'for', 'faces', '?', 'Swimming', 'faces', '.', 'He', 'has', 'good', 'facials', '.', 'Okay', ',', 'so', '...', 'Shut', 'up', '.', 'Never', 'ever', 'say', 'that', 'again', '.', 'I', "'m", 'gon', 'na', 'be', 'creepy', '.', 'He', "'s", 'gon', 'na', 'die', '.', 'You', "'re", 'gon', 'na', 'die', '.', 'Do', 'you', 'have', 'any', 'food', '?', 'Uh', ',', 'yeah', ',', 'but', 'it', "'s", 'fine', '.', 'Go', 'away', ',', 'I', 'have', 'coffee', '.', 'I', 'do', "n't", 'have', 'cheese', ',', 'but', 'I', 'have', 'coffee', '.', 'If', 'he', "'s", 'here', 'today', ',', 'he', "'s", 'gon', 'na', 'have', 'a', 'bald', 'head', '.', 'If', 'he', "'s", 'here', 'today', ',', 'he', "'s", 'gon', 'na', 'have', 'a', 'shaved', 'head', '.', 'Oh', 'yeah', ',', 'he', 'requested', 'permission', 'to', 'wear', 'his', 'hat', 'during', 'a', 'trade', 'this', 'year', '.', 'Maybe', 'he', "'s", 'here', '.', 'Oh', 'is', 'that', 'why', 'everyone', 'shaved', 'their', 'heads', '?', 'Yeah', ',', 'swimming', 'or', '...', 'I', 'thought', 'it', 'was', 'cancer', 'or', 'something', ',', 'because', 'that', "'s", 'what', 'he', 'said', 'last', 'week', '.', 'Yeah', ',', 'I', 'know', '.', 'Wow', '.', 'Oh', ',', 'is', 'this', 'for', 'Drake', '?', 'I', 'mean', ',', 'uh', ',', 'Precoc', '?']

# %%
sorted(set(text_file[0:50]))
len(text_file)
sorted(set(text_wordTokens[0:50]))
sorted(set(text_sentTokens[0:50]))
sorted(set(text_Objects[0:50]))

# %% [markdown]
# Extract only nouns

# %%
text_regexTokensST_only_nn = [x for (x,y) in pos if y in ('NN')]

freq = nltk.FreqDist(text_regexTokensST_only_nn)
freq
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-e8e1427ec387> in <cell line: 1>()
# ----> 1 text_regexTokensST_only_nn = [x for (x,y) in pos if y in ('NN')]
#       2
#       3 freq = nltk.FreqDist(text_regexTokensST_only_nn)
#       4 freq
#
# NameError: name 'pos' is not defined

# %%
text_regexTokensST
# Out:
# ['He',
#  'has',
#  'like',
#  'a...',
#  "I'm",
#  'one',
#  'of',
#  'the',
#  'chair',
#  'people.',
#  'Oh',
#  'really?',
#  'Also,',
#  'are',
#  'you',
#  'ready',
#  'for',
#  'faces?',
#  'Swimming',
#  'faces.',
#  'He',
#  'has',
#  'good',
#  'facials.',
#  'Okay,',
#  'so...',
#  'Shut',
#  'up.',
#  'Never',
#  'ever',
#  'say',
#  'that',
#  'again.',
#  "I'm",
#  'gonna',
#  'be',
#  'creepy.',
#  "He's",
#  'gonna',
#  'die.',
#  "You're",
#  'gonna',
#  'die.',
#  'Do',
#  'you',
#  'have',
#  'any',
#  'food?',
#  'Uh,',
#  'yeah,',
#  'but',
#  "it's",
#  'fine.',
#  'Go',
#  'away,',
#  'I',
#  'have',
#  'coffee.',
#  'I',
#  "don't",
#  'have',
#  'cheese,',
#  'but',
#  'I',
#  'have',
#  'coffee.',
#  'If',
#  "he's",
#  'here',
#  'today,',
#  "he's",
#  'gonna',
#  'have',
#  'a',
#  'bald',
#  'head.',
#  'If',
#  "he's",
#  'here',
#  'today,',
#  "he's",
#  'gonna',
#  'have',
#  'a',
#  'shaved',
#  'head.',
#  'Oh',
#  'yeah,',
#  'he',
#  'requested',
#  'permission',
#  'to',
#  'wear',
#  'his',
#  'hat',
#  'during',
#  'a',
#  'trade',
#  'this',
#  'year.',
#  'Maybe',
#  "he's",
#  'here.',
#  'Oh',
#  'is',
#  'that',
#  'why',
#  'everyone',
#  'shaved',
#  'their',
#  'heads?',
#  'Yeah,',
#  'swimming',
#  'or...',
#  'I',
#  'thought',
#  'it',
#  'was',
#  'cancer',
#  'or',
#  'something,',
#  'because',
#  "that's",
#  'what',
#  'he',
#  'said',
#  'last',
#  'week.',
#  'Yeah,',
#  'I',
#  'know.',
#  'Wow.',
#  'Oh,',
#  'is',
#  'this',
#  'for',
#  'Drake?',
#  'I',
#  'mean,',
#  'uh,',
#  'Precoc?',
#  "I'm",
#  'gonna',
#  'go',
#  'reach',
#  'for',
#  'presents.',
#  'Can',
#  'I',
#  'seriously',
#  'do',
#  'it',
#  'next',
#  'time?',
#  'Cause',
#  'seriously',
#  'I',
#  'did',
#  'really',
#  'bad',
#  'on',
#  'this',
#  'one.',
#  'So',
#  'did',
#  'I.',
#  'No',
#  'seriously',
#  'I',
#  'promise',
#  "I'll",
#  'do',
#  'it',
#  'next',
#  'time.',
#  'We',
#  'all',
#  'did',
#  'really',
#  'bad',
#  'on',
#  'this',
#  'one.',
#  "I'm",
#  '24,',
#  'I',
#  "don't",
#  'really',
#  'care.',
#  'Are',
#  'we',
#  'eight',
#  'or',
#  'five?',
#  'Are',
#  'we',
#  'eight',
#  'or',
#  'five?',
#  'No,',
#  "we're",
#  'eight.',
#  'Are',
#  'you',
#  'sure?',
#  "We're",
#  'going',
#  'to',
#  'take',
#  'it',
#  'in',
#  'the',
#  'back.',
#  "It's",
#  'easy,',
#  "it's",
#  'really',
#  'easy.',
#  'Nah,',
#  'seriously.',
#  'Nah,',
#  'seriously.',
#  "I'll",
#  'do',
#  'it',
#  'on',
#  'Thursday,',
#  'seriously.',
#  'I',
#  "don't",
#  'want',
#  'to',
#  'do',
#  'it.',
#  'Not',
#  'today,',
#  'please.',
#  'It',
#  'was',
#  'really',
#  'easy.',
#  'Just',
#  'put',
#  'our',
#  'number',
#  'up',
#  'there.',
#  'Just',
#  'put',
#  'our',
#  'number.',
#  '24',
#  'number',
#  '1.',
#  "I'm",
#  'okay.',
#  '24',
#  'number',
#  '1.',
#  'You',
#  'get',
#  '10,500,',
#  '25,2105,',
#  '423,070,',
#  'and',
#  '15,000',
#  'times',
#  '0.72.',
#  'I',
#  'did',
#  'it',
#  'wrong,',
#  "I'm",
#  'pretty',
#  'sure.',
#  'Instead',
#  'of',
#  'doing',
#  '10.7,',
#  'I',
#  'did',
#  'divide',
#  'it',
#  'by',
#  '1.3,',
#  'which',
#  "doesn't",
#  'make',
#  'sense',
#  'now',
#  'that',
#  'I',
#  'think',
#  'about',
#  'it.',
#  'So',
#  'yeah,',
#  'I',
#  'was',
#  'wrong.',
#  'Yeah,',
#  'I',
#  'got',
#  'it',
#  'wrong,',
#  'man.',
#  'Hold',
#  'on.',
#  "I'm",
#  'going',
#  'to',
#  'go',
#  'ahead',
#  'and',
#  'get',
#  'some',
#  'more.',
#  'Wait.',
#  'Now',
#  "don't",
#  'pan.',
#  "Nobody's",
#  'panning.',
#  'I',
#  'should',
#  'have',
#  'run',
#  'by',
#  'Italy.',
#  'I',
#  "can't",
#  'seem',
#  'to',
#  'find',
#  'this',
#  'class',
#  'of',
#  'Hennigans.',
#  'I',
#  "don't",
#  'know',
#  'where',
#  'that',
#  'one',
#  'is.',
#  'What',
#  'are',
#  'you',
#  'following?',
#  'So',
#  'the',
#  'chance',
#  'to',
#  'actually...',
#  'Make',
#  'sure',
#  'you',
#  'get',
#  'all',
#  'your',
#  'stuff',
#  'out.',
#  'Yeah.',
#  'Yeah,',
#  'and',
#  'you',
#  'had',
#  'to',
#  'act',
#  'as',
#  'somebody,',
#  'right?',
#  'Alright,',
#  'um,',
#  'where',
#  'was',
#  'that',
#  'list?',
#  "Let's",
#  'see',
#  'here.',
#  'Thank',
#  'you.',
#  'Look',
#  'at',
#  'this.',
#  'Nothing',
#  'too',
#  'special,',
#  'just',
#  'a',
#  'very',
#  'quick',
#  'lap.',
#  'This',
#  'is',
#  'good.',
#  'So',
#  'really',
#  'what',
#  'I',
#  'meant',
#  'by',
#  'that',
#  'is',
#  "let's",
#  'label',
#  'the',
#  'x-axis.',
#  'The',
#  'y-axis',
#  'does',
#  'not',
#  'need',
#  'to',
#  'be',
#  'labeled.',
#  'You',
#  'can',
#  'if',
#  'you',
#  'want,',
#  'but',
#  "it's",
#  'not',
#  'important.',
#  'And',
#  'I',
#  'think',
#  "we'll",
#  'do',
#  'the',
#  'x',
#  'as',
#  'soon',
#  'as',
#  'this',
#  'comes',
#  'out.',
#  'Okay,',
#  'so',
#  "let's",
#  'do',
#  'this.',
#  'Negative',
#  '2,',
#  'negative',
#  '5,',
#  'and',
#  'negative',
#  '7.',
#  'Okay,',
#  'so',
#  'you',
#  'can',
#  'work',
#  'on',
#  'this',
#  'together,',
#  'for',
#  'sure.',
#  'By',
#  'mathematical',
#  'notation,',
#  'what',
#  'I',
#  'mean',
#  'is,',
#  'I',
#  'think',
#  'I',
#  'want',
#  'you',
#  'to',
#  'do',
#  'it',
#  'with',
#  'an',
#  'equality.',
#  'They',
#  "don't",
#  'want',
#  'to',
#  'leave',
#  'him.',
#  'This',
#  'one',
#  'has',
#  'x',
#  'to',
#  'equal.',
#  'Look',
#  'at',
#  'that,',
#  "they're",
#  'in',
#  'the',
#  'calculus',
#  'folder.',
#  'They',
#  'are',
#  'not',
#  'graded.',
#  'Why,',
#  'you',
#  'want',
#  'to',
#  'grade',
#  'them',
#  'or',
#  'you',
#  'operate',
#  'them?',
#  'He',
#  'really',
#  'needs',
#  'to',
#  'get',
#  'a',
#  'GoPro.',
#  'He',
#  'really',
#  'needs',
#  'to',
#  'get',
#  'a',
#  'GoPro.',
#  'So',
#  'it',
#  'looks',
#  'to',
#  'me',
#  'like',
#  'we',
#  'might',
#  'need',
#  'a',
#  'little',
#  'recursion',
#  'on',
#  'how',
#  'to',
#  'write',
#  'these',
#  'inequalities.',
#  'Tell',
#  'you',
#  'what,',
#  'as',
#  'the',
#  'inequality,',
#  'oh,',
#  "there's",
#  'a',
#  'typo',
#  'if',
#  'you',
#  "didn't",
#  'see',
#  'it.',
#  'One',
#  'of',
#  'those',
#  'should',
#  'be',
#  'positive,',
#  'right?',
#  'Someone',
#  'with',
#  'an',
#  'A',
#  'can',
#  'be',
#  'noble.',
#  'I',
#  'mean,',
#  'it',
#  'makes',
#  'sense.',
#  'So',
#  'maybe',
#  "I'll",
#  'take',
#  'you',
#  'through',
#  'this.',
#  'When',
#  'f',
#  'prime',
#  'is,',
#  'you',
#  'know',
#  'what?',
#  'Before',
#  'we',
#  'do',
#  'this,',
#  'can',
#  'somebody',
#  'come',
#  'and',
#  'mark',
#  'up',
#  'the',
#  'graph',
#  'and',
#  'show',
#  'us',
#  'visually?',
#  'Come',
#  'on',
#  'up',
#  'and',
#  'show',
#  'us.',
#  'Yeah,',
#  'where',
#  'is',
#  'the',
#  'positive',
#  'and',
#  'negative',
#  'squared?',
#  'It.',
#  'says',
#  "it's",
#  'okay',
#  'to',
#  'not',
#  'be',
#  'perfect.',
#  'What',
#  'do',
#  'you',
#  'think?',
#  "We'll",
#  'do',
#  'it',
#  'again?',
#  'Now',
#  'that',
#  'we',
#  'see',
#  'it,',
#  "I'm",
#  'pretty',
#  'sure',
#  'you',
#  'all',
#  'on',
#  'your',
#  'papers,',
#  'some',
#  'of',
#  'us',
#  'use',
#  'pluses',
#  'and',
#  'minuses,',
#  'I',
#  'like',
#  'that,',
#  "it's",
#  'good',
#  'too,',
#  'just',
#  'has',
#  'to',
#  'be',
#  'very',
#  'clear',
#  "what's",
#  'going',
#  'on.',
#  'Now',
#  'that',
#  'we',
#  'see',
#  'it,',
#  'for',
#  'the',
#  'derivative',
#  'greater',
#  'than',
#  'zero,',
#  'what',
#  'values',
#  'of',
#  'x',
#  'correspond',
#  'with',
#  'that?',
#  'Mackenzie?',
#  'X',
#  'is',
#  'greater',
#  'than',
#  'negative',
#  '6',
#  'and',
#  'less',
#  'than',
#  'negative',
#  '3.5.',
#  "That's",
#  'what',
#  'you',
#  'have.',
#  'And',
#  'so',
#  'in',
#  'between',
#  'those',
#  'two',
#  'numbers',
#  'is',
#  'where',
#  'the',
#  'derivative',
#  'is',
#  'positive.',
#  'Do',
#  'you',
#  'concur?',
#  'So',
#  'how',
#  'do',
#  'we',
#  'write',
#  'that?',
#  'In',
#  'other',
#  'words,',
#  'x',
#  'is',
#  'in',
#  'between',
#  'negative',
#  '6',
#  'and',
#  '3.5.',
#  'The',
#  'lower',
#  'number',
#  'goes',
#  'to',
#  'the',
#  'left,',
#  'like',
#  "you're",
#  'reading,',
#  'left',
#  'to',
#  'right,',
#  'the',
#  'higher',
#  'number',
#  'goes',
#  'to',
#  'the',
#  'right,',
#  'and',
#  'you',
#  'put',
#  'x',
#  'in',
#  'between',
#  'there.',
#  'And...',
#  'What',
#  'else?',
#  'Gina?',
#  'You',
#  'labeled',
#  'this',
#  '1.5?',
#  'Ok.',
#  'Fair',
#  'enough.',
#  'And,',
#  "that's",
#  'greater',
#  'than',
#  '1.5.',
#  'Does',
#  'that',
#  'help',
#  'model',
#  'how',
#  'you',
#  'should',
#  'fill',
#  'this',
#  'out?',
#  'Ok,',
#  "let's",
#  'finish',
#  'the',
#  'first',
#  'half',
#  'at',
#  'least.',
#  'Get',
#  'our',
#  'explanations',
#  'down.',
#  'Ah,',
#  'darn.',
#  'Make',
#  'sure',
#  "we're",
#  'comparing',
#  'our',
#  'answers,',
#  'please.',
#  'Okay,',
#  'can',
#  'somebody',
#  'please',
#  'come',
#  'up',
#  'here',
#  'and',
#  'finish',
#  'these',
#  'statements?',
#  'Do',
#  'one',
#  'person',
#  'do',
#  'one',
#  'and',
#  'another',
#  'do',
#  'another.',
#  'Join',
#  'up',
#  'there.',
#  'Oh,',
#  'there',
#  'were',
#  'scissors.',
#  'established',
#  'around',
#  'books.',
#  'Thank',
#  'you,',
#  'thank',
#  'you,',
#  'Destiny.',
#  'Well,',
#  "it's",
#  'yet',
#  'another',
#  'case',
#  'where',
#  'all',
#  'men',
#  'sit',
#  'and',
#  'discuss',
#  'something,',
#  'a',
#  'woman',
#  'gets',
#  'up',
#  'and',
#  'goes',
#  'to',
#  'action.',
#  'Do',
#  'we',
#  'agree?',
#  "There's",
#  'a',
#  'lower',
#  'number',
#  'on',
#  'the',
#  'left,',
#  'a',
#  'higher',
#  'number',
#  'on',
#  'the',
#  'right.',
#  'I',
#  'agree',
#  'with',
#  'you,',
#  'Mike.',
#  'Looks',
#  'pretty',
#  'good,',
#  'but',
#  'I',
#  'love',
#  'it.',
#  'OK.',
#  'Christian,',
#  'how',
#  'do',
#  'you',
#  'know',
#  'when',
#  'the',
#  'derivative',
#  'is',
#  '0?',
#  'Okay.',
#  'Ruben,',
#  'how',
#  'do',
#  'you',
#  'describe',
#  'that?',
#  'How',
#  'do',
#  'you',
#  'know',
#  'when',
#  'the',
#  'derivative',
#  'is',
#  'zero?',
#  'I',
#  'guess',
#  'that',
#  'one',
#  'thing',
#  'where',
#  "it's",
#  'going',
#  'to',
#  'be',
#  '0.',
#  'All',
#  'right.',
#  'And',
#  'a',
#  'vertex.',
#  'OK,',
#  'very',
#  'good.',
#  'Very',
#  'good.',
#  'Any',
#  'other',
#  'ways',
#  'of',
#  'explaining',
#  'how',
#  'you',
#  'know',
#  'when',
#  'the',
#  'derivative',
#  'is',
#  '0?',
#  'So',
#  'for',
#  'the',
#  'tangent',
#  'line,',
#  'right,',
#  'right,',
#  'good,',
#  'all',
#  'right,',
#  'very',
#  'good.',
#  "That's",
#  'kind',
#  'of',
#  'our',
#  'technical',
#  'definition,',
#  'where',
#  'the',
#  'slope',
#  'of',
#  'the',
#  'tangent',
#  'line',
#  'is',
#  'equal',
#  'to',
#  'zero.',
#  'How',
#  'about,',
#  'excuse',
#  'me,',
#  'how',
#  'do',
#  'you',
#  'know',
#  'when',
#  "it's",
#  'negative?',
#  'When',
#  ...]

# %% [markdown]
# # 3.1 Different ways of tokenizing text
# text_wordTokens
# text_sentenceTokens
# text_

# %% [markdown]
# Print list of top 10 items sorted.

# %%
freq = nltk.FreqDist(text_regexTokensST)
print(freq.most_common(5))
# Out:
# [('the', 3072), ('I', 2305), ('to', 2242), ('you', 2055), ('a', 1613)]
# [('like', 837), ('yeah', 641), ('right', 561), ('one', 498), ('im', 482)]

# %% [markdown]
# Removing

# %%
#Combined All in one normalizer
import nltk
nltk.download('punkt')
nltk.download('stopwords')

# split into word tokens
#from nltk.tokenize import word_tokenize
#word_tokens = word_tokenize(text_file)

# convert to lower case
lower_tokens = [w.lower() for w in text_regexTokensST]

# remove punctuation from each word
import string
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in lower_tokens]


# remove remaining tokens that are not alphabetic
alpha_words = [word for word in stripped if word.isalpha()]


# filter out stop words
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
teacher1Transcript = [w for w in alpha_words if not w in stop_words]
print(teacher1Transcript[:100])
# Out:
# ['like', 'im', 'one', 'chair', 'people', 'oh', 'really', 'also', 'ready', 'faces', 'swimming', 'faces', 'good', 'facials', 'okay', 'shut', 'never', 'ever', 'say', 'im', 'gonna', 'creepy', 'hes', 'gonna', 'die', 'youre', 'gonna', 'die', 'food', 'uh', 'yeah', 'fine', 'go', 'away', 'coffee', 'dont', 'cheese', 'coffee', 'hes', 'today', 'hes', 'gonna', 'bald', 'head', 'hes', 'today', 'hes', 'gonna', 'shaved', 'head', 'oh', 'yeah', 'requested', 'permission', 'wear', 'hat', 'trade', 'year', 'maybe', 'hes', 'oh', 'everyone', 'shaved', 'heads', 'yeah', 'swimming', 'thought', 'cancer', 'something', 'thats', 'said', 'last', 'week', 'yeah', 'know', 'wow', 'oh', 'drake', 'mean', 'uh', 'precoc', 'im', 'gonna', 'go', 'reach', 'presents', 'seriously', 'next', 'time', 'cause', 'seriously', 'really', 'bad', 'one', 'seriously', 'promise', 'ill', 'next', 'time', 'really']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
freq = nltk.FreqDist(text_regexTokensST)
print(freq.most_common(5))

testfreq = nltk.FreqDist(teacher1Transcript)
print(testfreq.most_common(5))
# Out:
# [('the', 3072), ('I', 2305), ('to', 2242), ('you', 2055), ('a', 1613)]
# [('like', 837), ('yeah', 641), ('right', 561), ('one', 498), ('im', 482)]

# %%
cleanedTeacher1Transcript = nltk.Text(teacher1Transcript)

print(type(teacher1Transcript))
print(type(cleanedTeacher1Transcript))

cleanedTeacher1Transcript.concordance("math")
# Out:
# <class 'list'>
# <class 'nltk.text.Text'>
# Displaying 25 of 39 matches:
# ane wrong dont know dont like making math dude math like nightmare dude dont k
# dont know dont like making math dude math like nightmare dude dont know decide
# y wanted go magic theres thing magic math except fibonacci series see thats ma
# g right thank thank thank right many math teachers wild today right byebye who
#  together yeah dont know lets mental math bad yeah far file three seconds go w
# l two assignments oh right yay loves math rong okay bye thanks done getting co
# ly ask mr caldwell mr deboer physics math true oh werent making big noise alri
# uff focus lecture never zone science math social science zone time science oh
# nd im like dont want include anymore math give gotten point dont even know wri
#  okay might get wrong answer oh hate math okay buddy cant math feel like cum l
#  answer oh hate math okay buddy cant math feel like cum like cum dude im going
# ird much guys get year dont idea got math tests nervous test read every questi
# ly dead kidding dont know guys think math video ones funny sergio second one s
# laylist played automatically labeled math watched come look like stars yeah pi
# ont know ive never taught elementary math dont know reasoning teaching way pra
# s goes dont know people get matching math tshirts matching math tshirt like pe
# e get matching math tshirts matching math tshirt like people oh math team math
#  matching math tshirt like people oh math team math day old school ate pie del
# math tshirt like people oh math team math day old school ate pie delicious lik
# y wanted go magic theres thing magic math except fibonacci series close comput
# al cosine got x equals length equals math good video really cool c really need
#  questions get grand final want talk math ill show werent things thought need
# traveled five seconds think one used math big one ok pamelas process found man
#  b would like first semester college math taking semester one freshman year ca
# ces get see final mean want come see math day ill show questions oh question w

# %% [markdown]
# compute frequency distribution of words found in the document. Can find most common, least, total count, etc.

# %%
#Top ten most common words
fd = nltk.FreqDist(cleanedTeacher1Transcript)
fd.most_common(100)
# Out:
# [('like', 837),
#  ('yeah', 641),
#  ('right', 561),
#  ('one', 498),
#  ('im', 482),
#  ('thats', 465),
#  ('dont', 454),
#  ('know', 449),
#  ('get', 367),
#  ('oh', 366),
#  ('going', 321),
#  ('got', 304),
#  ('go', 300),
#  ('okay', 283),
#  ('two', 274),
#  ('youre', 266),
#  ('would', 253),
#  ('number', 244),
#  ('x', 243),
#  ('good', 242),
#  ('think', 234),
#  ('well', 232),
#  ('kind', 209),
#  ('see', 202),
#  ('want', 197),
#  ('ok', 193),
#  ('thank', 188),
#  ('say', 187),
#  ('first', 182),
#  ('us', 179),
#  ('line', 179),
#  ('speed', 177),
#  ('negative', 175),
#  ('lets', 174),
#  ('said', 171),
#  ('really', 163),
#  ('time', 163),
#  ('way', 163),
#  ('mean', 160),
#  ('take', 159),
#  ('yes', 154),
#  ('change', 153),
#  ('question', 152),
#  ('average', 152),
#  ('could', 148),
#  ('last', 147),
#  ('equals', 147),
#  ('guys', 146),
#  ('slope', 145),
#  ('little', 144),
#  ('wait', 137),
#  ('need', 136),
#  ('back', 135),
#  ('five', 134),
#  ('look', 133),
#  ('something', 132),
#  ('graph', 132),
#  ('derivative', 128),
#  ('make', 127),
#  ('use', 125),
#  ('thing', 124),
#  ('point', 122),
#  ('base', 121),
#  ('put', 119),
#  ('find', 119),
#  ('three', 119),
#  ('whats', 118),
#  ('year', 117),
#  ('log', 117),
#  ('didnt', 116),
#  ('seconds', 116),
#  ('times', 111),
#  ('sure', 109),
#  ('theres', 107),
#  ('class', 106),
#  ('function', 106),
#  ('give', 103),
#  ('equation', 101),
#  ('work', 99),
#  ('value', 99),
#  ('another', 98),
#  ('actually', 95),
#  ('alright', 95),
#  ('talk', 93),
#  ('answer', 93),
#  ('rate', 93),
#  ('second', 89),
#  ('cant', 88),
#  ('questions', 88),
#  ('sorry', 85),
#  ('found', 82),
#  ('tangent', 81),
#  ('show', 80),
#  ('come', 79),
#  ('maybe', 78),
#  ('many', 78),
#  ('group', 77),
#  ('sam', 75),
#  ('homework', 74),
#  ('different', 73)]

# %%
fd.tabulate(25)
# Out:
#   like   yeah  right    one     im  thats   dont   know    get     oh  going    got     go   okay    two  youre  would number      x   good  think   well   kind    see   want
#    837    641    561    498    482    465    454    449    367    366    321    304    300    283    274    266    253    244    243    242    234    232    209    202    197

# %% [markdown]
# Word count

# %%
fd["equal"]
# Out:
# 58

# %%
fd.plot(35, cumulative=True)
# Out:
# <Axes: xlabel='Samples', ylabel='Cumulative Counts'>

# %%
from matplotlib import pyplot as plt
# Create a frequency distribution
#fd = nltk.FreqDist(tokens_nltk_text)

# Get the 10 most common words and their counts
common = fd.most_common(10)

# Unzip the words and counts into two separate lists
words, counts = zip(*common)

# Create a bar graph
plt.bar(words, counts)
plt.show()

# %% [markdown]
# # 4.0 Basic analysis
# 1. Words/Sentences
#   *   Counting/Sorting
#   *   Concordance
# 2. Chunking
# 3. Data Visualization
#   *   plot distribution
# 3. POS Tagging
# 4. Parsing

# %% [markdown]
# This displays the total number of individual words left after several rounds of preprocessing. These numbers are good to keep up with as you continue to clean your data.

# %%
len(cleanedTeacher1Transcript)
# Out:
# 38547

# %% [markdown]
# The sorted set lists and alphabetizes all words that appear at least once throughout the document. This is another important step in cleaning your data. We can also use other preprocessing methods to shrink this list down such as stemming and lemmatizing.

# %%
sorted(set(cleanedTeacher1Transcript))
# Out:
# ['ab',
#  'ability',
#  'able',
#  'abolitionist',
#  'abrupt',
#  'absent',
#  'absolute',
#  'absolutely',
#  'absorbs',
#  'academy',
#  'accelerates',
#  'accelerating',
#  'acceleration',
#  'accent',
#  'accept',
#  'according',
#  'account',
#  'accurate',
#  'accurately',
#  'acknowledge',
#  'acquaintances',
#  'across',
#  'act',
#  'acting',
#  'action',
#  'actively',
#  'activity',
#  'actual',
#  'actuality',
#  'actually',
#  'ad',
#  'add',
#  'added',
#  'adding',
#  'addition',
#  'additive',
#  'address',
#  'adjacent',
#  'adrian',
#  'advanced',
#  'advise',
#  'af',
#  'affect',
#  'age',
#  'ago',
#  'agree',
#  'agreed',
#  'ah',
#  'ahead',
#  'aiming',
#  'aint',
#  'air',
#  'aircraft',
#  'akin',
#  'al',
#  'alb',
#  'alberdin',
#  'albert',
#  'albertans',
#  'albertin',
#  'alberton',
#  'albritton',
#  'album',
#  'alejandro',
#  'alex',
#  'algebra',
#  'algebraic',
#  'algebraically',
#  'algorithm',
#  'alice',
#  'allergic',
#  'allergies',
#  'allow',
#  'allowed',
#  'almond',
#  'almost',
#  'along',
#  'already',
#  'alreden',
#  'alright',
#  'alrighty',
#  'also',
#  'alternative',
#  'although',
#  'always',
#  'amazing',
#  'amber',
#  'ambition',
#  'american',
#  'amount',
#  'amplitude',
#  'amy',
#  'analysis',
#  'analyze',
#  'analyzing',
#  'andi',
#  'angle',
#  'angles',
#  'angry',
#  'angular',
#  'annie',
#  'annoying',
#  'annual',
#  'another',
#  'answer',
#  'answerable',
#  'answered',
#  'answers',
#  'anthem',
#  'anticipation',
#  'anybody',
#  'anybodys',
#  'anymore',
#  'anyone',
#  'anything',
#  'anyway',
#  'anyways',
#  'ap',
#  'apart',
#  'apollo',
#  'apostrophe',
#  'app',
#  'apparently',
#  'appetizing',
#  'applause',
#  'application',
#  'applies',
#  'applying',
#  'appreciate',
#  'appreciating',
#  'approach',
#  'approaches',
#  'approaching',
#  'approve',
#  'approximated',
#  'approximately',
#  'approximating',
#  'approximation',
#  'approximations',
#  'aprils',
#  'apus',
#  'aquí',
#  'arc',
#  'arctangent',
#  'area',
#  'arent',
#  'argue',
#  'arguing',
#  'argument',
#  'arithmetic',
#  'arms',
#  'around',
#  'arrows',
#  'articulate',
#  'artists',
#  'aruba',
#  'ashy',
#  'aside',
#  'ask',
#  'asked',
#  'asking',
#  'asks',
#  'asleep',
#  'assessment',
#  'assign',
#  'assignment',
#  'assignments',
#  'assume',
#  'assumes',
#  'assuming',
#  'assured',
#  'asymptote',
#  'ate',
#  'atmosphere',
#  'atrocious',
#  'attention',
#  'attitude',
#  'auberdin',
#  'auburn',
#  'audience',
#  'automatically',
#  'available',
#  'average',
#  'averaged',
#  'averages',
#  'averaging',
#  'avicii',
#  'avoid',
#  'aw',
#  'aware',
#  'away',
#  'awesome',
#  'axes',
#  'axis',
#  'ay',
#  'b',
#  'babies',
#  'baby',
#  'babys',
#  'back',
#  'backpack',
#  'backside',
#  'backwards',
#  'bad',
#  'bae',
#  'bag',
#  'bags',
#  'bald',
#  'ball',
#  'balls',
#  'bam',
#  'bank',
#  'bar',
#  'barbara',
#  'barely',
#  'barrel',
#  'bars',
#  'base',
#  'baseball',
#  'based',
#  'bases',
#  'basic',
#  'basically',
#  'basis',
#  'basketball',
#  'bathroom',
#  'batter',
#  'batteries',
#  'battery',
#  'bc',
#  'beanstalk',
#  'beat',
#  'beautiful',
#  'become',
#  'becomes',
#  'becoming',
#  'bed',
#  'bedroom',
#  'beer',
#  'begin',
#  'beginning',
#  'begun',
#  'behind',
#  'beige',
#  'believe',
#  'bell',
#  'bella',
#  'bellas',
#  'bellen',
#  'belong',
#  'bench',
#  'bennett',
#  'berry',
#  'besides',
#  'best',
#  'bestest',
#  'bet',
#  'better',
#  'betunia',
#  'beyond',
#  'big',
#  'bigger',
#  'biggest',
#  'bill',
#  'billion',
#  'bina',
#  'binary',
#  'birds',
#  'birthday',
#  'bit',
#  'bitch',
#  'bite',
#  'bittersweet',
#  'black',
#  'blackberries',
#  'blackberry',
#  'blah',
#  'blame',
#  'blaming',
#  'blank',
#  'bleach',
#  'bless',
#  'blew',
#  'bloated',
#  'block',
#  'blocks',
#  'blonde',
#  'blowing',
#  'blue',
#  'blueberries',
#  'board',
#  'boards',
#  'boat',
#  'body',
#  'bogeyman',
#  'book',
#  'bookmarked',
#  'books',
#  'boom',
#  'boots',
#  'booty',
#  'bored',
#  'boring',
#  'borrow',
#  'borrowed',
#  'bottom',
#  'bowl',
#  'bowling',
#  'box',
#  'boxes',
#  'boxing',
#  'boy',
#  'bozle',
#  'braces',
#  'brackets',
#  'brave',
#  'brazil',
#  'breadcrumb',
#  'break',
#  'breath',
#  'brief',
#  'briefly',
#  'bright',
#  'brilliant',
#  'bring',
#  'bringing',
#  'brisk',
#  'britain',
#  'britten',
#  'bro',
#  'broadly',
#  'broke',
#  'broken',
#  'brother',
#  'brothers',
#  'brought',
#  'brown',
#  'brrr',
#  'bruce',
#  'bubble',
#  'bucks',
#  'bud',
#  'buddy',
#  'budget',
#  'buh',
#  'build',
#  'bullet',
#  'bullets',
#  'bulls',
#  'bully',
#  'bun',
#  'bunch',
#  'bundle',
#  'bunk',
#  'burn',
#  'burned',
#  'burns',
#  'burrow',
#  'bus',
#  'busy',
#  'butt',
#  'button',
#  'butts',
#  'buy',
#  'bye',
#  'byebye',
#  'c',
#  'caffeine',
#  'caillou',
#  'calc',
#  'calculate',
#  'calculated',
#  'calculating',
#  'calculation',
#  'calculations',
#  'calculator',
#  'calculators',
#  'calculus',
#  'caldwell',
#  'cali',
#  'calibrate',
#  'call',
#  'called',
#  'calling',
#  'calls',
#  'camcorder',
#  'came',
#  'camera',
#  'cams',
#  'canada',
#  'cancel',
#  'canceled',
#  'cancels',
#  'cancer',
#  'cannot',
#  'cans',
#  'cant',
#  'cap',
#  'capping',
#  'capps',
#  'captain',
#  'car',
#  'carajo',
#  'card',
#  'cards',
#  'care',
#  'careful',
#  'cares',
#  'caring',
#  'carrier',
#  'carries',
#  'carrots',
#  'carrying',
#  'cars',
#  'cart',
#  'case',
#  'cash',
#  'casted',
#  'cat',
#  'catch',
#  'catching',
#  'category',
#  'catholicism',
#  'cause',
#  'cbh',
#  'center',
#  'centimeter',
#  'centimeters',
#  'cents',
#  'cereal',
#  'certain',
#  'certainly',
#  'cest',
#  'chair',
#  'challenge',
#  'chance',
#  'change',
#  'changed',
#  'changes',
#  'changing',
#  'channels',
#  'chapters',
#  'character',
#  'characteristic',
#  'characteristics',
#  'characters',
#  'charlotte',
#  'charm',
#  'chart',
#  'chase',
#  'cheat',
#  'cheating',
#  'check',
#  'checking',
#  'checks',
#  'cheerful',
#  'cheers',
#  'cheese',
#  'cheesy',
#  'chem',
#  'chemical',
#  'cherries',
#  'chess',
#  'chicharron',
#  'chick',
#  'chicken',
#  'chihuahua',
#  'chime',
#  'chinese',
#  'choice',
#  'choices',
#  'choose',
#  'chord',
#  'chris',
#  'christian',
#  'christians',
#  'christmas',
#  'chunk',
#  'cinco',
#  'cindy',
#  'circle',
#  'circled',
#  'circles',
#  'circuit',
#  'circumference',
#  'citing',
#  'city',
#  'civil',
#  'claim',
#  'claimed',
#  'claims',
#  'clairvoyant',
#  'clap',
#  'clapping',
#  'clarify',
#  'clase',
#  'class',
#  'classes',
#  'classificated',
#  'classmates',
#  'classroom',
#  'clean',
#  'clear',
#  'clearer',
#  'clearly',
#  'clever',
#  'click',
#  'clicked',
#  'clicking',
#  'cliff',
#  'close',
#  'closely',
#  'closer',
#  'club',
#  'clue',
#  'co',
#  'coach',
#  'coal',
#  'coasters',
#  'coconut',
#  'code',
#  'coefficient',
#  'coffee',
#  'cold',
#  'collect',
#  'collecting',
#  'collection',
#  'collective',
#  'collects',
#  'college',
#  'collegey',
#  'colons',
#  'color',
#  'colored',
#  'colors',
#  'combination',
#  'combine',
#  'combined',
#  'combining',
#  'combusts',
#  'come',
#  'comes',
#  'comfortable',
#  'coming',
#  'command',
#  'comment',
#  'commented',
#  'comments',
#  'commercials',
#  'commitment',
#  'common',
#  'communicating',
#  'comparable',
#  'compare',
#  'compared',
#  'comparing',
#  'comparison',
#  'compile',
#  'complaining',
#  'complete',
#  'completely',
#  'completion',
#  'complicated',
#  'composition',
#  'compounded',
#  'compromiser',
#  'computational',
#  'computations',
#  'computer',
#  'con',
#  'concentrate',
#  'concepts',
#  'concur',
#  'conditioner',
#  'condolences',
#  'confident',
#  'confirm',
#  'confirmation',
#  'confused',
#  'confusing',
#  'congratulations',
#  'congress',
#  'connect',
#  'connected',
#  'connection',
#  'connects',
#  'consider',
#  'considered',
#  'considering',
#  'constant',
#  'construct',
#  'constructed',
#  'consuming',
#  'content',
#  'context',
#  'contextual',
#  'continually',
#  'continuation',
#  'continue',
#  'continues',
#  'continuing',
#  'continuous',
#  'control',
#  'controlling',
#  'convenience',
#  'convenient',
#  'convention',
#  'convergence',
#  'conversations',
#  'convert',
#  'convinced',
#  'cook',
#  'cookie',
#  'cookies',
#  'cool',
#  'coolest',
#  'coordinate',
#  'copied',
#  'copy',
#  'copyright',
#  'cora',
#  'corner',
#  'correct',
#  'correction',
#  'correctly',
#  'correspond',
#  'corresponding',
#  'cosentan',
#  'cosine',
#  'cosmic',
#  'cost',
#  'cotangent',
#  'could',
#  'couldnt',
#  'count',
#  'counted',
#  'counter',
#  'couple',
#  'coupled',
#  'course',
#  'courteous',
#  'courtroom',
#  'cousin',
#  'cousins',
#  'covered',
#  'cows',
#  'crack',
#  'craigslist',
#  'crap',
#  'crazy',
#  'cream',
#  'create',
#  'credit',
#  'creep',
#  'creepy',
#  'crema',
#  'crew',
#  'cried',
#  'criteria',
#  'cross',
#  'crosses',
#  'crow',
#  'crowds',
#  'crush',
#  'cry',
#  'crying',
#  'cs',
#  'cub',
#  'cubes',
#  'cubic',
#  'cubics',
#  'cuff',
#  'cum',
#  'curious',
#  'curriculum',
#  'curvature',
#  'curve',
#  'curved',
#  'curves',
#  'cut',
#  'cute',
#  'cuts',
#  'cutting',
#  'dad',
#  'daddy',
#  'daily',
#  'damn',
#  'dance',
#  'dancers',
#  'dancing',
#  'dang',
#  'dangerous',
#  'dark',
#  'darker',
#  'darn',
#  'darned',
#  'data',
#  'date',
#  'dates',
#  'daughter',
#  'dave',
#  'dawn',
#  'day',
#  'days',
#  'de',
#  'dead',
#  'deadline',
#  'deal',
#  'dealing',
#  'deals',
#  'death',
#  'debate',
#  'deboer',
#  'decade',
#  'decay',
#  'decent',
#  'decibel',
#  'decibels',
#  'decide',
#  'decided',
#  'decimal',
#  'decimals',
#  'decisively',
#  'decrease',
#  'decreases',
#  'decreasing',
#  'deemphasize',
#  'deep',
#  'deepest',
#  'define',
#  'defined',
#  'defining',
#  'definitely',
#  'definition',
#  'degree',
#  'degrees',
#  'delicious',
#  'delta',
#  'demanding',
#  'denominator',
#  'dense',
#  'department',
#  'depending',
#  'depends',
#  'derivative',
#  'derivatives',
#  'describe',
#  'described',
#  'describes',
#  'describing',
#  'designer',
#  'desk',
#  'desktop',
#  'destiny',
#  'details',
#  'determine',
#  'determined',
#  'devine',
#  'dex',
#  'dexter',
#  'di',
#  'diagonally',
#  'diagram',
#  'diagrams',
#  'diameter',
#  'diamond',
#  'diaper',
#  'dictate',
#  'didnt',
#  'die',
#  'died',
#  'diet',
#  'difference',
#  'differences',
#  'different',
#  'differentiation',
#  'differently',
#  'difficult',
#  'dig',
#  'dignity',
#  'dim',
#  'dina',
#  'direct',
#  'direction',
#  'directions',
#  'directly',
#  'dirty',
#  'disagree',
#  'disappear',
#  'discovery',
#  'discrepancies',
#  'discrete',
#  'discuss',
#  'discussed',
#  'discussing',
#  'discussion',
#  'discussions',
#  'disgusted',
#  'disgusting',
#  'dispose',
#  'distance',
#  'distances',
#  'distribute',
#  'distributions',
#  'disturb',
#  'dive',
#  'diver',
#  'divide',
#  'divided',
#  'dividing',
#  'divine',
#  'division',
#  'dmt',
#  'doble',
#  'doesnt',
#  'dog',
#  'dollar',
#  'dollars',
#  'domain',
#  'done',
#  'dont',
#  'door',
#  'doors',
#  'doorway',
#  'dory',
#  'dos',
#  'dot',
#  'dots',
#  'double',
#  'doubling',
#  'downstairs',
#  'dr',
#  'drake',
#  'draw',
#  'drawing',
#  'drawn',
#  'dressing',
#  'drew',
#  'drift',
#  'drink',
#  'drinking',
#  'drinks',
#  'drivers',
#  'driving',
#  'drop',
#  'dropped',
#  'dropping',
#  'drugs',
#  'duck',
#  'dude',
#  'due',
#  'duh',
#  'dumb',
#  'dumbass',
#  'dump',
#  'duplicate',
#  'dying',
#  'dynamite',
#  'dysfunction',
#  'e',
#  'ear',
#  'earlier',
#  'early',
#  'ears',
#  'earth',
#  'earthquakes',
#  'easier',
#  'easiest',
#  'easily',
#  'easy',
#  'eat',
#  'eaten',
#  'eating',
#  'ebay',
#  'ed',
#  'edge',
#  'edges',
#  'edited',
#  'education',
#  'ees',
#  'effect',
#  'efficient',
#  'effort',
#  'eggs',
#  'eh',
#  'eight',
#  'eighteen',
#  'either',
#  'el',
#  'elapsed',
#  'elbow',
#  'elbowed',
#  'elementary',
#  'eleven',
#  'elias',
#  'elmo',
#  'elsa',
#  'else',
#  'elses',
#  'email',
#  'emailing',
#  'emails',
#  'embarrassed',
#  'embarrassing',
#  'emmett',
#  'emotional',
#  'emphasis',
#  'end',
#  'ended',
#  'ends',
#  'enemy',
#  'energy',
#  'engineering',
#  'engineers',
#  'engines',
#  'english',
#  'enjoy',
#  'enjoyed',
#  'enough',
#  'ensemble',
#  'enter',
#  'entertaining',
#  'entire',
#  'entirely',
#  'entry',
#  'equal',
#  'equality',
#  'equals',
#  'equation',
#  'equations',
#  'equivalent',
#  'er',
#  'erase',
#  'erased',
#  'eraser',
#  'err',
#  'error',
#  'especially',
#  'essays',
#  'essentially',
#  'established',
#  'estimate',
#  'estimated',
#  'et',
#  'europe',
#  'evaluate',
#  'evan',
#  'evans',
#  'even',
#  'ever',
#  'every',
#  'everybody',
#  'everybodys',
#  'everyone',
#  'everyones',
#  'everything',
#  'everythings',
#  'everywhere',
#  'ew',
#  'exact',
#  'exactly',
#  'exam',
#  'examinations',
#  'examine',
#  'example',
#  'examples',
#  'excellent',
#  'except',
#  'exceptions',
#  'excessive',
#  'excited',
#  'exclamations',
#  'excuse',
#  'excusezmoi',
#  'exercise',
#  'exist',
#  'expand',
#  'expect',
#  'expected',
#  'expects',
#  'experiment',
#  'explain',
#  'explaining',
#  'explanation',
#  'explanations',
#  'explicit',
#  'explicitly',
#  'exponent',
#  'exponential',
#  'exponentials',
#  'exponentiation',
#  'exponents',
#  'express',
#  'expressed',
#  'expression',
#  'expressions',
#  'extend',
#  'extended',
#  'extensively',
#  'extra',
#  ...]

# %% [markdown]
# # 4.1 More quick analysis options
# 1. concordance
# 2. similar words
# 3. dispersion plots

# %%
cleanedTeacher1Transcript.concordance('remember', lines = 50)
# Out:
# Displaying 50 of 65 matches:
# ting looking exponential functions remember whole activity x x found proportio
# t right yeah one talked last class remember inflection point yes inflection po
# s got another one sign table group remember hoping one else table got number s
#  idea weighted average us game pig remember anybody oh missed good unit algebr
#  like shes got function notation h remember thats say h put input value parent
# me bunch questions going youve got remember ish ish take one mean im cool like
# als x equals case one function one remember discussions youve past functions f
#  idea weighted average us game pig remember anybody oh missed good unit algebr
#  many posters like posters oh yeah remember league legends im elementary schoo
#  like shes got function notation h remember thats say h put input value parent
# als x equals case one function one remember discussions youve past functions f
# inite yeah function want make sure remember write equations vertical lines wri
# uss learning styles well move dont remember put think put hear teacher lecture
#  lecture like said oh oh okay yeah remember put said cutting remember yeah sai
# kay yeah remember put said cutting remember yeah said cutting hear teacher lec
#  like actually went shes like dont remember got thing portfolios end im like d
# equation derivative function bless remember shortcuts shortcut function deriva
# nds see oh thats negative exponent remember negative exponent learned last uni
# ngles wouldnt see right kind trick remember special angles use knowledge ratio
# hats tangent degrees actually dont remember could tell square root square root
# ite mines sockchair mines one dont remember bookmarked yeah yeah footlocker hi
# na charlotte kitts nona whos gonna remember name im gonna make shorter name li
# tting looking exponential function remember whole activity x x found proportio
# t right yeah one talked last class remember yes inflection points minimum maxi
# homework oh yeah get homework dont remember homework get never going less yeah
# cult problem might go solving cant remember base two certainly take numbers tu
# h yeah pretty close final answer x remember multiply bases exponents add expon
# epresent show graph settle yes yes remember talked little bit well actually to
# rvoyant youre going something like remember well probably something like last
# uded oh illustrate nice yeah could remember using go separating fraction like
# a go ahead log base equals x right remember theres kind strange way saying str
# ch shape put important information remember third fourth pages circle problem
# olon called transversal wish could remember vocab remember front library hes l
# nsversal wish could remember vocab remember front library hes like transversal
# ace guess last last one guess dont remember one shows dont know anything cute
# rmula simplify make sure get forms remember started barely started today turn
# ove forward theres really easy way remember formula questions pretty hard actu
# sam saying didnt actually use used remember went couple steps took guys whole
# ets lets work heres summation dont remember exactly first terms alright asked
# d oh alright well hate youre going remember stuff last semester yeah thats goi
# nny week goes im sure funny things remember little something main character ca
# g main character called speedy yes remember basketball one pop quiz got us rea
# ly theyre numbered front page says remember speedy group id like come answers
#  tried ignore dont recall probably remember yeah great job gave opportunity re
# er yeah great job gave opportunity remember said alright get everybody get let
# thing actually finding adrian cant remember discussing maybe bella way kind de
# ion question well hate youre going remember stuff last hows baby hows bae baby
#  good morning yeah right good like remember little something main character ca
# racter called speedy gonzales yeah remember house basketball basketball basket
# hing good mark yes okay thank dont remember swimming next oh yeah remember mar

# %%
cleanedTeacher1Transcript.similar("students")
# Out:
# dont number think might twentythree

# %%
cleanedTeacher1Transcript.dispersion_plot(["students","teacher", "math", "help"])

# %% [markdown]
# # 4.2 n-grams and colocations
# 1. bigrams
# 2. trigrams

# %%
Teacher1Transcript_bigrams = list(nltk.bigrams(cleanedTeacher1Transcript))
Teacher1Transcript_bigrams
# Out:
# [('like', 'im'),
#  ('im', 'one'),
#  ('one', 'chair'),
#  ('chair', 'people'),
#  ('people', 'oh'),
#  ('oh', 'really'),
#  ('really', 'also'),
#  ('also', 'ready'),
#  ('ready', 'faces'),
#  ('faces', 'swimming'),
#  ('swimming', 'faces'),
#  ('faces', 'good'),
#  ('good', 'facials'),
#  ('facials', 'okay'),
#  ('okay', 'shut'),
#  ('shut', 'never'),
#  ('never', 'ever'),
#  ('ever', 'say'),
#  ('say', 'im'),
#  ('im', 'gonna'),
#  ('gonna', 'creepy'),
#  ('creepy', 'hes'),
#  ('hes', 'gonna'),
#  ('gonna', 'die'),
#  ('die', 'youre'),
#  ('youre', 'gonna'),
#  ('gonna', 'die'),
#  ('die', 'food'),
#  ('food', 'uh'),
#  ('uh', 'yeah'),
#  ('yeah', 'fine'),
#  ('fine', 'go'),
#  ('go', 'away'),
#  ('away', 'coffee'),
#  ('coffee', 'dont'),
#  ('dont', 'cheese'),
#  ('cheese', 'coffee'),
#  ('coffee', 'hes'),
#  ('hes', 'today'),
#  ('today', 'hes'),
#  ('hes', 'gonna'),
#  ('gonna', 'bald'),
#  ('bald', 'head'),
#  ('head', 'hes'),
#  ('hes', 'today'),
#  ('today', 'hes'),
#  ('hes', 'gonna'),
#  ('gonna', 'shaved'),
#  ('shaved', 'head'),
#  ('head', 'oh'),
#  ('oh', 'yeah'),
#  ('yeah', 'requested'),
#  ('requested', 'permission'),
#  ('permission', 'wear'),
#  ('wear', 'hat'),
#  ('hat', 'trade'),
#  ('trade', 'year'),
#  ('year', 'maybe'),
#  ('maybe', 'hes'),
#  ('hes', 'oh'),
#  ('oh', 'everyone'),
#  ('everyone', 'shaved'),
#  ('shaved', 'heads'),
#  ('heads', 'yeah'),
#  ('yeah', 'swimming'),
#  ('swimming', 'thought'),
#  ('thought', 'cancer'),
#  ('cancer', 'something'),
#  ('something', 'thats'),
#  ('thats', 'said'),
#  ('said', 'last'),
#  ('last', 'week'),
#  ('week', 'yeah'),
#  ('yeah', 'know'),
#  ('know', 'wow'),
#  ('wow', 'oh'),
#  ('oh', 'drake'),
#  ('drake', 'mean'),
#  ('mean', 'uh'),
#  ('uh', 'precoc'),
#  ('precoc', 'im'),
#  ('im', 'gonna'),
#  ('gonna', 'go'),
#  ('go', 'reach'),
#  ('reach', 'presents'),
#  ('presents', 'seriously'),
#  ('seriously', 'next'),
#  ('next', 'time'),
#  ('time', 'cause'),
#  ('cause', 'seriously'),
#  ('seriously', 'really'),
#  ('really', 'bad'),
#  ('bad', 'one'),
#  ('one', 'seriously'),
#  ('seriously', 'promise'),
#  ('promise', 'ill'),
#  ('ill', 'next'),
#  ('next', 'time'),
#  ('time', 'really'),
#  ('really', 'bad'),
#  ('bad', 'one'),
#  ('one', 'im'),
#  ('im', 'dont'),
#  ('dont', 'really'),
#  ('really', 'care'),
#  ('care', 'eight'),
#  ('eight', 'five'),
#  ('five', 'eight'),
#  ('eight', 'five'),
#  ('five', 'eight'),
#  ('eight', 'sure'),
#  ('sure', 'going'),
#  ('going', 'take'),
#  ('take', 'back'),
#  ('back', 'easy'),
#  ('easy', 'really'),
#  ('really', 'easy'),
#  ('easy', 'nah'),
#  ('nah', 'seriously'),
#  ('seriously', 'nah'),
#  ('nah', 'seriously'),
#  ('seriously', 'ill'),
#  ('ill', 'thursday'),
#  ('thursday', 'seriously'),
#  ('seriously', 'dont'),
#  ('dont', 'want'),
#  ('want', 'today'),
#  ('today', 'please'),
#  ('please', 'really'),
#  ('really', 'easy'),
#  ('easy', 'put'),
#  ('put', 'number'),
#  ('number', 'put'),
#  ('put', 'number'),
#  ('number', 'number'),
#  ('number', 'im'),
#  ('im', 'okay'),
#  ('okay', 'number'),
#  ('number', 'get'),
#  ('get', 'times'),
#  ('times', 'wrong'),
#  ('wrong', 'im'),
#  ('im', 'pretty'),
#  ('pretty', 'sure'),
#  ('sure', 'instead'),
#  ('instead', 'divide'),
#  ('divide', 'doesnt'),
#  ('doesnt', 'make'),
#  ('make', 'sense'),
#  ('sense', 'think'),
#  ('think', 'yeah'),
#  ('yeah', 'wrong'),
#  ('wrong', 'yeah'),
#  ('yeah', 'got'),
#  ('got', 'wrong'),
#  ('wrong', 'man'),
#  ('man', 'hold'),
#  ('hold', 'im'),
#  ('im', 'going'),
#  ('going', 'go'),
#  ('go', 'ahead'),
#  ('ahead', 'get'),
#  ('get', 'wait'),
#  ('wait', 'dont'),
#  ('dont', 'pan'),
#  ('pan', 'nobodys'),
#  ('nobodys', 'panning'),
#  ('panning', 'run'),
#  ('run', 'italy'),
#  ('italy', 'cant'),
#  ('cant', 'seem'),
#  ('seem', 'find'),
#  ('find', 'class'),
#  ('class', 'hennigans'),
#  ('hennigans', 'dont'),
#  ('dont', 'know'),
#  ('know', 'one'),
#  ('one', 'following'),
#  ('following', 'chance'),
#  ('chance', 'actually'),
#  ('actually', 'make'),
#  ('make', 'sure'),
#  ('sure', 'get'),
#  ('get', 'stuff'),
#  ('stuff', 'yeah'),
#  ('yeah', 'yeah'),
#  ('yeah', 'act'),
#  ('act', 'somebody'),
#  ('somebody', 'right'),
#  ('right', 'alright'),
#  ('alright', 'um'),
#  ('um', 'list'),
#  ('list', 'lets'),
#  ('lets', 'see'),
#  ('see', 'thank'),
#  ('thank', 'look'),
#  ('look', 'nothing'),
#  ('nothing', 'special'),
#  ('special', 'quick'),
#  ('quick', 'lap'),
#  ('lap', 'good'),
#  ('good', 'really'),
#  ('really', 'meant'),
#  ('meant', 'lets'),
#  ('lets', 'label'),
#  ('label', 'xaxis'),
#  ('xaxis', 'yaxis'),
#  ('yaxis', 'need'),
#  ('need', 'labeled'),
#  ('labeled', 'want'),
#  ('want', 'important'),
#  ('important', 'think'),
#  ('think', 'well'),
#  ('well', 'x'),
#  ('x', 'soon'),
#  ('soon', 'comes'),
#  ('comes', 'okay'),
#  ('okay', 'lets'),
#  ('lets', 'negative'),
#  ('negative', 'negative'),
#  ('negative', 'negative'),
#  ('negative', 'okay'),
#  ('okay', 'work'),
#  ('work', 'together'),
#  ('together', 'sure'),
#  ('sure', 'mathematical'),
#  ('mathematical', 'notation'),
#  ('notation', 'mean'),
#  ('mean', 'think'),
#  ('think', 'want'),
#  ('want', 'equality'),
#  ('equality', 'dont'),
#  ('dont', 'want'),
#  ('want', 'leave'),
#  ('leave', 'one'),
#  ('one', 'x'),
#  ('x', 'equal'),
#  ('equal', 'look'),
#  ('look', 'theyre'),
#  ('theyre', 'calculus'),
#  ('calculus', 'folder'),
#  ('folder', 'graded'),
#  ('graded', 'want'),
#  ('want', 'grade'),
#  ('grade', 'operate'),
#  ('operate', 'really'),
#  ('really', 'needs'),
#  ('needs', 'get'),
#  ('get', 'gopro'),
#  ('gopro', 'really'),
#  ('really', 'needs'),
#  ('needs', 'get'),
#  ('get', 'gopro'),
#  ('gopro', 'looks'),
#  ('looks', 'like'),
#  ('like', 'might'),
#  ('might', 'need'),
#  ('need', 'little'),
#  ('little', 'recursion'),
#  ('recursion', 'write'),
#  ('write', 'inequalities'),
#  ('inequalities', 'tell'),
#  ('tell', 'inequality'),
#  ('inequality', 'oh'),
#  ('oh', 'theres'),
#  ('theres', 'typo'),
#  ('typo', 'didnt'),
#  ('didnt', 'see'),
#  ('see', 'one'),
#  ('one', 'positive'),
#  ('positive', 'right'),
#  ('right', 'someone'),
#  ('someone', 'noble'),
#  ('noble', 'mean'),
#  ('mean', 'makes'),
#  ('makes', 'sense'),
#  ('sense', 'maybe'),
#  ('maybe', 'ill'),
#  ('ill', 'take'),
#  ('take', 'f'),
#  ('f', 'prime'),
#  ('prime', 'know'),
#  ('know', 'somebody'),
#  ('somebody', 'come'),
#  ('come', 'mark'),
#  ('mark', 'graph'),
#  ('graph', 'show'),
#  ('show', 'us'),
#  ('us', 'visually'),
#  ('visually', 'come'),
#  ('come', 'show'),
#  ('show', 'us'),
#  ('us', 'yeah'),
#  ('yeah', 'positive'),
#  ('positive', 'negative'),
#  ('negative', 'squared'),
#  ('squared', 'says'),
#  ('says', 'okay'),
#  ('okay', 'perfect'),
#  ('perfect', 'think'),
#  ('think', 'well'),
#  ('well', 'see'),
#  ('see', 'im'),
#  ('im', 'pretty'),
#  ('pretty', 'sure'),
#  ('sure', 'papers'),
#  ('papers', 'us'),
#  ('us', 'use'),
#  ('use', 'pluses'),
#  ('pluses', 'minuses'),
#  ('minuses', 'like'),
#  ('like', 'good'),
#  ('good', 'clear'),
#  ('clear', 'whats'),
#  ('whats', 'going'),
#  ('going', 'see'),
#  ('see', 'derivative'),
#  ('derivative', 'greater'),
#  ('greater', 'zero'),
#  ('zero', 'values'),
#  ('values', 'x'),
#  ('x', 'correspond'),
#  ('correspond', 'mackenzie'),
#  ('mackenzie', 'x'),
#  ('x', 'greater'),
#  ('greater', 'negative'),
#  ('negative', 'less'),
#  ('less', 'negative'),
#  ('negative', 'thats'),
#  ('thats', 'two'),
#  ('two', 'numbers'),
#  ('numbers', 'derivative'),
#  ('derivative', 'positive'),
#  ('positive', 'concur'),
#  ('concur', 'write'),
#  ('write', 'words'),
#  ('words', 'x'),
#  ('x', 'negative'),
#  ('negative', 'lower'),
#  ('lower', 'number'),
#  ('number', 'goes'),
#  ('goes', 'left'),
#  ('left', 'like'),
#  ('like', 'youre'),
#  ('youre', 'reading'),
#  ('reading', 'left'),
#  ('left', 'right'),
#  ('right', 'higher'),
#  ('higher', 'number'),
#  ('number', 'goes'),
#  ('goes', 'right'),
#  ('right', 'put'),
#  ('put', 'x'),
#  ('x', 'else'),
#  ('else', 'gina'),
#  ('gina', 'labeled'),
#  ('labeled', 'ok'),
#  ('ok', 'fair'),
#  ('fair', 'enough'),
#  ('enough', 'thats'),
#  ('thats', 'greater'),
#  ('greater', 'help'),
#  ('help', 'model'),
#  ('model', 'fill'),
#  ('fill', 'ok'),
#  ('ok', 'lets'),
#  ('lets', 'finish'),
#  ('finish', 'first'),
#  ('first', 'half'),
#  ('half', 'least'),
#  ('least', 'get'),
#  ('get', 'explanations'),
#  ('explanations', 'ah'),
#  ('ah', 'darn'),
#  ('darn', 'make'),
#  ('make', 'sure'),
#  ('sure', 'comparing'),
#  ('comparing', 'answers'),
#  ('answers', 'please'),
#  ('please', 'okay'),
#  ('okay', 'somebody'),
#  ('somebody', 'please'),
#  ('please', 'come'),
#  ('come', 'finish'),
#  ('finish', 'statements'),
#  ('statements', 'one'),
#  ('one', 'person'),
#  ('person', 'one'),
#  ('one', 'another'),
#  ('another', 'another'),
#  ('another', 'join'),
#  ('join', 'oh'),
#  ('oh', 'scissors'),
#  ('scissors', 'established'),
#  ('established', 'around'),
#  ('around', 'books'),
#  ('books', 'thank'),
#  ('thank', 'thank'),
#  ('thank', 'destiny'),
#  ('destiny', 'well'),
#  ('well', 'yet'),
#  ('yet', 'another'),
#  ('another', 'case'),
#  ('case', 'men'),
#  ('men', 'sit'),
#  ('sit', 'discuss'),
#  ('discuss', 'something'),
#  ('something', 'woman'),
#  ('woman', 'gets'),
#  ('gets', 'goes'),
#  ('goes', 'action'),
#  ('action', 'agree'),
#  ('agree', 'theres'),
#  ('theres', 'lower'),
#  ('lower', 'number'),
#  ('number', 'left'),
#  ('left', 'higher'),
#  ('higher', 'number'),
#  ('number', 'right'),
#  ('right', 'agree'),
#  ('agree', 'mike'),
#  ('mike', 'looks'),
#  ('looks', 'pretty'),
#  ('pretty', 'good'),
#  ('good', 'love'),
#  ('love', 'ok'),
#  ('ok', 'christian'),
#  ('christian', 'know'),
#  ('know', 'derivative'),
#  ('derivative', 'okay'),
#  ('okay', 'ruben'),
#  ('ruben', 'describe'),
#  ('describe', 'know'),
#  ('know', 'derivative'),
#  ('derivative', 'zero'),
#  ('zero', 'guess'),
#  ('guess', 'one'),
#  ('one', 'thing'),
#  ('thing', 'going'),
#  ('going', 'right'),
#  ('right', 'vertex'),
#  ('vertex', 'ok'),
#  ('ok', 'good'),
#  ('good', 'good'),
#  ('good', 'ways'),
#  ('ways', 'explaining'),
#  ('explaining', 'know'),
#  ('know', 'derivative'),
#  ('derivative', 'tangent'),
#  ('tangent', 'line'),
#  ('line', 'right'),
#  ('right', 'right'),
#  ('right', 'good'),
#  ('good', 'right'),
#  ('right', 'good'),
#  ('good', 'thats'),
#  ('thats', 'kind'),
#  ('kind', 'technical'),
#  ('technical', 'definition'),
#  ('definition', 'slope'),
#  ('slope', 'tangent'),
#  ('tangent', 'line'),
#  ('line', 'equal'),
#  ('equal', 'zero'),
#  ('zero', 'excuse'),
#  ('excuse', 'know'),
#  ('know', 'negative'),
#  ('negative', 'slope'),
#  ('slope', 'tangent'),
#  ('tangent', 'line'),
#  ('line', 'negative'),
#  ('negative', 'ok'),
#  ('ok', 'sure'),
#  ('sure', 'fair'),
#  ('fair', 'enough'),
#  ('enough', 'course'),
#  ('course', 'positive'),
#  ('positive', 'youre'),
#  ('youre', 'going'),
#  ('going', 'keep'),
#  ('keep', 'using'),
#  ('using', 'bet'),
#  ('bet', 'youre'),
#  ('youre', 'going'),
#  ('going', 'say'),
#  ('say', 'thing'),
#  ('thing', 'slope'),
#  ('slope', 'tangent'),
#  ('tangent', 'line'),
#  ('line', 'positive'),
#  ('positive', 'right'),
#  ('right', 'fine'),
#  ('fine', 'fine'),
#  ('fine', 'curve'),
#  ('curve', 'headed'),
#  ('headed', 'positive'),
#  ('positive', 'direction'),
#  ('direction', 'thats'),
#  ('thats', 'interesting'),
#  ('interesting', 'curve'),
#  ('curve', 'headed'),
#  ('headed', 'positive'),
#  ('positive', 'direction'),
#  ('direction', 'yeah'),
#  ('yeah', 'ok'),
#  ('ok', 'like'),
#  ('like', 'right'),
#  ('right', 'id'),
#  ('id', 'like'),
#  ('like', 'send'),
#  ('send', 'one'),
#  ('one', 'person'),
#  ('person', 'back'),
#  ('back', 'get'),
#  ('get', 'whiteboard'),
#  ('whiteboard', 'another'),
#  ('another', 'person'),
#  ('person', 'forwards'),
#  ('forwards', 'get'),
#  ('get', 'marker'),
#  ('marker', 'group'),
#  ('group', 'make'),
#  ('make', 'graph'),
#  ('graph', 'derivative'),
#  ('derivative', 'function'),
#  ('function', 'physics'),
#  ('physics', 'horrible'),
#  ('horrible', 'im'),
#  ('im', 'trying'),
#  ('trying', 'resist'),
#  ('resist', 'want'),
#  ('want', 'graph'),
#  ('graph', 'copy'),
#  ('copy', 'oh'),
#  ('oh', 'man'),
#  ('man', 'get'),
#  ('get', 'better'),
#  ('better', 'ill'),
#  ('ill', 'go'),
#  ('go', 'get'),
#  ('get', 'better'),
#  ('better', 'mic'),
#  ('mic', 'working'),
#  ('working', 'sorry'),
#  ('sorry', 'cool'),
#  ('cool', 'please'),
#  ('please', 'bet'),
#  ('bet', 'taking'),
#  ('taking', 'ap'),
#  ('ap', 'social'),
#  ('social', 'science'),
#  ('science', 'class'),
#  ('class', 'next'),
#  ('next', 'year'),
#  ('year', 'social'),
#  ('social', 'science'),
#  ('science', 'taking'),
#  ('taking', 'next'),
#  ('next', 'year'),
#  ('year', 'sociality'),
#  ('sociality', 'sociality'),
#  ('sociality', 'sounds'),
#  ('sounds', 'cool'),
#  ('cool', 'want'),
#  ('want', 'ap'),
#  ('ap', 'oh'),
#  ('oh', 'man'),
#  ('man', 'micro'),
#  ('micro', 'though'),
#  ('though', 'would'),
#  ('would', 'im'),
#  ('im', 'taking'),
#  ('taking', 'calc'),
#  ('calc', 'stats'),
#  ('stats', 'oh'),
#  ('oh', 'yeah'),
#  ('yeah', 'take'),
#  ('take', 'like'),
#  ('like', 'frigging'),
#  ('frigging', 'uh'),
#  ('uh', 'wait'),
#  ('wait', 'youre'),
#  ('youre', 'taking'),
#  ('taking', 'calc'),
#  ('calc', 'stats'),
#  ('stats', 'fucking'),
#  ('fucking', 'kidding'),
#  ('kidding', 'insane'),
#  ('insane', 'insane'),
#  ('insane', 'wrong'),
#  ('wrong', 'dont'),
#  ('dont', 'know'),
#  ('know', 'dont'),
#  ('dont', 'like'),
#  ('like', 'making'),
#  ('making', 'math'),
#  ('math', 'dude'),
#  ('dude', 'math'),
#  ('math', 'like'),
#  ('like', 'nightmare'),
#  ('nightmare', 'dude'),
#  ('dude', 'dont'),
#  ('dont', 'know'),
#  ('know', 'decided'),
#  ('decided', 'also'),
#  ('also', 'take'),
#  ('take', 'english'),
#  ('english', 'social'),
#  ('social', 'science'),
#  ('science', 'wait'),
#  ('wait', 'put'),
#  ('put', 'thats'),
#  ('thats', 'okay'),
#  ('okay', 'guess'),
#  ('guess', 'agree'),
#  ('agree', 'disagree'),
#  ('disagree', 'one'),
#  ('one', 'get'),
#  ('get', 'giant'),
#  ('giant', 'fight'),
#  ('fight', 'subject'),
#  ('subject', 'better'),
#  ('better', 'fighting'),
#  ('fighting', 'like'),
#  ('like', 'horrible'),
#  ('horrible', 'rules'),
#  ('rules', 'slash'),
#  ('slash', 'social'),
#  ('social', 'sciences'),
#  ('sciences', 'worry'),
#  ('worry', 'parker'),
#  ('parker', 'let'),
#  ('let', 'tire'),
#  ('tire', 'get'),
#  ('get', 'another'),
#  ('another', 'grade'),
#  ('grade', 'yeah'),
#  ('yeah', 'get'),
#  ('get', 'gopro'),
#  ('gopro', 'get'),
#  ('get', 'gopro'),
#  ('gopro', 'gopro'),
#  ('gopro', 'yeah'),
#  ('yeah', 'theyre'),
#  ('theyre', 'really'),
#  ('really', 'nice'),
#  ('nice', 'better'),
#  ('better', 'oh'),
#  ('oh', 'really'),
#  ('really', 'dang'),
#  ('dang', 'got'),
#  ('got', 'never'),
#  ('never', 'used'),
#  ('used', 'gopro'),
#  ('gopro', 'whatd'),
#  ('whatd', 'say'),
#  ('say', 'whatd'),
#  ('whatd', 'say'),
#  ('say', 'whatd'),
#  ('whatd', 'say'),
#  ('say', 'said'),
#  ('said', 'better'),
#  ('better', 'dont'),
#  ('dont', 'know'),
#  ('know', 'though'),
#  ('though', 'headstripe'),
#  ('headstripe', 'though'),
#  ('though', 'looks'),
#  ('looks', 'little'),
#  ('little', 'excessive'),
#  ('excessive', 'head'),
#  ('head', 'strap'),
#  ('strap', 'bigger'),
#  ('bigger', 'actual'),
#  ('actual', 'camera'),
#  ('camera', 'bigger'),
#  ('bigger', 'oh'),
#  ('oh', 'never'),
#  ('never', 'mind'),
#  ('mind', 'thought'),
#  ('thought', 'like'),
#  ('like', 'dont'),
#  ('dont', 'know'),
#  ('know', 'last'),
#  ('last', 'time'),
#  ('time', 'saw'),
#  ('saw', 'like'),
#  ('like', 'little'),
#  ('little', 'cubes'),
#  ('cubes', 'something'),
#  ('something', 'friend'),
#  ('friend', 'head'),
#  ('head', 'camera'),
#  ('camera', 'gopro'),
#  ('gopro', 'like'),
#  ('like', 'big'),
#  ('big', 'really'),
#  ('really', 'nice'),
#  ('nice', 'friends'),
#  ('friends', 'really'),
#  ('really', 'ghetto'),
#  ('ghetto', 'paintball'),
#  ('paintball', 'trip'),
#  ('trip', 'tie'),
#  ('tie', 'camcorder'),
#  ('camcorder', 'head'),
#  ('head', 'piece'),
#  ('piece', 'string'),
#  ('string', 'another'),
#  ('another', 'time'),
#  ('time', 'like'),
#  ('like', 'hang'),
#  ('hang', 'camera'),
#  ('camera', 'string'),
#  ('string', 'gun'),
#  ('gun', 'string'),
#  ('string', 'barrel'),
#  ('barrel', 'string'),
#  ('string', 'ive'),
#  ('ive', 'seen'),
#  ('seen', 'better'),
#  ('better', 'oh'),
#  ('oh', 'dang'),
#  ('dang', 'im'),
#  ('im', 'carrying'),
#  ('carrying', 'desk'),
#  ('desk', 'okay'),
#  ('okay', 'think'),
#  ('think', 'looks'),
#  ('looks', 'alright'),
#  ('alright', 'sell'),
#  ('sell', 'ebay'),
#  ('ebay', 'end'),
#  ('end', 'period'),
#  ('period', 'craigslist'),
#  ('craigslist', 'theres'),
#  ('theres', 'couple'),
#  ('couple', 'oh'),
#  ('oh', 'apparently'),
#  ('apparently', 'craigslist'),
#  ('craigslist', 'stupid'),
#  ('stupid', 'ridiculous'),
#  ('ridiculous', 'put'),
#  ('put', 'dot'),
#  ('dot', 'like'),
#  ('like', 'negative'),
#  ('negative', 'dot'),
#  ('dot', 'derivative'),
#  ('derivative', 'behind'),
#  ('behind', 'negative'),
#  ('negative', 'negative'),
#  ('negative', 'negative'),
#  ('negative', 'positive'),
#  ('positive', 'oh'),
#  ('oh', 'yeah'),
#  ('yeah', 'positive'),
#  ('positive', 'guess'),
#  ('guess', 'line'),
#  ('line', 'already'),
#  ('already', 'crosses'),
#  ('crosses', 'makes'),
#  ('makes', 'clearer'),
#  ('clearer', 'let'),
#  ('let', 'us'),
#  ('us', 'thats'),
#  ('thats', 'okay'),
#  ('okay', 'lets'),
#  ('lets', 'hear'),
#  ('hear', 'thought'),
#  ('thought', 'process'),
#  ('process', 'hold'),
#  ('hold', 'stand'),
#  ('stand', 'please'),
#  ('please', 'stand'),
#  ('stand', 'stand'),
#  ('stand', 'stand'),
#  ('stand', 'like'),
#  ('like', 'gabriel'),
#  ('gabriel', 'us'),
#  ('us', 'see'),
#  ('see', 'graph'),
#  ('graph', 'put'),
#  ('put', 'arms'),
#  ('arms', 'way'),
#  ('way', 'alright'),
#  ('alright', 'question'),
#  ('question', 'havent'),
#  ('havent', 'even'),
#  ('even', 'presented'),
#  ('presented', 'anything'),
#  ('anything', 'yet'),
#  ('yet', 'talk'),
#  ('talk', 'us'),
#  ('us', 'thinking'),
#  ('thinking', 'supposed'),
#  ('supposed', 'graphed'),
#  ('graphed', 'supposed'),
#  ('supposed', 'something'),
#  ('something', 'graphed'),
#  ('graphed', 'function'),
#  ('function', 'multiple'),
#  ('multiple', 'three'),
#  ('three', 'intercepts'),
#  ('intercepts', 'doesnt'),
#  ('doesnt', 'lets'),
#  ('lets', 'make'),
#  ('make', 'answerable'),
#  ('answerable', 'question'),
#  ('question', 'least'),
#  ('least', 'one'),
#  ('one', 'might'),
#  ('might', 'opinion'),
#  ('opinion', 'yes'),
#  ('yes', 'sure'),
#  ('sure', 'think'),
#  ('think', 'talked'),
#  ('talked', 'last'),
#  ('last', 'class'),
#  ('class', 'fourth'),
#  ('fourth', 'order'),
#  ('order', 'think'),
#  ('think', 'tennessee'),
#  ('tennessee', 'going'),
#  ('going', 'get'),
#  ('get', 'quadratic'),
#  ('quadratic', 'function'),
#  ('function', 'get'),
#  ('get', 'linear'),
#  ('linear', 'graph'),
#  ('graph', 'kind'),
#  ('kind', 'makes'),
#  ('makes', 'sense'),
#  ('sense', 'would'),
#  ('would', 'would'),
#  ('would', 'interested'),
#  ('interested', 'hear'),
#  ('hear', 'two'),
#  ('two', 'show'),
#  ('show', 'us'),
#  ('us', 'boards'),
#  ('boards', 'two'),
#  ('two', 'groups'),
#  ('groups', 'kind'),
#  ('kind', 'little'),
#  ('little', 'boxing'),
#  ('boxing', 'ring'),
#  ('ring', 'go'),
#  ('go', 'around'),
#  ('around', 'right'),
#  ('right', 'zigzag'),
#  ('zigzag', 'im'),
#  ('im', 'curious'),
#  ('curious', 'hear'),
#  ('hear', 'think'),
#  ('think', 'group'),
#  ('group', 'hotline'),
#  ('hotline', 'number'),
#  ('number', 'jizz'),
#  ('jizz', 'four'),
#  ('four', 'people'),
#  ('people', 'crazy'),
#  ('crazy', 'yes'),
#  ('yes', 'yes'),
#  ('yes', 'four'),
#  ('four', 'thinking'),
#  ('thinking', 'think'),
#  ('think', 'three'),
#  ('three', 'increase'),
#  ('increase', 'kind'),
#  ('kind', 'linearly'),
#  ('linearly', 'ok'),
#  ('ok', 'want'),
#  ('want', 'change'),
#  ('change', 'back'),
#  ('back', 'yeah'),
#  ('yeah', 'like'),
#  ('like', 'linear'),
#  ('linear', 'derivative'),
#  ('derivative', 'negative'),
#  ('negative', 'gets'),
#  ('gets', 'negative'),
#  ('negative', 'right'),
#  ('right', 'thats'),
#  ('thats', 'goes'),
#  ('goes', 'starts'),
#  ('starts', 'wanna'),
#  ('wanna', 'like'),
#  ('like', 'fuck'),
#  ('fuck', 'uh'),
#  ('uh', 'fuck'),
#  ('fuck', 'explain'),
#  ('explain', 'explain'),
#  ('explain', 'okay'),
#  ('okay', 'get'),
#  ('get', 'called'),
#  ('called', 'explain'),
#  ('explain', 'okay'),
#  ('okay', 'like'),
#  ('like', 'wait'),
#  ('wait', 'youre'),
#  ('youre', 'saying'),
#  ('saying', 'reason'),
#  ('reason', 'went'),
#  ('went', 'stopped'),
#  ('stopped', 'something'),
#  ('something', 'started'),
#  ('started', 'went'),
#  ('went', 'want'),
#  ('want', 'change'),
#  ('change', 'something'),
#  ('something', 'else'),
#  ('else', 'cant'),
#  ('cant', 'make'),
#  ('make', 'hidden'),
#  ('hidden', 'know'),
#  ('know', 'shouldnt'),
#  ('shouldnt', 'side'),
#  ('side', 'slip'),
#  ('slip', 'positive'),
#  ('positive', 'actual'),
#  ('actual', 'values'),
#  ('values', 'arent'),
#  ('arent', 'positive'),
#  ('positive', 'values'),
#  ('values', 'derivative'),
#  ('derivative', 'positive'),
#  ('positive', 'shouldnt'),
#  ('shouldnt', 'arent'),
#  ('arent', 'values'),
#  ('values', 'derivative'),
#  ('derivative', 'negative'),
#  ('negative', 'values'),
#  ('values', 'derivative'),
#  ('derivative', 'negative'),
#  ('negative', 'going'),
#  ('going', 'oh'),
#  ('oh', 'right'),
#  ('right', 'im'),
#  ('im', 'sorry'),
#  ('sorry', 'thats'),
#  ('thats', 'bad'),
#  ('bad', 'theyre'),
#  ('theyre', 'decreasing'),
#  ('decreasing', 'right'),
#  ('right', 'yeah'),
#  ('yeah', 'youre'),
#  ('youre', 'right'),
#  ('right', 'think'),
#  ('think', 'well'),
#  ('well', 'convinced'),
#  ('convinced', 'group'),
#  ('group', 'least'),
#  ('least', 'dont'),
#  ('dont', 'think'),
#  ('think', 'youve'),
#  ('youve', 'convinced'),
#  ('convinced', 'two'),
#  ('two', 'im'),
#  ('im', 'sure'),
#  ('sure', 'group'),
#  ('group', 'lets'),
#  ('lets', 'go'),
#  ('go', 'back'),
#  ('back', 'general'),
#  ('general', 'like'),
#  ('like', 'kind'),
#  ('kind', 'mentioned'),
#  ('mentioned', 'gabriel'),
#  ('gabriel', 'said'),
#  ('said', 'graphed'),
#  ('graphed', 'intercepts'),
#  ('intercepts', 'heard'),
#  ('heard', 'discussions'),
#  ('discussions', 'know'),
#  ('know', 'side'),
#  ('side', 'xaxis'),
#  ('xaxis', 'start'),
#  ('start', 'us'),
#  ('us', 'kind'),
#  ('kind', 'work'),
#  ('work', 'well'),
#  ('well', 'weve'),
#  ('weve', 'got'),
#  ('got', 'options'),
#  ('options', 'tell'),
#  ('tell', 'derivative'),
#  ('derivative', 'zero'),
#  ('zero', 'negative'),
#  ('negative', 'positive'),
#  ('positive', 'need'),
#  ('need', 'follow'),
#  ('follow', 'directions'),
#  ('directions', 'need'),
#  ('need', 'talked'),
#  ('talked', 'last'),
#  ('last', 'class'),
#  ('class', 'little'),
#  ('little', 'bit'),
#  ('bit', 'derivative'),
#  ('derivative', 'function'),
#  ...]

# %%
Teacher1Transcript_trigrams = list(nltk.trigrams(cleanedTeacher1Transcript))
Teacher1Transcript_trigrams
# Out:
# [('like', 'im', 'one'),
#  ('im', 'one', 'chair'),
#  ('one', 'chair', 'people'),
#  ('chair', 'people', 'oh'),
#  ('people', 'oh', 'really'),
#  ('oh', 'really', 'also'),
#  ('really', 'also', 'ready'),
#  ('also', 'ready', 'faces'),
#  ('ready', 'faces', 'swimming'),
#  ('faces', 'swimming', 'faces'),
#  ('swimming', 'faces', 'good'),
#  ('faces', 'good', 'facials'),
#  ('good', 'facials', 'okay'),
#  ('facials', 'okay', 'shut'),
#  ('okay', 'shut', 'never'),
#  ('shut', 'never', 'ever'),
#  ('never', 'ever', 'say'),
#  ('ever', 'say', 'im'),
#  ('say', 'im', 'gonna'),
#  ('im', 'gonna', 'creepy'),
#  ('gonna', 'creepy', 'hes'),
#  ('creepy', 'hes', 'gonna'),
#  ('hes', 'gonna', 'die'),
#  ('gonna', 'die', 'youre'),
#  ('die', 'youre', 'gonna'),
#  ('youre', 'gonna', 'die'),
#  ('gonna', 'die', 'food'),
#  ('die', 'food', 'uh'),
#  ('food', 'uh', 'yeah'),
#  ('uh', 'yeah', 'fine'),
#  ('yeah', 'fine', 'go'),
#  ('fine', 'go', 'away'),
#  ('go', 'away', 'coffee'),
#  ('away', 'coffee', 'dont'),
#  ('coffee', 'dont', 'cheese'),
#  ('dont', 'cheese', 'coffee'),
#  ('cheese', 'coffee', 'hes'),
#  ('coffee', 'hes', 'today'),
#  ('hes', 'today', 'hes'),
#  ('today', 'hes', 'gonna'),
#  ('hes', 'gonna', 'bald'),
#  ('gonna', 'bald', 'head'),
#  ('bald', 'head', 'hes'),
#  ('head', 'hes', 'today'),
#  ('hes', 'today', 'hes'),
#  ('today', 'hes', 'gonna'),
#  ('hes', 'gonna', 'shaved'),
#  ('gonna', 'shaved', 'head'),
#  ('shaved', 'head', 'oh'),
#  ('head', 'oh', 'yeah'),
#  ('oh', 'yeah', 'requested'),
#  ('yeah', 'requested', 'permission'),
#  ('requested', 'permission', 'wear'),
#  ('permission', 'wear', 'hat'),
#  ('wear', 'hat', 'trade'),
#  ('hat', 'trade', 'year'),
#  ('trade', 'year', 'maybe'),
#  ('year', 'maybe', 'hes'),
#  ('maybe', 'hes', 'oh'),
#  ('hes', 'oh', 'everyone'),
#  ('oh', 'everyone', 'shaved'),
#  ('everyone', 'shaved', 'heads'),
#  ('shaved', 'heads', 'yeah'),
#  ('heads', 'yeah', 'swimming'),
#  ('yeah', 'swimming', 'thought'),
#  ('swimming', 'thought', 'cancer'),
#  ('thought', 'cancer', 'something'),
#  ('cancer', 'something', 'thats'),
#  ('something', 'thats', 'said'),
#  ('thats', 'said', 'last'),
#  ('said', 'last', 'week'),
#  ('last', 'week', 'yeah'),
#  ('week', 'yeah', 'know'),
#  ('yeah', 'know', 'wow'),
#  ('know', 'wow', 'oh'),
#  ('wow', 'oh', 'drake'),
#  ('oh', 'drake', 'mean'),
#  ('drake', 'mean', 'uh'),
#  ('mean', 'uh', 'precoc'),
#  ('uh', 'precoc', 'im'),
#  ('precoc', 'im', 'gonna'),
#  ('im', 'gonna', 'go'),
#  ('gonna', 'go', 'reach'),
#  ('go', 'reach', 'presents'),
#  ('reach', 'presents', 'seriously'),
#  ('presents', 'seriously', 'next'),
#  ('seriously', 'next', 'time'),
#  ('next', 'time', 'cause'),
#  ('time', 'cause', 'seriously'),
#  ('cause', 'seriously', 'really'),
#  ('seriously', 'really', 'bad'),
#  ('really', 'bad', 'one'),
#  ('bad', 'one', 'seriously'),
#  ('one', 'seriously', 'promise'),
#  ('seriously', 'promise', 'ill'),
#  ('promise', 'ill', 'next'),
#  ('ill', 'next', 'time'),
#  ('next', 'time', 'really'),
#  ('time', 'really', 'bad'),
#  ('really', 'bad', 'one'),
#  ('bad', 'one', 'im'),
#  ('one', 'im', 'dont'),
#  ('im', 'dont', 'really'),
#  ('dont', 'really', 'care'),
#  ('really', 'care', 'eight'),
#  ('care', 'eight', 'five'),
#  ('eight', 'five', 'eight'),
#  ('five', 'eight', 'five'),
#  ('eight', 'five', 'eight'),
#  ('five', 'eight', 'sure'),
#  ('eight', 'sure', 'going'),
#  ('sure', 'going', 'take'),
#  ('going', 'take', 'back'),
#  ('take', 'back', 'easy'),
#  ('back', 'easy', 'really'),
#  ('easy', 'really', 'easy'),
#  ('really', 'easy', 'nah'),
#  ('easy', 'nah', 'seriously'),
#  ('nah', 'seriously', 'nah'),
#  ('seriously', 'nah', 'seriously'),
#  ('nah', 'seriously', 'ill'),
#  ('seriously', 'ill', 'thursday'),
#  ('ill', 'thursday', 'seriously'),
#  ('thursday', 'seriously', 'dont'),
#  ('seriously', 'dont', 'want'),
#  ('dont', 'want', 'today'),
#  ('want', 'today', 'please'),
#  ('today', 'please', 'really'),
#  ('please', 'really', 'easy'),
#  ('really', 'easy', 'put'),
#  ('easy', 'put', 'number'),
#  ('put', 'number', 'put'),
#  ('number', 'put', 'number'),
#  ('put', 'number', 'number'),
#  ('number', 'number', 'im'),
#  ('number', 'im', 'okay'),
#  ('im', 'okay', 'number'),
#  ('okay', 'number', 'get'),
#  ('number', 'get', 'times'),
#  ('get', 'times', 'wrong'),
#  ('times', 'wrong', 'im'),
#  ('wrong', 'im', 'pretty'),
#  ('im', 'pretty', 'sure'),
#  ('pretty', 'sure', 'instead'),
#  ('sure', 'instead', 'divide'),
#  ('instead', 'divide', 'doesnt'),
#  ('divide', 'doesnt', 'make'),
#  ('doesnt', 'make', 'sense'),
#  ('make', 'sense', 'think'),
#  ('sense', 'think', 'yeah'),
#  ('think', 'yeah', 'wrong'),
#  ('yeah', 'wrong', 'yeah'),
#  ('wrong', 'yeah', 'got'),
#  ('yeah', 'got', 'wrong'),
#  ('got', 'wrong', 'man'),
#  ('wrong', 'man', 'hold'),
#  ('man', 'hold', 'im'),
#  ('hold', 'im', 'going'),
#  ('im', 'going', 'go'),
#  ('going', 'go', 'ahead'),
#  ('go', 'ahead', 'get'),
#  ('ahead', 'get', 'wait'),
#  ('get', 'wait', 'dont'),
#  ('wait', 'dont', 'pan'),
#  ('dont', 'pan', 'nobodys'),
#  ('pan', 'nobodys', 'panning'),
#  ('nobodys', 'panning', 'run'),
#  ('panning', 'run', 'italy'),
#  ('run', 'italy', 'cant'),
#  ('italy', 'cant', 'seem'),
#  ('cant', 'seem', 'find'),
#  ('seem', 'find', 'class'),
#  ('find', 'class', 'hennigans'),
#  ('class', 'hennigans', 'dont'),
#  ('hennigans', 'dont', 'know'),
#  ('dont', 'know', 'one'),
#  ('know', 'one', 'following'),
#  ('one', 'following', 'chance'),
#  ('following', 'chance', 'actually'),
#  ('chance', 'actually', 'make'),
#  ('actually', 'make', 'sure'),
#  ('make', 'sure', 'get'),
#  ('sure', 'get', 'stuff'),
#  ('get', 'stuff', 'yeah'),
#  ('stuff', 'yeah', 'yeah'),
#  ('yeah', 'yeah', 'act'),
#  ('yeah', 'act', 'somebody'),
#  ('act', 'somebody', 'right'),
#  ('somebody', 'right', 'alright'),
#  ('right', 'alright', 'um'),
#  ('alright', 'um', 'list'),
#  ('um', 'list', 'lets'),
#  ('list', 'lets', 'see'),
#  ('lets', 'see', 'thank'),
#  ('see', 'thank', 'look'),
#  ('thank', 'look', 'nothing'),
#  ('look', 'nothing', 'special'),
#  ('nothing', 'special', 'quick'),
#  ('special', 'quick', 'lap'),
#  ('quick', 'lap', 'good'),
#  ('lap', 'good', 'really'),
#  ('good', 'really', 'meant'),
#  ('really', 'meant', 'lets'),
#  ('meant', 'lets', 'label'),
#  ('lets', 'label', 'xaxis'),
#  ('label', 'xaxis', 'yaxis'),
#  ('xaxis', 'yaxis', 'need'),
#  ('yaxis', 'need', 'labeled'),
#  ('need', 'labeled', 'want'),
#  ('labeled', 'want', 'important'),
#  ('want', 'important', 'think'),
#  ('important', 'think', 'well'),
#  ('think', 'well', 'x'),
#  ('well', 'x', 'soon'),
#  ('x', 'soon', 'comes'),
#  ('soon', 'comes', 'okay'),
#  ('comes', 'okay', 'lets'),
#  ('okay', 'lets', 'negative'),
#  ('lets', 'negative', 'negative'),
#  ('negative', 'negative', 'negative'),
#  ('negative', 'negative', 'okay'),
#  ('negative', 'okay', 'work'),
#  ('okay', 'work', 'together'),
#  ('work', 'together', 'sure'),
#  ('together', 'sure', 'mathematical'),
#  ('sure', 'mathematical', 'notation'),
#  ('mathematical', 'notation', 'mean'),
#  ('notation', 'mean', 'think'),
#  ('mean', 'think', 'want'),
#  ('think', 'want', 'equality'),
#  ('want', 'equality', 'dont'),
#  ('equality', 'dont', 'want'),
#  ('dont', 'want', 'leave'),
#  ('want', 'leave', 'one'),
#  ('leave', 'one', 'x'),
#  ('one', 'x', 'equal'),
#  ('x', 'equal', 'look'),
#  ('equal', 'look', 'theyre'),
#  ('look', 'theyre', 'calculus'),
#  ('theyre', 'calculus', 'folder'),
#  ('calculus', 'folder', 'graded'),
#  ('folder', 'graded', 'want'),
#  ('graded', 'want', 'grade'),
#  ('want', 'grade', 'operate'),
#  ('grade', 'operate', 'really'),
#  ('operate', 'really', 'needs'),
#  ('really', 'needs', 'get'),
#  ('needs', 'get', 'gopro'),
#  ('get', 'gopro', 'really'),
#  ('gopro', 'really', 'needs'),
#  ('really', 'needs', 'get'),
#  ('needs', 'get', 'gopro'),
#  ('get', 'gopro', 'looks'),
#  ('gopro', 'looks', 'like'),
#  ('looks', 'like', 'might'),
#  ('like', 'might', 'need'),
#  ('might', 'need', 'little'),
#  ('need', 'little', 'recursion'),
#  ('little', 'recursion', 'write'),
#  ('recursion', 'write', 'inequalities'),
#  ('write', 'inequalities', 'tell'),
#  ('inequalities', 'tell', 'inequality'),
#  ('tell', 'inequality', 'oh'),
#  ('inequality', 'oh', 'theres'),
#  ('oh', 'theres', 'typo'),
#  ('theres', 'typo', 'didnt'),
#  ('typo', 'didnt', 'see'),
#  ('didnt', 'see', 'one'),
#  ('see', 'one', 'positive'),
#  ('one', 'positive', 'right'),
#  ('positive', 'right', 'someone'),
#  ('right', 'someone', 'noble'),
#  ('someone', 'noble', 'mean'),
#  ('noble', 'mean', 'makes'),
#  ('mean', 'makes', 'sense'),
#  ('makes', 'sense', 'maybe'),
#  ('sense', 'maybe', 'ill'),
#  ('maybe', 'ill', 'take'),
#  ('ill', 'take', 'f'),
#  ('take', 'f', 'prime'),
#  ('f', 'prime', 'know'),
#  ('prime', 'know', 'somebody'),
#  ('know', 'somebody', 'come'),
#  ('somebody', 'come', 'mark'),
#  ('come', 'mark', 'graph'),
#  ('mark', 'graph', 'show'),
#  ('graph', 'show', 'us'),
#  ('show', 'us', 'visually'),
#  ('us', 'visually', 'come'),
#  ('visually', 'come', 'show'),
#  ('come', 'show', 'us'),
#  ('show', 'us', 'yeah'),
#  ('us', 'yeah', 'positive'),
#  ('yeah', 'positive', 'negative'),
#  ('positive', 'negative', 'squared'),
#  ('negative', 'squared', 'says'),
#  ('squared', 'says', 'okay'),
#  ('says', 'okay', 'perfect'),
#  ('okay', 'perfect', 'think'),
#  ('perfect', 'think', 'well'),
#  ('think', 'well', 'see'),
#  ('well', 'see', 'im'),
#  ('see', 'im', 'pretty'),
#  ('im', 'pretty', 'sure'),
#  ('pretty', 'sure', 'papers'),
#  ('sure', 'papers', 'us'),
#  ('papers', 'us', 'use'),
#  ('us', 'use', 'pluses'),
#  ('use', 'pluses', 'minuses'),
#  ('pluses', 'minuses', 'like'),
#  ('minuses', 'like', 'good'),
#  ('like', 'good', 'clear'),
#  ('good', 'clear', 'whats'),
#  ('clear', 'whats', 'going'),
#  ('whats', 'going', 'see'),
#  ('going', 'see', 'derivative'),
#  ('see', 'derivative', 'greater'),
#  ('derivative', 'greater', 'zero'),
#  ('greater', 'zero', 'values'),
#  ('zero', 'values', 'x'),
#  ('values', 'x', 'correspond'),
#  ('x', 'correspond', 'mackenzie'),
#  ('correspond', 'mackenzie', 'x'),
#  ('mackenzie', 'x', 'greater'),
#  ('x', 'greater', 'negative'),
#  ('greater', 'negative', 'less'),
#  ('negative', 'less', 'negative'),
#  ('less', 'negative', 'thats'),
#  ('negative', 'thats', 'two'),
#  ('thats', 'two', 'numbers'),
#  ('two', 'numbers', 'derivative'),
#  ('numbers', 'derivative', 'positive'),
#  ('derivative', 'positive', 'concur'),
#  ('positive', 'concur', 'write'),
#  ('concur', 'write', 'words'),
#  ('write', 'words', 'x'),
#  ('words', 'x', 'negative'),
#  ('x', 'negative', 'lower'),
#  ('negative', 'lower', 'number'),
#  ('lower', 'number', 'goes'),
#  ('number', 'goes', 'left'),
#  ('goes', 'left', 'like'),
#  ('left', 'like', 'youre'),
#  ('like', 'youre', 'reading'),
#  ('youre', 'reading', 'left'),
#  ('reading', 'left', 'right'),
#  ('left', 'right', 'higher'),
#  ('right', 'higher', 'number'),
#  ('higher', 'number', 'goes'),
#  ('number', 'goes', 'right'),
#  ('goes', 'right', 'put'),
#  ('right', 'put', 'x'),
#  ('put', 'x', 'else'),
#  ('x', 'else', 'gina'),
#  ('else', 'gina', 'labeled'),
#  ('gina', 'labeled', 'ok'),
#  ('labeled', 'ok', 'fair'),
#  ('ok', 'fair', 'enough'),
#  ('fair', 'enough', 'thats'),
#  ('enough', 'thats', 'greater'),
#  ('thats', 'greater', 'help'),
#  ('greater', 'help', 'model'),
#  ('help', 'model', 'fill'),
#  ('model', 'fill', 'ok'),
#  ('fill', 'ok', 'lets'),
#  ('ok', 'lets', 'finish'),
#  ('lets', 'finish', 'first'),
#  ('finish', 'first', 'half'),
#  ('first', 'half', 'least'),
#  ('half', 'least', 'get'),
#  ('least', 'get', 'explanations'),
#  ('get', 'explanations', 'ah'),
#  ('explanations', 'ah', 'darn'),
#  ('ah', 'darn', 'make'),
#  ('darn', 'make', 'sure'),
#  ('make', 'sure', 'comparing'),
#  ('sure', 'comparing', 'answers'),
#  ('comparing', 'answers', 'please'),
#  ('answers', 'please', 'okay'),
#  ('please', 'okay', 'somebody'),
#  ('okay', 'somebody', 'please'),
#  ('somebody', 'please', 'come'),
#  ('please', 'come', 'finish'),
#  ('come', 'finish', 'statements'),
#  ('finish', 'statements', 'one'),
#  ('statements', 'one', 'person'),
#  ('one', 'person', 'one'),
#  ('person', 'one', 'another'),
#  ('one', 'another', 'another'),
#  ('another', 'another', 'join'),
#  ('another', 'join', 'oh'),
#  ('join', 'oh', 'scissors'),
#  ('oh', 'scissors', 'established'),
#  ('scissors', 'established', 'around'),
#  ('established', 'around', 'books'),
#  ('around', 'books', 'thank'),
#  ('books', 'thank', 'thank'),
#  ('thank', 'thank', 'destiny'),
#  ('thank', 'destiny', 'well'),
#  ('destiny', 'well', 'yet'),
#  ('well', 'yet', 'another'),
#  ('yet', 'another', 'case'),
#  ('another', 'case', 'men'),
#  ('case', 'men', 'sit'),
#  ('men', 'sit', 'discuss'),
#  ('sit', 'discuss', 'something'),
#  ('discuss', 'something', 'woman'),
#  ('something', 'woman', 'gets'),
#  ('woman', 'gets', 'goes'),
#  ('gets', 'goes', 'action'),
#  ('goes', 'action', 'agree'),
#  ('action', 'agree', 'theres'),
#  ('agree', 'theres', 'lower'),
#  ('theres', 'lower', 'number'),
#  ('lower', 'number', 'left'),
#  ('number', 'left', 'higher'),
#  ('left', 'higher', 'number'),
#  ('higher', 'number', 'right'),
#  ('number', 'right', 'agree'),
#  ('right', 'agree', 'mike'),
#  ('agree', 'mike', 'looks'),
#  ('mike', 'looks', 'pretty'),
#  ('looks', 'pretty', 'good'),
#  ('pretty', 'good', 'love'),
#  ('good', 'love', 'ok'),
#  ('love', 'ok', 'christian'),
#  ('ok', 'christian', 'know'),
#  ('christian', 'know', 'derivative'),
#  ('know', 'derivative', 'okay'),
#  ('derivative', 'okay', 'ruben'),
#  ('okay', 'ruben', 'describe'),
#  ('ruben', 'describe', 'know'),
#  ('describe', 'know', 'derivative'),
#  ('know', 'derivative', 'zero'),
#  ('derivative', 'zero', 'guess'),
#  ('zero', 'guess', 'one'),
#  ('guess', 'one', 'thing'),
#  ('one', 'thing', 'going'),
#  ('thing', 'going', 'right'),
#  ('going', 'right', 'vertex'),
#  ('right', 'vertex', 'ok'),
#  ('vertex', 'ok', 'good'),
#  ('ok', 'good', 'good'),
#  ('good', 'good', 'ways'),
#  ('good', 'ways', 'explaining'),
#  ('ways', 'explaining', 'know'),
#  ('explaining', 'know', 'derivative'),
#  ('know', 'derivative', 'tangent'),
#  ('derivative', 'tangent', 'line'),
#  ('tangent', 'line', 'right'),
#  ('line', 'right', 'right'),
#  ('right', 'right', 'good'),
#  ('right', 'good', 'right'),
#  ('good', 'right', 'good'),
#  ('right', 'good', 'thats'),
#  ('good', 'thats', 'kind'),
#  ('thats', 'kind', 'technical'),
#  ('kind', 'technical', 'definition'),
#  ('technical', 'definition', 'slope'),
#  ('definition', 'slope', 'tangent'),
#  ('slope', 'tangent', 'line'),
#  ('tangent', 'line', 'equal'),
#  ('line', 'equal', 'zero'),
#  ('equal', 'zero', 'excuse'),
#  ('zero', 'excuse', 'know'),
#  ('excuse', 'know', 'negative'),
#  ('know', 'negative', 'slope'),
#  ('negative', 'slope', 'tangent'),
#  ('slope', 'tangent', 'line'),
#  ('tangent', 'line', 'negative'),
#  ('line', 'negative', 'ok'),
#  ('negative', 'ok', 'sure'),
#  ('ok', 'sure', 'fair'),
#  ('sure', 'fair', 'enough'),
#  ('fair', 'enough', 'course'),
#  ('enough', 'course', 'positive'),
#  ('course', 'positive', 'youre'),
#  ('positive', 'youre', 'going'),
#  ('youre', 'going', 'keep'),
#  ('going', 'keep', 'using'),
#  ('keep', 'using', 'bet'),
#  ('using', 'bet', 'youre'),
#  ('bet', 'youre', 'going'),
#  ('youre', 'going', 'say'),
#  ('going', 'say', 'thing'),
#  ('say', 'thing', 'slope'),
#  ('thing', 'slope', 'tangent'),
#  ('slope', 'tangent', 'line'),
#  ('tangent', 'line', 'positive'),
#  ('line', 'positive', 'right'),
#  ('positive', 'right', 'fine'),
#  ('right', 'fine', 'fine'),
#  ('fine', 'fine', 'curve'),
#  ('fine', 'curve', 'headed'),
#  ('curve', 'headed', 'positive'),
#  ('headed', 'positive', 'direction'),
#  ('positive', 'direction', 'thats'),
#  ('direction', 'thats', 'interesting'),
#  ('thats', 'interesting', 'curve'),
#  ('interesting', 'curve', 'headed'),
#  ('curve', 'headed', 'positive'),
#  ('headed', 'positive', 'direction'),
#  ('positive', 'direction', 'yeah'),
#  ('direction', 'yeah', 'ok'),
#  ('yeah', 'ok', 'like'),
#  ('ok', 'like', 'right'),
#  ('like', 'right', 'id'),
#  ('right', 'id', 'like'),
#  ('id', 'like', 'send'),
#  ('like', 'send', 'one'),
#  ('send', 'one', 'person'),
#  ('one', 'person', 'back'),
#  ('person', 'back', 'get'),
#  ('back', 'get', 'whiteboard'),
#  ('get', 'whiteboard', 'another'),
#  ('whiteboard', 'another', 'person'),
#  ('another', 'person', 'forwards'),
#  ('person', 'forwards', 'get'),
#  ('forwards', 'get', 'marker'),
#  ('get', 'marker', 'group'),
#  ('marker', 'group', 'make'),
#  ('group', 'make', 'graph'),
#  ('make', 'graph', 'derivative'),
#  ('graph', 'derivative', 'function'),
#  ('derivative', 'function', 'physics'),
#  ('function', 'physics', 'horrible'),
#  ('physics', 'horrible', 'im'),
#  ('horrible', 'im', 'trying'),
#  ('im', 'trying', 'resist'),
#  ('trying', 'resist', 'want'),
#  ('resist', 'want', 'graph'),
#  ('want', 'graph', 'copy'),
#  ('graph', 'copy', 'oh'),
#  ('copy', 'oh', 'man'),
#  ('oh', 'man', 'get'),
#  ('man', 'get', 'better'),
#  ('get', 'better', 'ill'),
#  ('better', 'ill', 'go'),
#  ('ill', 'go', 'get'),
#  ('go', 'get', 'better'),
#  ('get', 'better', 'mic'),
#  ('better', 'mic', 'working'),
#  ('mic', 'working', 'sorry'),
#  ('working', 'sorry', 'cool'),
#  ('sorry', 'cool', 'please'),
#  ('cool', 'please', 'bet'),
#  ('please', 'bet', 'taking'),
#  ('bet', 'taking', 'ap'),
#  ('taking', 'ap', 'social'),
#  ('ap', 'social', 'science'),
#  ('social', 'science', 'class'),
#  ('science', 'class', 'next'),
#  ('class', 'next', 'year'),
#  ('next', 'year', 'social'),
#  ('year', 'social', 'science'),
#  ('social', 'science', 'taking'),
#  ('science', 'taking', 'next'),
#  ('taking', 'next', 'year'),
#  ('next', 'year', 'sociality'),
#  ('year', 'sociality', 'sociality'),
#  ('sociality', 'sociality', 'sounds'),
#  ('sociality', 'sounds', 'cool'),
#  ('sounds', 'cool', 'want'),
#  ('cool', 'want', 'ap'),
#  ('want', 'ap', 'oh'),
#  ('ap', 'oh', 'man'),
#  ('oh', 'man', 'micro'),
#  ('man', 'micro', 'though'),
#  ('micro', 'though', 'would'),
#  ('though', 'would', 'im'),
#  ('would', 'im', 'taking'),
#  ('im', 'taking', 'calc'),
#  ('taking', 'calc', 'stats'),
#  ('calc', 'stats', 'oh'),
#  ('stats', 'oh', 'yeah'),
#  ('oh', 'yeah', 'take'),
#  ('yeah', 'take', 'like'),
#  ('take', 'like', 'frigging'),
#  ('like', 'frigging', 'uh'),
#  ('frigging', 'uh', 'wait'),
#  ('uh', 'wait', 'youre'),
#  ('wait', 'youre', 'taking'),
#  ('youre', 'taking', 'calc'),
#  ('taking', 'calc', 'stats'),
#  ('calc', 'stats', 'fucking'),
#  ('stats', 'fucking', 'kidding'),
#  ('fucking', 'kidding', 'insane'),
#  ('kidding', 'insane', 'insane'),
#  ('insane', 'insane', 'wrong'),
#  ('insane', 'wrong', 'dont'),
#  ('wrong', 'dont', 'know'),
#  ('dont', 'know', 'dont'),
#  ('know', 'dont', 'like'),
#  ('dont', 'like', 'making'),
#  ('like', 'making', 'math'),
#  ('making', 'math', 'dude'),
#  ('math', 'dude', 'math'),
#  ('dude', 'math', 'like'),
#  ('math', 'like', 'nightmare'),
#  ('like', 'nightmare', 'dude'),
#  ('nightmare', 'dude', 'dont'),
#  ('dude', 'dont', 'know'),
#  ('dont', 'know', 'decided'),
#  ('know', 'decided', 'also'),
#  ('decided', 'also', 'take'),
#  ('also', 'take', 'english'),
#  ('take', 'english', 'social'),
#  ('english', 'social', 'science'),
#  ('social', 'science', 'wait'),
#  ('science', 'wait', 'put'),
#  ('wait', 'put', 'thats'),
#  ('put', 'thats', 'okay'),
#  ('thats', 'okay', 'guess'),
#  ('okay', 'guess', 'agree'),
#  ('guess', 'agree', 'disagree'),
#  ('agree', 'disagree', 'one'),
#  ('disagree', 'one', 'get'),
#  ('one', 'get', 'giant'),
#  ('get', 'giant', 'fight'),
#  ('giant', 'fight', 'subject'),
#  ('fight', 'subject', 'better'),
#  ('subject', 'better', 'fighting'),
#  ('better', 'fighting', 'like'),
#  ('fighting', 'like', 'horrible'),
#  ('like', 'horrible', 'rules'),
#  ('horrible', 'rules', 'slash'),
#  ('rules', 'slash', 'social'),
#  ('slash', 'social', 'sciences'),
#  ('social', 'sciences', 'worry'),
#  ('sciences', 'worry', 'parker'),
#  ('worry', 'parker', 'let'),
#  ('parker', 'let', 'tire'),
#  ('let', 'tire', 'get'),
#  ('tire', 'get', 'another'),
#  ('get', 'another', 'grade'),
#  ('another', 'grade', 'yeah'),
#  ('grade', 'yeah', 'get'),
#  ('yeah', 'get', 'gopro'),
#  ('get', 'gopro', 'get'),
#  ('gopro', 'get', 'gopro'),
#  ('get', 'gopro', 'gopro'),
#  ('gopro', 'gopro', 'yeah'),
#  ('gopro', 'yeah', 'theyre'),
#  ('yeah', 'theyre', 'really'),
#  ('theyre', 'really', 'nice'),
#  ('really', 'nice', 'better'),
#  ('nice', 'better', 'oh'),
#  ('better', 'oh', 'really'),
#  ('oh', 'really', 'dang'),
#  ('really', 'dang', 'got'),
#  ('dang', 'got', 'never'),
#  ('got', 'never', 'used'),
#  ('never', 'used', 'gopro'),
#  ('used', 'gopro', 'whatd'),
#  ('gopro', 'whatd', 'say'),
#  ('whatd', 'say', 'whatd'),
#  ('say', 'whatd', 'say'),
#  ('whatd', 'say', 'whatd'),
#  ('say', 'whatd', 'say'),
#  ('whatd', 'say', 'said'),
#  ('say', 'said', 'better'),
#  ('said', 'better', 'dont'),
#  ('better', 'dont', 'know'),
#  ('dont', 'know', 'though'),
#  ('know', 'though', 'headstripe'),
#  ('though', 'headstripe', 'though'),
#  ('headstripe', 'though', 'looks'),
#  ('though', 'looks', 'little'),
#  ('looks', 'little', 'excessive'),
#  ('little', 'excessive', 'head'),
#  ('excessive', 'head', 'strap'),
#  ('head', 'strap', 'bigger'),
#  ('strap', 'bigger', 'actual'),
#  ('bigger', 'actual', 'camera'),
#  ('actual', 'camera', 'bigger'),
#  ('camera', 'bigger', 'oh'),
#  ('bigger', 'oh', 'never'),
#  ('oh', 'never', 'mind'),
#  ('never', 'mind', 'thought'),
#  ('mind', 'thought', 'like'),
#  ('thought', 'like', 'dont'),
#  ('like', 'dont', 'know'),
#  ('dont', 'know', 'last'),
#  ('know', 'last', 'time'),
#  ('last', 'time', 'saw'),
#  ('time', 'saw', 'like'),
#  ('saw', 'like', 'little'),
#  ('like', 'little', 'cubes'),
#  ('little', 'cubes', 'something'),
#  ('cubes', 'something', 'friend'),
#  ('something', 'friend', 'head'),
#  ('friend', 'head', 'camera'),
#  ('head', 'camera', 'gopro'),
#  ('camera', 'gopro', 'like'),
#  ('gopro', 'like', 'big'),
#  ('like', 'big', 'really'),
#  ('big', 'really', 'nice'),
#  ('really', 'nice', 'friends'),
#  ('nice', 'friends', 'really'),
#  ('friends', 'really', 'ghetto'),
#  ('really', 'ghetto', 'paintball'),
#  ('ghetto', 'paintball', 'trip'),
#  ('paintball', 'trip', 'tie'),
#  ('trip', 'tie', 'camcorder'),
#  ('tie', 'camcorder', 'head'),
#  ('camcorder', 'head', 'piece'),
#  ('head', 'piece', 'string'),
#  ('piece', 'string', 'another'),
#  ('string', 'another', 'time'),
#  ('another', 'time', 'like'),
#  ('time', 'like', 'hang'),
#  ('like', 'hang', 'camera'),
#  ('hang', 'camera', 'string'),
#  ('camera', 'string', 'gun'),
#  ('string', 'gun', 'string'),
#  ('gun', 'string', 'barrel'),
#  ('string', 'barrel', 'string'),
#  ('barrel', 'string', 'ive'),
#  ('string', 'ive', 'seen'),
#  ('ive', 'seen', 'better'),
#  ('seen', 'better', 'oh'),
#  ('better', 'oh', 'dang'),
#  ('oh', 'dang', 'im'),
#  ('dang', 'im', 'carrying'),
#  ('im', 'carrying', 'desk'),
#  ('carrying', 'desk', 'okay'),
#  ('desk', 'okay', 'think'),
#  ('okay', 'think', 'looks'),
#  ('think', 'looks', 'alright'),
#  ('looks', 'alright', 'sell'),
#  ('alright', 'sell', 'ebay'),
#  ('sell', 'ebay', 'end'),
#  ('ebay', 'end', 'period'),
#  ('end', 'period', 'craigslist'),
#  ('period', 'craigslist', 'theres'),
#  ('craigslist', 'theres', 'couple'),
#  ('theres', 'couple', 'oh'),
#  ('couple', 'oh', 'apparently'),
#  ('oh', 'apparently', 'craigslist'),
#  ('apparently', 'craigslist', 'stupid'),
#  ('craigslist', 'stupid', 'ridiculous'),
#  ('stupid', 'ridiculous', 'put'),
#  ('ridiculous', 'put', 'dot'),
#  ('put', 'dot', 'like'),
#  ('dot', 'like', 'negative'),
#  ('like', 'negative', 'dot'),
#  ('negative', 'dot', 'derivative'),
#  ('dot', 'derivative', 'behind'),
#  ('derivative', 'behind', 'negative'),
#  ('behind', 'negative', 'negative'),
#  ('negative', 'negative', 'negative'),
#  ('negative', 'negative', 'positive'),
#  ('negative', 'positive', 'oh'),
#  ('positive', 'oh', 'yeah'),
#  ('oh', 'yeah', 'positive'),
#  ('yeah', 'positive', 'guess'),
#  ('positive', 'guess', 'line'),
#  ('guess', 'line', 'already'),
#  ('line', 'already', 'crosses'),
#  ('already', 'crosses', 'makes'),
#  ('crosses', 'makes', 'clearer'),
#  ('makes', 'clearer', 'let'),
#  ('clearer', 'let', 'us'),
#  ('let', 'us', 'thats'),
#  ('us', 'thats', 'okay'),
#  ('thats', 'okay', 'lets'),
#  ('okay', 'lets', 'hear'),
#  ('lets', 'hear', 'thought'),
#  ('hear', 'thought', 'process'),
#  ('thought', 'process', 'hold'),
#  ('process', 'hold', 'stand'),
#  ('hold', 'stand', 'please'),
#  ('stand', 'please', 'stand'),
#  ('please', 'stand', 'stand'),
#  ('stand', 'stand', 'stand'),
#  ('stand', 'stand', 'like'),
#  ('stand', 'like', 'gabriel'),
#  ('like', 'gabriel', 'us'),
#  ('gabriel', 'us', 'see'),
#  ('us', 'see', 'graph'),
#  ('see', 'graph', 'put'),
#  ('graph', 'put', 'arms'),
#  ('put', 'arms', 'way'),
#  ('arms', 'way', 'alright'),
#  ('way', 'alright', 'question'),
#  ('alright', 'question', 'havent'),
#  ('question', 'havent', 'even'),
#  ('havent', 'even', 'presented'),
#  ('even', 'presented', 'anything'),
#  ('presented', 'anything', 'yet'),
#  ('anything', 'yet', 'talk'),
#  ('yet', 'talk', 'us'),
#  ('talk', 'us', 'thinking'),
#  ('us', 'thinking', 'supposed'),
#  ('thinking', 'supposed', 'graphed'),
#  ('supposed', 'graphed', 'supposed'),
#  ('graphed', 'supposed', 'something'),
#  ('supposed', 'something', 'graphed'),
#  ('something', 'graphed', 'function'),
#  ('graphed', 'function', 'multiple'),
#  ('function', 'multiple', 'three'),
#  ('multiple', 'three', 'intercepts'),
#  ('three', 'intercepts', 'doesnt'),
#  ('intercepts', 'doesnt', 'lets'),
#  ('doesnt', 'lets', 'make'),
#  ('lets', 'make', 'answerable'),
#  ('make', 'answerable', 'question'),
#  ('answerable', 'question', 'least'),
#  ('question', 'least', 'one'),
#  ('least', 'one', 'might'),
#  ('one', 'might', 'opinion'),
#  ('might', 'opinion', 'yes'),
#  ('opinion', 'yes', 'sure'),
#  ('yes', 'sure', 'think'),
#  ('sure', 'think', 'talked'),
#  ('think', 'talked', 'last'),
#  ('talked', 'last', 'class'),
#  ('last', 'class', 'fourth'),
#  ('class', 'fourth', 'order'),
#  ('fourth', 'order', 'think'),
#  ('order', 'think', 'tennessee'),
#  ('think', 'tennessee', 'going'),
#  ('tennessee', 'going', 'get'),
#  ('going', 'get', 'quadratic'),
#  ('get', 'quadratic', 'function'),
#  ('quadratic', 'function', 'get'),
#  ('function', 'get', 'linear'),
#  ('get', 'linear', 'graph'),
#  ('linear', 'graph', 'kind'),
#  ('graph', 'kind', 'makes'),
#  ('kind', 'makes', 'sense'),
#  ('makes', 'sense', 'would'),
#  ('sense', 'would', 'would'),
#  ('would', 'would', 'interested'),
#  ('would', 'interested', 'hear'),
#  ('interested', 'hear', 'two'),
#  ('hear', 'two', 'show'),
#  ('two', 'show', 'us'),
#  ('show', 'us', 'boards'),
#  ('us', 'boards', 'two'),
#  ('boards', 'two', 'groups'),
#  ('two', 'groups', 'kind'),
#  ('groups', 'kind', 'little'),
#  ('kind', 'little', 'boxing'),
#  ('little', 'boxing', 'ring'),
#  ('boxing', 'ring', 'go'),
#  ('ring', 'go', 'around'),
#  ('go', 'around', 'right'),
#  ('around', 'right', 'zigzag'),
#  ('right', 'zigzag', 'im'),
#  ('zigzag', 'im', 'curious'),
#  ('im', 'curious', 'hear'),
#  ('curious', 'hear', 'think'),
#  ('hear', 'think', 'group'),
#  ('think', 'group', 'hotline'),
#  ('group', 'hotline', 'number'),
#  ('hotline', 'number', 'jizz'),
#  ('number', 'jizz', 'four'),
#  ('jizz', 'four', 'people'),
#  ('four', 'people', 'crazy'),
#  ('people', 'crazy', 'yes'),
#  ('crazy', 'yes', 'yes'),
#  ('yes', 'yes', 'four'),
#  ('yes', 'four', 'thinking'),
#  ('four', 'thinking', 'think'),
#  ('thinking', 'think', 'three'),
#  ('think', 'three', 'increase'),
#  ('three', 'increase', 'kind'),
#  ('increase', 'kind', 'linearly'),
#  ('kind', 'linearly', 'ok'),
#  ('linearly', 'ok', 'want'),
#  ('ok', 'want', 'change'),
#  ('want', 'change', 'back'),
#  ('change', 'back', 'yeah'),
#  ('back', 'yeah', 'like'),
#  ('yeah', 'like', 'linear'),
#  ('like', 'linear', 'derivative'),
#  ('linear', 'derivative', 'negative'),
#  ('derivative', 'negative', 'gets'),
#  ('negative', 'gets', 'negative'),
#  ('gets', 'negative', 'right'),
#  ('negative', 'right', 'thats'),
#  ('right', 'thats', 'goes'),
#  ('thats', 'goes', 'starts'),
#  ('goes', 'starts', 'wanna'),
#  ('starts', 'wanna', 'like'),
#  ('wanna', 'like', 'fuck'),
#  ('like', 'fuck', 'uh'),
#  ('fuck', 'uh', 'fuck'),
#  ('uh', 'fuck', 'explain'),
#  ('fuck', 'explain', 'explain'),
#  ('explain', 'explain', 'okay'),
#  ('explain', 'okay', 'get'),
#  ('okay', 'get', 'called'),
#  ('get', 'called', 'explain'),
#  ('called', 'explain', 'okay'),
#  ('explain', 'okay', 'like'),
#  ('okay', 'like', 'wait'),
#  ('like', 'wait', 'youre'),
#  ('wait', 'youre', 'saying'),
#  ('youre', 'saying', 'reason'),
#  ('saying', 'reason', 'went'),
#  ('reason', 'went', 'stopped'),
#  ('went', 'stopped', 'something'),
#  ('stopped', 'something', 'started'),
#  ('something', 'started', 'went'),
#  ('started', 'went', 'want'),
#  ('went', 'want', 'change'),
#  ('want', 'change', 'something'),
#  ('change', 'something', 'else'),
#  ('something', 'else', 'cant'),
#  ('else', 'cant', 'make'),
#  ('cant', 'make', 'hidden'),
#  ('make', 'hidden', 'know'),
#  ('hidden', 'know', 'shouldnt'),
#  ('know', 'shouldnt', 'side'),
#  ('shouldnt', 'side', 'slip'),
#  ('side', 'slip', 'positive'),
#  ('slip', 'positive', 'actual'),
#  ('positive', 'actual', 'values'),
#  ('actual', 'values', 'arent'),
#  ('values', 'arent', 'positive'),
#  ('arent', 'positive', 'values'),
#  ('positive', 'values', 'derivative'),
#  ('values', 'derivative', 'positive'),
#  ('derivative', 'positive', 'shouldnt'),
#  ('positive', 'shouldnt', 'arent'),
#  ('shouldnt', 'arent', 'values'),
#  ('arent', 'values', 'derivative'),
#  ('values', 'derivative', 'negative'),
#  ('derivative', 'negative', 'values'),
#  ('negative', 'values', 'derivative'),
#  ('values', 'derivative', 'negative'),
#  ('derivative', 'negative', 'going'),
#  ('negative', 'going', 'oh'),
#  ('going', 'oh', 'right'),
#  ('oh', 'right', 'im'),
#  ('right', 'im', 'sorry'),
#  ('im', 'sorry', 'thats'),
#  ('sorry', 'thats', 'bad'),
#  ('thats', 'bad', 'theyre'),
#  ('bad', 'theyre', 'decreasing'),
#  ('theyre', 'decreasing', 'right'),
#  ('decreasing', 'right', 'yeah'),
#  ('right', 'yeah', 'youre'),
#  ('yeah', 'youre', 'right'),
#  ('youre', 'right', 'think'),
#  ('right', 'think', 'well'),
#  ('think', 'well', 'convinced'),
#  ('well', 'convinced', 'group'),
#  ('convinced', 'group', 'least'),
#  ('group', 'least', 'dont'),
#  ('least', 'dont', 'think'),
#  ('dont', 'think', 'youve'),
#  ('think', 'youve', 'convinced'),
#  ('youve', 'convinced', 'two'),
#  ('convinced', 'two', 'im'),
#  ('two', 'im', 'sure'),
#  ('im', 'sure', 'group'),
#  ('sure', 'group', 'lets'),
#  ('group', 'lets', 'go'),
#  ('lets', 'go', 'back'),
#  ('go', 'back', 'general'),
#  ('back', 'general', 'like'),
#  ('general', 'like', 'kind'),
#  ('like', 'kind', 'mentioned'),
#  ('kind', 'mentioned', 'gabriel'),
#  ('mentioned', 'gabriel', 'said'),
#  ('gabriel', 'said', 'graphed'),
#  ('said', 'graphed', 'intercepts'),
#  ('graphed', 'intercepts', 'heard'),
#  ('intercepts', 'heard', 'discussions'),
#  ('heard', 'discussions', 'know'),
#  ('discussions', 'know', 'side'),
#  ('know', 'side', 'xaxis'),
#  ('side', 'xaxis', 'start'),
#  ('xaxis', 'start', 'us'),
#  ('start', 'us', 'kind'),
#  ('us', 'kind', 'work'),
#  ('kind', 'work', 'well'),
#  ('work', 'well', 'weve'),
#  ('well', 'weve', 'got'),
#  ('weve', 'got', 'options'),
#  ('got', 'options', 'tell'),
#  ('options', 'tell', 'derivative'),
#  ('tell', 'derivative', 'zero'),
#  ('derivative', 'zero', 'negative'),
#  ('zero', 'negative', 'positive'),
#  ('negative', 'positive', 'need'),
#  ('positive', 'need', 'follow'),
#  ('need', 'follow', 'directions'),
#  ('follow', 'directions', 'need'),
#  ('directions', 'need', 'talked'),
#  ('need', 'talked', 'last'),
#  ('talked', 'last', 'class'),
#  ('last', 'class', 'little'),
#  ('class', 'little', 'bit'),
#  ('little', 'bit', 'derivative'),
#  ('bit', 'derivative', 'function'),
#  ('derivative', 'function', 'function'),
#  ...]

# %%
finder = nltk.collocations.BigramCollocationFinder.from_words(cleanedTeacher1Transcript)
finder.ngram_fd.tabulate(25)
# Out:
#     ('dont', 'know')     ('yeah', 'yeah')      ('im', 'going')   ('rate', 'change') ('average', 'speed')    ('little', 'bit')   ('square', 'root')    ('looks', 'like')     ('make', 'sure')      ('x', 'equals')       ('id', 'like')      ('im', 'sorry')   ('thank', 'thank')   ('right', 'right')       ('oh', 'yeah')    ('thats', 'good')    ('last', 'class')   ('another', 'way')    ('right', 'yeah')     ('dont', 'want')       ('go', 'back')     ('next', 'year')    ('two', 'points')       ('yes', 'yes')    ('dont', 'think')
#                  183                   87                   80                   67                   66                   64                   61                   41                   40                   39                   38                   37                   35                   35                   34                   33                   32                   32                   30                   29                   29                   28                   28                   27                   27

# %%
finder = nltk.collocations.TrigramCollocationFinder.from_words(cleanedTeacher1Transcript)
finder.ngram_fd.tabulate(25)
# Out:
#       ('yeah', 'yeah', 'yeah')     ('rate', 'change', 'rate')   ('change', 'rate', 'change')      ('feet', 'per', 'second')          ('bye', 'bye', 'bye')       ('dont', 'know', 'dont')       ('know', 'dont', 'know')          ('yes', 'yes', 'yes')    ('talked', 'last', 'class')    ('thank', 'thank', 'thank')  ('average', 'speed', 'first')   ('slope', 'tangent', 'line')       ('last', 'two', 'hours')    ('right', 'right', 'right')   ('square', 'root', 'square')     ('root', 'square', 'root')       ('like', 'like', 'like') ('rate', 'change', 'constant') ('another', 'way', 'describe')          ('buh', 'buh', 'buh')    ('doesnt', 'make', 'sense')         ('lets', 'go', 'back')       ('miles', 'per', 'hour')    ('whats', 'another', 'way')   ('kidding', 'im', 'kidding')
#                             41                             22                             22                             20                             20                             18                             17                             16                             13                             13                             13                             12                             11                             11                             11                             11                             10                             10                             10                             10                              9                              9                              9                              9                              9

# %%
from nltk.util import ngrams

n_value = 4  # Change this for different n values
fourgrams = ngrams(cleanedTeacher1Transcript, n_value)

# Tabulate the top n-grams
fdist = nltk.FreqDist(fourgrams)
fdist.tabulate(25)  # Top 10 fourgrams
# Out:
#                 ('yeah', 'yeah', 'yeah', 'yeah')             ('rate', 'change', 'rate', 'change')                     ('bye', 'bye', 'bye', 'bye')                 ('dont', 'know', 'dont', 'know')                     ('yes', 'yes', 'yes', 'yes')             ('square', 'root', 'square', 'root')                     ('buh', 'buh', 'buh', 'buh')                 ('know', 'dont', 'know', 'dont')               ('kidding', 'im', 'kidding', 'im')               ('im', 'kidding', 'im', 'kidding')         ('change', 'rate', 'change', 'constant')         ('average', 'speed', 'first', 'seconds')                     ('got', 'got', 'got', 'got')             ('right', 'right', 'right', 'right')                       ('im', 'kid', 'im', 'kid')                 ('like', 'like', 'like', 'like')            ('change', 'rate', 'change', 'would')             ('change', 'rate', 'change', 'rate')                 ('thank', 'sir', 'give', 'hand')              ('power', 'raise', 'get', 'number') ('implication', 'thats', 'implication', 'thats')     ('curve', 'headed', 'positive', 'direction')           ('constant', 'rate', 'change', 'rate')                 ('use', 'log', 'solve', 'would')              ('might', 'want', 'change', 'base')
#                                               28                                               22                                               17                                               15                                               14                                               11                                                9                                                9                                                8                                                8                                                7                                                7                                                7                                                7                                                7                                                6                                                6                                                6                                                6                                                6                                                6                                                5                                                5                                                5                                                5

# %%
from nltk.util import ngrams
from nltk import sent_tokenize

# Assuming the raw text is in variable 'raw_text'
#sentences = text_sentTokens
sentences = sent_tokenize(text_tokens)

# Your tokenized data is in 'cleanedTeacher1Transcript'
n_value = 2
fourgrams = ngrams(cleanedTeacher1Transcript, n=n_value)

# Find the most common n-grams
fdist = nltk.FreqDist(fourgrams)
common_fourgrams = [gram for gram, count in fdist.most_common(100)]

# Search for sentences containing the n-grams
for gram in common_fourgrams:
    joined_gram = ' '.join(gram)  # Turn tuple to string for matching
    for sentence in sentences:
        if joined_gram in sentence:
            print(f"For n-gram {joined_gram}:")
            print(sentence)
            print("------")

# %%
from nltk.util import ngrams
from nltk import sent_tokenize

# Assuming the raw text is in variable 'raw_text'
sentences = sent_tokenize(text_tokens)

# Your tokenized data is in 'cleanedTeacher1Transcript'
n_value = 2
fourgrams = ngrams(cleanedTeacher1Transcript, n=n_value)

# Find the most common n-grams
fdist = nltk.FreqDist(fourgrams)
common_fourgrams = [gram for gram, count in fdist.most_common(10)]

# Print the most common n-grams for inspection
print("Most common 50 n-grams:")
for gram, count in fdist.most_common(5):
    print(' '.join(gram), "-", count, "occurrences")
print("------")

# Search for sentences containing the n-grams
found = False
for gram, count in common_fourgrams:
    joined_gram = ' '.join(gram)  # Turn tuple to string for matching
    occurrence_count = 0  # To track occurrences within sentences
    for i, sentence in enumerate(sentences, start=1):
        if joined_gram in sentence:
            occurrence_count += 1
            print(f"For n-gram '{joined_gram}' (Sentence {i}):")
            print(sentence)
            print("------")
            found = True
    print(f"N-gram '{joined_gram}' occurs {occurrence_count} times.")
    print("------")
if not found:
    print("No common n-grams found in the sentences.")

# %%
from nltk.util import ngrams
from collections import defaultdict

def find_ngram_occurrences_chunked(text, n_value, top_n, chunk_size=500):
    tokenized_sentences = nltk.sent_tokenize(text)
    num_chunks = len(tokenized_sentences) // chunk_size + 1

    ngram_freq = defaultdict(int)
    ngram_sentences = defaultdict(list)

    for chunk in range(num_chunks):
        start = chunk * chunk_size
        end = (chunk + 1) * chunk_size

        chunk_sentences = tokenized_sentences[start:end]
        chunk_words = [nltk.word_tokenize(sentence) for sentence in chunk_sentences]

        for i, words in enumerate(chunk_words):
            for ngram in set(ngrams(words, n_value)):
                ngram_freq[ngram] += 1
                ngram_sentences[ngram].append((start+i, chunk_sentences[i]))

    sorted_ngrams = sorted(ngram_freq.items(), key=lambda x: x[1], reverse=True)

    for ngram, freq in sorted_ngrams[:top_n]:
        print('-' * 6)
        print(f"N-gram {' '.join(ngram)} occurs {freq} times.")

        for i, sentence in ngram_sentences[ngram]:
            print(f"(Sentence {i+1}): {sentence}")
        print('-' * 6)

# Example usage:
text_sample = cleanedTeacher1Transcript
find_ngram_occurrences_chunked(text_sample, 4, 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b7915055e290> in <cell line: 34>()
#      32
#      33 # Example usage:
# ---> 34 text_sample = cleanedTeacher1Transcript
#      35 find_ngram_occurrences_chunked(text_sample, 4, 10)
#      36
#
# NameError: name 'cleanedTeacher1Transcript' is not defined

# %%
from nltk.util import ngrams
from collections import defaultdict

def find_ngram_occurrences(text, n_value, top_n):
    tokenized_sentences = text_sentTokens
    tokenized_words = [text_wordTokens for sentence in tokenized_sentences]

    # A dictionary to hold n-gram frequencies
    ngram_freq = defaultdict(int)

    # A dictionary to hold the sentences where each n-gram occurs
    ngram_sentences = defaultdict(list)

    for i, words in enumerate(tokenized_words):
        for ngram in set(ngrams(words, n_value)):  # Using set to avoid counting duplicates within a sentence
            ngram_freq[ngram] += 1
            ngram_sentences[ngram].append((i, tokenized_sentences[i]))

    # Sort ngrams by frequency
    sorted_ngrams = sorted(ngram_freq.items(), key=lambda x: x[1], reverse=True)

    for ngram, freq in sorted_ngrams[:top_n]:
        print('-' * 6)
        print(f"N-gram {' '.join(ngram)} occurs {freq} times.")

        for i, sentence in ngram_sentences[ngram]:
            print(f"(Sentence {i+1}): {sentence}")
        print('-' * 6)

# Example usage:
text_sample = cleanedTeacher1Transcript
find_ngram_occurrences(text_sample, 4, 10)

# %% [markdown]
# The following code will allow you to write the contents of a variable to a text file instead of just to memory.

# %%
cleanedTeacher1Transcript.similar("share")

# %%
cleanedTeacher1Transcript.common_contexts(["students", "ask"])
# Out:
# No common contexts were found

# %% [markdown]
# #5.0 Sentiment Analysis
# 1. Movie transcript database

# %% [markdown]
# # 6.0 Further Usage

# %% [markdown]
# TESTING

# %% [markdown]
# len(words)

# %%
len(words)
# Out:
# 72769

# %%
sorted(set(words))
# Out:
# ['class',
#  'ideas',
#  'initial',
#  'lesson',
#  'min',
#  'model',
#  'question',
#  'questions',
#  'student',
#  'students']

# %%
nltk.draw.dispersion.dispersion_plot(cleanedTeacher1Transcript, words, ignore_case=False, title='Lexical Dispersion Plot')
# Out:
# <Axes: title={'center': 'Lexical Dispersion Plot'}, xlabel='Word Offset'>

# %%
fig = plt.figure(figsize = (10,4))
plt.gcf().subplots_adjust(bottom=0.15) # to avoid x-ticks cut-off
#OPSE_tokens.dispersion_plot(["students","teacher", "diverse", "diversity", "teacher", "student"])
#OPSE_tokens.plot(10)
nltk.draw.dispersion.dispersion_plot(cleanedTeacher1Transcript, words, ignore_case=False, title='Lexical Dispersion Plot')
#nltk.draw.dispersion_plot(OPSEwords, words, ignore_case=False, title='Lexical Dispersion Plot')
plt.show()
fig.savefig('freqDist7.png', bbox_inches = "tight")

# %%
plt.ion()
cleanedTeacher1Transcript.plot(10)
plt.savefig('img_common.png')
plt.ioff()
plt.show()

# %%
import nltk
from nltk import word_tokenize
import matplotlib.pyplot as plt


text1 = cleanedTeacher1Transcript

fig = plt.figure()
dplot = text1.dispersion_plot(["students"])
# save the figure
fig.savefig('dispersion_plot1.png')

# %% [markdown]
# # Testing out a Corpus TIMIT Acoustic-Phonetic Continuous Speech Corpus

# %%
import nltk
nltk.download('timit')
files = nltk.corpus.timit.fileids()
#from nltk.corpus import timit
#timit.sents()
#files = timit.fileids()
files

# %% [markdown]
# # Looking for bag of words
#
# Load Uncertainty Words:Load your list of words that denote uncertainty. This list can be stored as a simple Python list.
# Load Text Files: Load the content of your three text files.

# %%
uncertainty_words = ["help", "doubt", "difficult", "hard", "equal"]

text_filed = []
text_files_path = ['/content/drive/MyDrive/transcripts/merged/teacher101_merged.txt', '/content/drive/MyDrive/transcripts/merged/teacher102_merged.txt', '/content/drive/MyDrive/transcripts/merged/teacher103_merged.txt']

for file_path in text_files_path:
    with open(file_path, 'r', encoding='utf-8') as file:
        text_filed.append(file.read())
text_filed

# %% [markdown]
# Search for Uncertainty Words:
# Iterate through the text files and search for the uncertainty words. Count how often each word appears in each file.

# %%
word_frequency_per_file = []

for text in text_filed:
    word_frequency = {}
    for word in uncertainty_words:
        word_frequency[word] = text.lower().count(word.lower())
    word_frequency_per_file.append(word_frequency)

# %% [markdown]
# Print or Analyze Results:
# You can now print or analyze the results based on the word frequency per file.

# %%
for i, word_frequency in enumerate(word_frequency_per_file):
    print(f"Results for file {i+1}:")
    for word, frequency in word_frequency.items():
        print(f"{word}: {frequency} occurrences")
# Out:
# Results for file 1:
# help: 38 occurrences
# doubt: 0 occurrences
# difficult: 13 occurrences
# hard: 18 occurrences
# equal: 214 occurrences
# Results for file 2:
# help: 43 occurrences
# doubt: 2 occurrences
# difficult: 2 occurrences
# hard: 46 occurrences
# equal: 203 occurrences
# Results for file 3:
# help: 27 occurrences
# doubt: 3 occurrences
# difficult: 2 occurrences
# hard: 49 occurrences
# equal: 222 occurrences

# %% [markdown]
# Install it using pip install matplotlib. In this code, we use the matplotlib library to create bar plots for each text file, showing the frequency of each uncertainty word. The bar plots are saved as PNG image files with filenames like file_1_word_frequencies.png, file_2_word_frequencies.png, etc. Each plot shows the frequency distribution of uncertainty words in a specific text file.
#
# "maybe","perhaps","unsure","possibly","guess","think","believe","kinda","seem","supposedly","likely","presumably","unclear","doubt"

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load uncertainty words
uncertainty_words = ["help", "difficult", "hard", "equal","maybe","perhaps","unsure","possibly","guess","think","believe","kinda","seem","supposedly","likely","presumably","unclear","doubt", "convinced", "kind", "yeah"]

# Load text files
text_files = []
text_files_path = ['/content/drive/MyDrive/transcripts/merged/teacher101_merged.txt', '/content/drive/MyDrive/transcripts/merged/teacher102_merged.txt', '/content/drive/MyDrive/transcripts/merged/teacher103_merged.txt']

for file_path in text_files_path:
    with open(file_path, 'r', encoding='utf-8') as file:
        text_files.append(file.read())

# Search for uncertainty words and count occurrences
word_frequency_per_file = []

for text in text_files:
    word_frequency = {}
    for word in uncertainty_words:
        word_frequency[word] = text.lower().count(word.lower())
    word_frequency_per_file.append(word_frequency)

# Plotting the data
for i, word_frequency in enumerate(word_frequency_per_file):
    words = list(word_frequency.keys())
    frequencies = list(word_frequency.values())

    plt.figure(figsize=(10, 6))
    plt.bar(words, frequencies)
    plt.title(f"Uncertainty Word Frequencies in File {i+1}")
    plt.xlabel("Uncertainty Words")
    plt.ylabel("Frequency")
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()

    plt.savefig(f'file_{i+1}_word_frequencies.png')
    plt.show()
