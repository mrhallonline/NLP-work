# %% [markdown]
# <a href="https://colab.research.google.com/github/mrhallonline/NLP-work/blob/main/Copy_of_Module_1_Workshop_Setting_Up_Natural_Language_Toolkit_(NLTK)_V3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.0 Introduction to NLP and Overview of modules
# The data corpus that we will be using is an Excel file of a Whisper AI transcription of a high school math class that Stina mentioned in her talk. This data is located in my Google Drive. We will use NLTK, Python, and Google Colab to copy and process the file so that it can be analyzed by you during the workshop. From there we will do some basic processing and analysis to extract specific features that might offer us some insight about student uncertainty during the transcribed math class, based on their conversations. We will end the workshop with a focus on the important first steps of preprocessing our data corpus.
#
# It is important to understand that while the tools we are using today offer some insight into our research question, researcher involvement is integral to the analysis.
#
# [Shared Document](https://docs.google.com/document/d/1q_b8pGBRqOg38HZh2tFjoQCzGomGfMt0ML9U34w4IV0/edit?usp=sharing )

# %% [markdown]
# ## 1.1 What is Feature Extraction in NLP (Signal vs. Noise)
#
# * Isolating Useful Information: the aim is to isolate the useful or relevant information from a mass of data. In NLP, feature extraction is about selecting only those aspects of the data that are useful for a particular task (e.g., sentiment analysis, machine translation, etc.).
#
# * Improving Accuracy: Removing irrelevant features in NLP usually leads to better results, more accurate machine learning models.
#
# * Optimization: Iterative process, requiring several rounds of refinement to optimize performance.
#
# * Sometimes noise is signal and sometimes signal is actually noise in natural language processing. We will see this in module 2 when looking at capitalization as a useful feature as compared to times during text preprocessing when it is often more noise than signal. Extracting features can lead to the loss of others. (In the transcript pauses are noted by elipses, which can be lost when extracting certain character types. This is also true for question marks)
#
#
# ![MYNLPFlowCHart1.png](data:image/png;base64,...)

# %% [markdown]
# ![MYNLPFlowCHart2.png](data:image/png;base64,...)

# %% [markdown]
# # 1.2 Raw Uncertainty Excel file (Our data corpus)
# We will be extracting the text from the column labeled transcript. Currently there is more noise than signal if we used this whole file as our data corpus. It is also important to note that we rarely ever interact with or alter our raw data corpus. We extract specific features to new useful variables. This can get messy over time if we aren't able to keep up with our ever increasing buckets of transformed data.
# ![Screenshot 2023-09-02 at 1.01.57 PM.png](data:image/png;base64,...)

# %% [markdown]
# # 1.3 Interacting with Google Colab
# ## This is a text cell
# * Instructions or explanations will be found in text cells.
# * They will normally give explanations about the subsequent code cell.
# * You should make a copy of the notebook you are using so that you have the ability to save your changes if you would like.

# %%
# This is a code cell
# When you click the execute button it will spin as it processes the code then it will normally generate an output just below the cell
# This simple code will check what version of Python is currently being run by Google Colab
# When you click this cell the output should say something similar "Python 3.10.12"

# !python --version

# %% [markdown]
# # 1.4 Installing NLTK and Python supporting dependencies, packages and libraries using Google Colab.
#
# Clicking the code cell play button below will install all the following libraries that we will use throughout this workshop which include:
#
# * Natural Language Toolkit (NLTK)
# * Matplotlib library: Library for creating data visualizations.
# * Gensim library: Natural language processing tool
# * PyPDF2 library: NLTK normally works with text files, PyPDF2 will allow you to read, write, convert to text, and merge pdf files
# * Numpy
# * Pandas

# %%
# Clicking the code cell play button below will download and install all the following libraries listed above.
# This normally takes around ~30 seconds and each step will show up in the output below.
# !pip install nltk
# !pip install matplotlib
# !pip install gensim
# !pip install PyPDF2
# !pip install numpy
# !pip install pandas
# !pip install pandas openpyxl nltk

# %% [markdown]
# # 1.5  Questions for Module 1
#
# 1. Have you used Google Colab or Jupyter notebooks in the past?
# 2. What questions do you currently have about interacting with these notebooks?
# 3. What are some questions that we can ask about student uncertainty in a high school math class?
#
#
#
# Click link to move on to [Module 2](https://github.com/mrhallonline/NLP-Workshop/blob/main/Module_2_Workshop_Setting_Up_Natural_Language_Toolkit_(NLTK)_V3.ipynb)
