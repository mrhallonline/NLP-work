# %% [markdown]
# <a href="https://colab.research.google.com/github/mrhallonline/NLP-work/blob/main/PAGES_OPSEMERGED_Natural_Language_Toolkit_(NLTK).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **General Overview**
# 1. **Introduction to NLTK**
# 2. **Working with NLTK builtin datasets**
# 3. **Preprocessing and cleaning datasets**
# 4. **Basic analysis**
# 5. **Sentiment analysis Activity**
# 6. **Further Usage**
#
# 7. **important considerations having to do with research!!**

# %% [markdown]
# Connect to your Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests

#https://drive.google.com/file/d/1-6AkzKuyfY9Oj__MWQFCP_Yo-TSzMS0F/view?usp=drive_link

# get the file ID from the shareable link
file_id = "1-6AkzKuyfY9Oj__MWQFCP_Yo-TSzMS0F"

# construct the download URL
download_url = f"https://docs.google.com/uc?export=download&id={file_id}"

# send a GET request to the download URL and save the response content
response = requests.get(download_url)
with open("OPSEMERGED.txt", "wb") as f:
    f.write(response.content)

# %% [markdown]
# # 1.0. Installing NLTK dependencies and libraries
# NLTK
#
# 1.   [Matplotlib](https://matplotlib.org/) library: Library for creating data visualizations.
# 2.   [Beautiful Soup](https://pypi.org/project/beautifulsoup4/) library: Pulls information from HTML and XML files.
# 1.   [Gensim](https://pypi.org/project/gensim/) library: Natural language processing tool
# 2.   [PyPDF2](https://pypdf2.readthedocs.io/en/3.0.0/index.html#) library: NLTK normally works with text files, PyPDF2 will allow you to read, write, convert to text, and merge pdf files

# %%
# !pip install nltk
# !pip install matplotlib
# !pip install beautifulsoup4
# !pip install gensim
# !pip install PyPDF2
# !pip install numpy
# !pip install scipy
# !pip install pandas
# !pip install scikit-learn
# !pip install autocorrect
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.65.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.4.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.3.0)
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 7.0 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Collecting autocorrect
#   Downloading autocorrect-2.6.1.tar.gz (622 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.8/622.8 kB 12.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: autocorrect
#   Building wheel for autocorrect (setup.py) ... done
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622363 sha256=78e485f35ff149ad51007c493f32ac78067673b5c96f22a52c6d75ca65c99c7d
#   Stored in directory: /root/.cache/pip/wheels/b5/7b/6d/b76b29ce11ff8e2521c8c7dd0e5bfee4fb1789d76193124343
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.6.1

# %% [markdown]
# # 2.0. Working with builtin datasets using NLTK
#
# NLTK has access to a large body of example corpora than can be directly incorporated and analyzed.
# Descriptions of for each corpus module can be found here:
# 1. https://www.nltk.org/nltk_data/ and here
# 2. https://www.nltk.org/api/nltk.corpus.html
# * The syntax of the code can also be changed to download specific, all, or groups of modules for example:
#
# ```
# # nltk.download('all') or
# # nltk.download('popular') or
# # nltk.download('gutenberg') ##this name is found at id:gutenberg
# ```

# %%
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %% [markdown]
# # 2.1 Import an example corpus and run basic analysis on word usage in context.
# In this case we are looking at the ______ corpus finding out the frequency and context of the word ____ throughout the document using the concordance method.

# %%
import nltk
nltk.download('state_union')
union = nltk.Text(nltk.corpus.state_union.words())
union.concordance('democracy', lines = 25)
# Out:
# [nltk_data] Downloading package state_union to /root/nltk_data...
# [nltk_data]   Unzipping corpora/state_union.zip.
# Displaying 25 of 117 matches:
# citizenry enjoying the benefits of democracy under our free enterprise system .
# ith of our citizens in freedom and democracy will be spread over the whole eart
# nfidence in the ideals of our free democracy . Our deep belief in freedom and j
# earing upon the foundations of our democracy and the happiness of our people .
# s a denial of the basic beliefs of democracy and of our regard for the worth of
# rly contrary to American ideals of democracy . The recent report of the Preside
# h . Another fundamental aim of our democracy is to provide an adequate educatio
# nd sharing the responsibilities of democracy . The Government ' s programs for
# re of such great importance to our democracy that we should now establish an ex
#  doing exactly what the enemies of democracy want us to do . We should be just
# ing , we shall add strength to our democracy through the abilities and skills w
# The great economic strength of our democracy has developed in an atmosphere of
# ive -- and , finally , to practice democracy at home , in all States , with all
# tion of our hopes . " I believe in democracy ," said Woodrow Wilson , " because
# very human being ." The dynamic of democracy is the power and the purpose of th
# tatorship through disorder towards democracy . THE NEW AND DEVELOPING NATIONS O
# her the first continental union of democracy in the history of man . One hundre
# ward economic growth and political democracy . In this period we have taken mor
# d you must then help guide a great democracy . The answer was waiting for me in
#  dignity of man and the destiny of democracy . I urge every member of both part
# ause for hope and for faith in our democracy in what is happening here tonight
# to flourish , it must be rooted in democracy . The most basic right of all was
# ravery , and his faith in American democracy . For at the real heart of battle
# fe . The Nation , the principle of democracy , and , I think , each congression
# t we work to build a hemisphere of democracy and of social justice . In this pu

# %% [markdown]
# # 2.2 Creating a quick dispersion plot showing where specific words are found throughout the word count of a document.
# The following document represents a sequential merge of all ______
#
#
#
# ---
#
# *using the dispersion plot method in Google Colab seems to result in visualization errors, where displayed word frequencies are displayed incorrectly*

# %%
union.dispersion_plot(["america","culture", "democracy", "diversity","diverse", "terrorism", "war", "equity", "multicultural", "peace"])

# %% [markdown]
# # 3.0 Preprocessing Text in NLTK - importing a text file
# The follwing code will iterarte through all pages of a pdf document converting them item into text in this case equity_text, which is subsequently saved as a text file for further processing by NLTK.
#
# Change the path to point to your folder in Google Drive. You can right-click the folder to get this path when using Colab.
# ```
# # with open('/content/drive/MyDrive/pdfs/OPSEMERGEDCleanv2.pdf', 'rb') as file:
# ```
#
# One of the most important part of natural language processing is preprocessing or cleaning of your data. This is often less of an issue when using the cleaned examples.

# %% [markdown]
# # Loading data

# %%
# load data
filename = '/content/OPSEMERGED.txt'
textfile = open(filename, 'rt', encoding='utf-8', errors='replace')

text = textfile.read()
textfile.close()
text
# Out:
# ' \nLesson 1: How can something act like a mirror and a window at the same time?\n\n\n\n \n\nThis Lesson\n\nAnchoring Phenomenon\n\n4 days\n \n\nWe watch a puzzling video of a music student who can see his reflection in what seems to be a mirror. The student can�t see the teacher on the other side of the mirror, but the teacher can see the student. We wonder how something can act like a mirror and a window at the same time. We investigate the scenario using a box model that maps to the system in the video. We develop an Initial Class Consensus Model to explain the\none-way mirror phenomenon, and we identify related phenomena that could help us explain it. We share questions about the one-way mirror, which helps us form our Driving Question Board. We brainstorm investigations and data we need to answer our questions.\n \n\n\n\n\n\n \n\nBUILDING TOWARD NGSS\n\nMS-PS4-2, MS-LS1-8\n\n \n\nWhat students will do\n\n1.A\tDevelop a model to identify the important parts of the system and how those parts interact that could cause an object to look different in different light conditions.\n\n1.B\tAsk questions that arise from observations of a phenomenon in which an object appears different depending on the light conditions within the defined system.\n\nWhat students will figure out\n\n?\tSome materials can be reflective and see-through at the same time.\n?\tWhether the material is reflective or see-through may be related to where there is a light.\n \nLesson 1 � Learning Plan Snapshot\nPart\tDuration\tSummary\tSlide\tMaterials\n1\t10 min\tINTRODUCE A PUZZLING PHENOMENON\nPlay the Music Lesson video, showing a student who can see only his reflection in a one-way mirror while the teacher on the other side can see through the one-way mirror. Have students record noticings and wonderings.\tA\tcomputer and projector, Music Lesson video\n2\t10 min\tSHARE NOTICINGS AND WONDERINGS FROM THE VIDEO\nShare noticings and wonderings from the video with a partner. Lead a class discussion to record these observations and questions on a class chart.\tB\tNotice and Wonder chart (prepared in advance), markers\n3\t15 min\tIDENTIFY PARTS AND INTERACTIONS TO DIAGRAM OUR THINKING\nThrough partner talk and class discussion, co-construct a list of the important parts in the video phenomenon and a diagram of the parts� interactions that should be included in initial explanations.\tC-E\tInitial diagram to explain the phenomenon (optional), Parts chart (prepared in advance), markers\n4\t5 min\tCOMPARE DIAGRAMS WITH A PARTNER\nArrange students into partners to share their diagrams and note similarities and differences.\tF\tInitial diagram to explain the phenomenon\n(optional)\n5\t5 min\tNAVIGATION\nBrainstorm ideas for making a scale model that represents the system in the video to investigate the phenomenon in the classroom.\tG\t\nEnd of day 1\n6\t5 min\tNAVIGATION\nIntroduce the box model and elicit students� prior experiences with scale models.\tH\t1 box model setup, 1 picture mat set with one-way mirror film, 1 flashlight, toys\n7\t10 min\tMAP THE BOX MODEL TO THE VIDEO\nGuide students in mapping the parts of the box model to the important parts in the video. Use this mapping to highlight the benefits and limitations of using the box model.\tI\tMapping the Model to the \tchart (prepared in advance), Parts chart (prepared in advance), markers\n8\t15 min\tCARRY OUT THE BOX MODEL INVESTIGATION\nGive students time to explore the box model and to add noticings and wonderings to their chart.\tJ\t1 box model setup, 1 picture mat set with one-way mirror film, 1 flashlight, toys\n9\t12 min\tSHARE OBSERVATIONS FROM THE BOX MODEL INVESTIGATION\nFacilitate a class discussion to connect what students noticed and wondered in the Box Model Investigation to what they saw in the video. Evaluate the box model.\tK-L\tCommunicating in Scientific Ways handout, Notice and Wonder chart (prepared in advance), markers\n \n10\t3 min\tNAVIGATION\nAsk students to complete an exit ticket i ...

# %% [markdown]
# # Convert PDF to txt file
#
# The following will convert a pdf document from your Google Drive folder and convert it page by page to a text object that can be interacted with by NLTK.

# %% [markdown]
# # 3.1 Initial preprocessing
#
# 1.   Tokenizing text - words versus sentences
# 2.   Removing tokens that are not alphabetic
# 3.   normalizing tokens (cases)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# split into words
from nltk.tokenize import word_tokenize
word_tokens = word_tokenize(text)
# convert to lower case
lower_tokens = [w.lower() for w in word_tokens]
# remove punctuation from each word
import string
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in lower_tokens]
# remove remaining tokens that are not alphabetic
alpha_words = [word for word in stripped if word.isalpha()]
# filter out stop words
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
OPSEwords = [w for w in alpha_words if not w in stop_words]
print(OPSEwords[:100])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['lesson', 'something', 'act', 'like', 'mirror', 'window', 'time', 'lesson', 'anchoring', 'phenomenon', 'days', 'watch', 'puzzling', 'video', 'music', 'student', 'see', 'reflection', 'seems', 'mirror', 'student', 'see', 'teacher', 'side', 'mirror', 'teacher', 'see', 'student', 'wonder', 'something', 'act', 'like', 'mirror', 'window', 'time', 'investigate', 'scenario', 'using', 'box', 'model', 'maps', 'system', 'video', 'develop', 'initial', 'class', 'consensus', 'model', 'explain', 'oneway', 'mirror', 'phenomenon', 'identify', 'related', 'phenomena', 'could', 'help', 'us', 'explain', 'share', 'questions', 'oneway', 'mirror', 'helps', 'us', 'form', 'driving', 'question', 'board', 'brainstorm', 'investigations', 'data', 'need', 'answer', 'questions', 'building', 'toward', 'ngss', 'students', 'develop', 'model', 'identify', 'important', 'parts', 'system', 'parts', 'interact', 'could', 'cause', 'object', 'look', 'different', 'different', 'light', 'conditions', 'ask', 'questions', 'arise', 'observations', 'phenomenon']

# %%
print(OPSEwords)
# Out:
# ['lesson', 'something', 'act', 'like', 'mirror', 'window', 'time', 'lesson', 'anchoring', 'phenomenon', 'days', 'watch', 'puzzling', 'video', 'music', 'student', 'see', 'reflection', 'seems', 'mirror', 'student', 'see', 'teacher', 'side', 'mirror', 'teacher', 'see', 'student', 'wonder', 'something', 'act', 'like', 'mirror', 'window', 'time', 'investigate', 'scenario', 'using', 'box', 'model', 'maps', 'system', 'video', 'develop', 'initial', 'class', 'consensus', 'model', 'explain', 'oneway', 'mirror', 'phenomenon', 'identify', 'related', 'phenomena', 'could', 'help', 'us', 'explain', 'share', 'questions', 'oneway', 'mirror', 'helps', 'us', 'form', 'driving', 'question', 'board', 'brainstorm', 'investigations', 'data', 'need', 'answer', 'questions', 'building', 'toward', 'ngss', 'students', 'develop', 'model', 'identify', 'important', 'parts', 'system', 'parts', 'interact', 'could', 'cause', 'object', 'look', 'different', 'different', 'light', 'conditions', 'ask', 'questions', 'arise', 'observations', 'phenomenon', 'object', 'appears', 'different', 'depending', 'light', 'conditions', 'within', 'defined', 'system', 'students', 'figure', 'materials', 'reflective', 'seethrough', 'time', 'whether', 'material', 'reflective', 'seethrough', 'may', 'related', 'light', 'lesson', 'learning', 'plan', 'snapshot', 'part', 'duration', 'summary', 'slide', 'materials', 'min', 'introduce', 'puzzling', 'phenomenon', 'play', 'music', 'lesson', 'video', 'showing', 'student', 'see', 'reflection', 'oneway', 'mirror', 'teacher', 'side', 'see', 'oneway', 'mirror', 'students', 'record', 'noticings', 'wonderings', 'computer', 'projector', 'music', 'lesson', 'video', 'min', 'share', 'noticings', 'wonderings', 'video', 'share', 'noticings', 'wonderings', 'video', 'partner', 'lead', 'class', 'discussion', 'record', 'observations', 'questions', 'class', 'chart', 'b', 'notice', 'wonder', 'chart', 'prepared', 'advance', 'markers', 'min', 'identify', 'parts', 'interactions', 'diagram', 'thinking', 'partner', 'talk', 'class', 'discussion', 'coconstruct', 'list', 'important', 'parts', 'video', 'phenomenon', 'diagram', 'interactions', 'included', 'initial', 'explanations', 'ce', 'initial', 'diagram', 'explain', 'phenomenon', 'optional', 'parts', 'chart', 'prepared', 'advance', 'markers', 'min', 'compare', 'diagrams', 'partner', 'arrange', 'students', 'partners', 'share', 'diagrams', 'note', 'similarities', 'differences', 'f', 'initial', 'diagram', 'explain', 'phenomenon', 'optional', 'min', 'navigation', 'brainstorm', 'ideas', 'making', 'scale', 'model', 'represents', 'system', 'video', 'investigate', 'phenomenon', 'classroom', 'g', 'end', 'day', 'min', 'navigation', 'introduce', 'box', 'model', 'elicit', 'prior', 'experiences', 'scale', 'models', 'h', 'box', 'model', 'setup', 'picture', 'mat', 'set', 'oneway', 'mirror', 'film', 'flashlight', 'toys', 'min', 'map', 'box', 'model', 'video', 'guide', 'students', 'mapping', 'parts', 'box', 'model', 'important', 'parts', 'video', 'use', 'mapping', 'highlight', 'benefits', 'limitations', 'using', 'box', 'model', 'mapping', 'model', 'chart', 'prepared', 'advance', 'parts', 'chart', 'prepared', 'advance', 'markers', 'min', 'carry', 'box', 'model', 'investigation', 'give', 'students', 'time', 'explore', 'box', 'model', 'add', 'noticings', 'wonderings', 'chart', 'j', 'box', 'model', 'setup', 'picture', 'mat', 'set', 'oneway', 'mirror', 'film', 'flashlight', 'toys', 'min', 'share', 'observations', 'box', 'model', 'investigation', 'facilitate', 'class', 'discussion', 'connect', 'students', 'noticed', 'wondered', 'box', 'model', 'investigation', 'saw', 'video', 'evaluate', 'box', 'model', 'kl', 'communicating', 'scientific', 'ways', 'handout', 'notice', 'wonder', 'chart', 'prepared', 'advance', 'markers', 'min', 'navigation', 'ask', 'students', 'complete', 'exit', 'ticket', 'preparation', 'consensus', 'discussion', 'index', 'card', 'end', 'day', 'min', 'form', 'scientists', 'circle', 'discuss', 'classroom', 'norms', 'arrange' ...

# %%
nltk.download('stopwords')  # has to be done once
from nltk import word_tokenize

OPSE_tokens = nltk.Text(OPSEwords)
OPSE_tokens.collocations()
# Out:
# chart paper; attending equity; related phenomena; driving question;
# sticky notes; question board; consensus model; display slide; science
# notebook; end day; noticings wonderings; scientists circle; oil palm;
# min materials; bath bomb; paper markers; notice wonder; develop
# initial; initial model; universal design
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# #3.2 Working with Stop Words
# 1. Importing stop words
# 2. Modifying sop words list
# 3. Stemming and Lemmatizing

# %% [markdown]
# compute frequency distribution of words found in the document. Can find most common, least, total count, etc.

# %%
#Top ten most common words
fd = nltk.FreqDist(OPSEwords)
fd.most_common(100)

# %%
fd.tabulate(25)
# Out:
#  students questions     ideas     model       min   initial     class  question   student    lesson      unit     share       one       use     slide different      make      help   related   develop    models       ask    poster phenomena     chart
#      2227       877       735       661       552       530       524       510       456       412       412       398       380       369       346       340       339       337       333       327       322       316       316       309       291

# %% [markdown]
# Word count

# %%
fd["equity"]
# Out:
# 141

# %%
fd.plot(35, cumulative=True)
# Out:
# <Axes: xlabel='Samples', ylabel='Cumulative Counts'>

# %%
from matplotlib import pyplot as plt
# Create a frequency distribution
#fd = nltk.FreqDist(tokens_nltk_text)

# Get the 10 most common words and their counts
common = fd.most_common(10)

# Unzip the words and counts into two separate lists
words, counts = zip(*common)

# Create a bar graph
plt.bar(words, counts)
plt.show()

# %% [markdown]
# # 3.3 Part of Speech Tagging
#
# ```
# # This is formatted as code
# ```

# %%
import nltk
from nltk import wordpunct_tokenize
nltk.pos_tag(OPSE_tokens)

# %% [markdown]
# # 3.4 Spelling correction

# %%
import nltk
from nltk import word_tokenize
from autocorrect import Speller
spell = Speller(lang='en')
OPSE_autocorrect = OPSEwords
spell('definitly')
# Out:
# 'definitely'

# %% [markdown]
# # 3.5 Stemming

# %%
import nltk
stemmer = nltk.stem.PorterStemmer()
stemmer.stem("production")
# Out:
# 'product'

# %% [markdown]
# # 3.6 Lemmatization

# %%
import nltk
nltk.download("wordnet")
from nltk.stem.wordnet import WordNetLemmatizer

# %% [markdown]
# # 4.0 Basic analysis
# 1. Word/Sentence counts
# 2. Word/Sentence lists

# %% [markdown]
# This displays the total number of individual words left after several rounds of preprocessing. These numbers are good to keep up with as you continue to clean your data.

# %%
len(OPSEwords)
# Out:
# 72769

# %% [markdown]
# The sorted set lists and alphabetizes all words that appear at least once throughout the document. This is another important step in cleaning your data. We can also use other preprocessing methods to shrink this list down such as stemming and lemmatizing.

# %%
sorted(set(OPSEwords))
# Out:
# ['aa',
#  'aac',
#  'ab',
#  'abilities',
#  'ability',
#  'able',
#  'abs',
#  'absorb',
#  'absorbed',
#  'absorption',
#  'abstract',
#  'ac',
#  'accentuated',
#  'accept',
#  'acceptable',
#  'accepted',
#  'access',
#  'accessibility',
#  'accessible',
#  'accident',
#  'accidentally',
#  'accommodations',
#  'accompany',
#  'accompanying',
#  'accomplish',
#  'accomplished',
#  'accomplishment',
#  'according',
#  'accordingly',
#  'account',
#  'accountable',
#  'accounting',
#  'accumulate',
#  'accurate',
#  'accurately',
#  'achieve',
#  'acids',
#  'acknowledge',
#  'acknowledging',
#  'aconcagua',
#  'across',
#  'act',
#  'acted',
#  'acting',
#  'action',
#  'actions',
#  'active',
#  'activities',
#  'activity',
#  'actual',
#  'actually',
#  'ad',
#  'adamant',
#  'adapt',
#  'adapted',
#  'adapting',
#  'adaptive',
#  'adaptor',
#  'add',
#  'added',
#  'adding',
#  'addition',
#  'additional',
#  'additionally',
#  'additions',
#  'address',
#  'addressed',
#  'adequate',
#  'adhere',
#  'adjust',
#  'adjusting',
#  'adopt',
#  'adopted',
#  'adults',
#  'advance',
#  'advanced',
#  'advancing',
#  'advantages',
#  'adverbs',
#  'ae',
#  'affect',
#  'affected',
#  'affecting',
#  'affects',
#  'afraid',
#  'africa',
#  'aftershocks',
#  'afterward',
#  'age',
#  'agency',
#  'ago',
#  'agree',
#  'agreed',
#  'agreedisagree',
#  'agreedupon',
#  'agreeing',
#  'agreement',
#  'agreements',
#  'agrees',
#  'agricultural',
#  'agriculture',
#  'ah',
#  'ahead',
#  'aid',
#  'aids',
#  'aim',
#  'air',
#  'airplanes',
#  'airplaying',
#  'airtime',
#  'airvacuum',
#  'al',
#  'alarm',
#  'aldana',
#  'alerting',
#  'aligned',
#  'aligning',
#  'aligns',
#  'alive',
#  'alka',
#  'allele',
#  'allergies',
#  'alligator',
#  'allow',
#  'allowed',
#  'allowing',
#  'allows',
#  'almonds',
#  'almost',
#  'alone',
#  'along',
#  'aloud',
#  'already',
#  'also',
#  'alt',
#  'altamirano',
#  'alter',
#  'altered',
#  'alternate',
#  'alternately',
#  'alternative',
#  'alternatively',
#  'although',
#  'altogether',
#  'always',
#  'amass',
#  'america',
#  'american',
#  'americans',
#  'amino',
#  'among',
#  'amorphous',
#  'amount',
#  'amounts',
#  'amp',
#  'amplifier',
#  'amplifying',
#  'amplitude',
#  'analogies',
#  'analogy',
#  'analyses',
#  'analysis',
#  'analyze',
#  'analyzed',
#  'analyzing',
#  'anatomical',
#  'ancestor',
#  'ancestors',
#  'anchor',
#  'anchoring',
#  'anchors',
#  'ancient',
#  'andor',
#  'andreas',
#  'anecdotes',
#  'anger',
#  'angle',
#  'angles',
#  'animal',
#  'animals',
#  'animatedly',
#  'animations',
#  'ankle',
#  'annette',
#  'annotate',
#  'annotated',
#  'annotating',
#  'annotation',
#  'annotations',
#  'annual',
#  'another',
#  'answer',
#  'answered',
#  'answers',
#  'antarctica',
#  'anticipate',
#  'anticipated',
#  'anticipating',
#  'anybody',
#  'anymore',
#  'anyone',
#  'anything',
#  'anytime',
#  'anyway',
#  'anywhere',
#  'apart',
#  'app',
#  'appalachian',
#  'appalachians',
#  'apparatus',
#  'apparent',
#  'appear',
#  'appearance',
#  'appeared',
#  'appearing',
#  'appears',
#  'appendix',
#  'appliances',
#  'applicable',
#  'applied',
#  'apply',
#  'appreciate',
#  'approach',
#  'approaches',
#  'appropriate',
#  'approximate',
#  'approximately',
#  'april',
#  'apron',
#  'aquarium',
#  'area',
#  'arearanges',
#  'areas',
#  'argue',
#  'arguing',
#  'argument',
#  'argumentation',
#  'arguments',
#  'arise',
#  'arizona',
#  'arm',
#  'arms',
#  'around',
#  'arrange',
#  'array',
#  'arrow',
#  'arrows',
#  'article',
#  'articles',
#  'articulate',
#  'articulated',
#  'articulating',
#  'articulation',
#  'artifact',
#  'artifacts',
#  'artistry',
#  'artists',
#  'ascertain',
#  'asia',
#  'asian',
#  'aside',
#  'ask',
#  'asked',
#  'asking',
#  'asks',
#  'asl',
#  'aspect',
#  'aspects',
#  'assemble',
#  'assembled',
#  'assembly',
#  'assess',
#  'assessing',
#  'assessment',
#  'assign',
#  'assigned',
#  'assigning',
#  'assignment',
#  'assist',
#  'assistance',
#  'assistive',
#  'associate',
#  'associated',
#  'associations',
#  'assumes',
#  'assuming',
#  'asterisk',
#  'asteroid',
#  'asthma',
#  'astigmatism',
#  'astrology',
#  'ate',
#  'atmosphere',
#  'atmospheric',
#  'atom',
#  'atoms',
#  'atop',
#  'attach',
#  'attempt',
#  'attend',
#  'attending',
#  'attention',
#  'attitudes',
#  'attract',
#  'attracted',
#  'attractive',
#  'audio',
#  'auditory',
#  'augment',
#  'australia',
#  'auxiliary',
#  'availability',
#  'available',
#  'avenue',
#  'average',
#  'avocado',
#  'avoid',
#  'avoids',
#  'aware',
#  'awareness',
#  'away',
#  'awesome',
#  'axis',
#  'b',
#  'babiesreproducing',
#  'baby',
#  'back',
#  'backdrop',
#  'background',
#  'backgrounds',
#  'backpack',
#  'backs',
#  'bacteria',
#  'bad',
#  'bag',
#  'baggies',
#  'bags',
#  'balanced',
#  'ball',
#  'balls',
#  'ballsized',
#  'banana',
#  'band',
#  'bands',
#  'bank',
#  'banner',
#  'bargh',
#  'barriers',
#  'base',
#  'baseball',
#  'based',
#  'baseline',
#  'basements',
#  'basic',
#  'basically',
#  'basket',
#  'bass',
#  'bat',
#  'batches',
#  'bath',
#  'batteries',
#  'battery',
#  'bay',
#  'bb',
#  'beak',
#  'beaker',
#  'beaks',
#  'beans',
#  'beautifully',
#  'beauty',
#  'becauses',
#  'beckon',
#  'become',
#  'becomes',
#  'beforehand',
#  'began',
#  'begin',
#  'beginning',
#  'begins',
#  'behavior',
#  'behaviors',
#  'behind',
#  'beis',
#  'believe',
#  'believed',
#  'belong',
#  'bend',
#  'beneath',
#  'beneficial',
#  'benefit',
#  'benefits',
#  'beside',
#  'besides',
#  'best',
#  'better',
#  'beverage',
#  'beyond',
#  'big',
#  'bigger',
#  'bigmuscled',
#  'bike',
#  'billion',
#  'bin',
#  'binder',
#  'bins',
#  'biochemical',
#  'biodiversity',
#  'biological',
#  'biology',
#  'bird',
#  'birds',
#  'bit',
#  'bits',
#  'black',
#  'blackandwhite',
#  'blank',
#  'blasting',
#  'bleed',
#  'blind',
#  'blindness',
#  'blinks',
#  'blizzard',
#  'blizzards',
#  'block',
#  'blocked',
#  'blocking',
#  'blood',
#  'blown',
#  'blue',
#  'bluetooth',
#  'board',
#  'boardchart',
#  'boards',
#  'bodies',
#  'body',
#  'boiling',
#  'bold',
#  'bomb',
#  'bombs',
#  'bonds',
#  'bone',
#  'bones',
#  'boneskinmuscle',
#  'book',
#  'books',
#  'border',
#  'born',
#  'borneo',
#  'borrow',
#  'bother',
#  'bottle',
#  'bottles',
#  'bottlesjars',
#  'bottom',
#  'bounced',
#  'bounces',
#  'bouncing',
#  'boundaries',
#  'boundary',
#  'bounding',
#  'bowl',
#  'bowls',
#  'box',
#  'boxes',
#  'braces',
#  'braille',
#  'brain',
#  'brains',
#  'brainstorm',
#  'brainstormed',
#  'brainstorming',
#  'brazil',
#  'bread',
#  'break',
#  'breakage',
#  'breakfast',
#  'breaking',
#  'breaks',
#  'breath',
#  'brief',
#  'briefly',
#  'bright',
#  'brightening',
#  'brightness',
#  'bring',
#  'bringing',
#  'brings',
#  'broad',
#  'broaden',
#  'broadening',
#  'broadens',
#  'broader',
#  'broadest',
#  'broadly',
#  'broke',
#  'broken',
#  'brought',
#  'brown',
#  'bubble',
#  'bubbles',
#  'bucket',
#  'budget',
#  'build',
#  'building',
#  'buildings',
#  'builds',
#  'built',
#  'bull',
#  'bulletin',
#  'bulls',
#  'bumps',
#  'bunch',
#  'bundle',
#  'bundling',
#  'buoyancy',
#  'buried',
#  'burke',
#  'burn',
#  'burns',
#  'butter',
#  'buttons',
#  'buy',
#  'buying',
#  'c',
#  'ca',
#  'cable',
#  'cables',
#  'cadence',
#  'cafeteria',
#  'calculate',
#  'calendars',
#  'call',
#  'called',
#  'calling',
#  'callout',
#  'came',
#  'camera',
#  'campfire',
#  'canada',
#  'candidate',
#  'candidates',
#  'candy',
#  'cane',
#  'caption',
#  'captioning',
#  'captions',
#  'capture',
#  'captured',
#  'capturing',
#  'car',
#  'carbohydrate',
#  'carbohydrates',
#  'carbon',
#  'carbons',
#  'card',
#  'cardboard',
#  'cardinal',
#  'cards',
#  'cardstock',
#  'care',
#  'careers',
#  'careful',
#  'carefully',
#  'caring',
#  'carnivorous',
#  'carries',
#  'carry',
#  'carrying',
#  'cars',
#  'carve',
#  'case',
#  'cases',
#  'caseworker',
#  'cast',
#  'catastrophic',
#  'categories',
#  'categorization',
#  'categorize',
#  'categorized',
#  'category',
#  'cattle',
#  'causal',
#  'cause',
#  'causeandeffect',
#  'caused',
#  'causeeffect',
#  'causes',
#  'causing',
#  'caution',
#  'cavities',
#  'cc',
#  'ccc',
#  'cccs',
#  'cd',
#  'cdc',
#  'ce',
#  'ceiling',
#  'celebrate',
#  'celestial',
#  'cell',
#  'cells',
#  'center',
#  'centers',
#  'central',
#  'centrally',
#  'centuries',
#  'cereal',
#  'certain',
#  'cf',
#  'chair',
#  'chairs',
#  'chalkboard',
#  'challenge',
#  'challenges',
#  'challenging',
#  'chance',
#  'change',
#  'changed',
#  'changes',
#  'changing',
#  'character',
#  'characteristic',
#  'characteristics',
#  'charge',
#  'charity',
#  'chart',
#  'charts',
#  'check',
#  'checked',
#  'checkin',
#  'checkmark',
#  'checks',
#  'cheese',
#  'chemical',
#  'chemicals',
#  'childcare',
#  'children',
#  'chill',
#  'china',
#  'chocolate',
#  'choice',
#  'choices',
#  'choose',
#  'choosing',
#  'chose',
#  'chosen',
#  'chromosomes',
#  'chronological',
#  'circle',
#  'circles',
#  'circling',
#  'circulate',
#  'circulating',
#  'circulation',
#  'cite',
#  'cities',
#  'city',
#  'civil',
#  'claim',
#  'claimed',
#  'claiming',
#  'claims',
#  'clarification',
#  'clarifier',
#  'clarify',
#  'clarifying',
#  'clarkelab',
#  'class',
#  'classdeveloped',
#  'classes',
#  'classical',
#  'classification',
#  'classify',
#  'classifying',
#  'classlevel',
#  'classmateengineer',
#  'classmates',
#  'classroom',
#  'classrooms',
#  'clean',
#  'cleaner',
#  'cleaning',
#  'clear',
#  'clearcutting',
#  'clearer',
#  'clearly',
#  'climate',
#  'climates',
#  'climbing',
#  'clip',
#  'clips',
#  'close',
#  'closed',
#  'closedended',
#  'closedtoe',
#  'closeended',
#  'closely',
#  'closer',
#  'closing',
#  'clothing',
#  'cloud',
#  'clouds',
#  'cloudy',
#  'clue',
#  'clues',
#  'cluster',
#  'clustering',
#  'clusters',
#  'cm',
#  'cmyear',
#  'coast',
#  'cochlear',
#  'cocoa',
#  'coconstruct',
#  'coconstructed',
#  'coconstructing',
#  'coconstruction',
#  'code',
#  'codes',
#  'coding',
#  'coffee',
#  'cognate',
#  'cognates',
#  'cognitive',
#  'coherence',
#  'coil',
#  'coiled',
#  'coils',
#  'coincides',
#  'cold',
#  'colder',
#  'collaborate',
#  'collaboration',
#  'collaborative',
#  'collaboratively',
#  'collect',
#  'collected',
#  'collecting',
#  'collection',
#  'collections',
#  'collectively',
#  'collegial',
#  'collide',
#  'collided',
#  'collides',
#  'colliding',
#  'collision',
#  'collisions',
#  'collison',
#  'color',
#  'coloration',
#  'colorblind',
#  'colored',
#  'coloring',
#  'colors',
#  'column',
#  'columns',
#  'combination',
#  'combine',
#  'combined',
#  'come',
#  'comes',
#  'comets',
#  'comfort',
#  'comfortable',
#  'comforting',
#  'coming',
#  'comment',
#  'comments',
#  'commodity',
#  'common',
#  'commonalities',
#  'commonly',
#  'communicate',
#  'communicating',
#  'communication',
#  'communities',
#  'community',
#  'compare',
#  'compared',
#  'compares',
#  'comparing',
#  'comparison',
#  'comparisons',
#  'compass',
#  'compelling',
#  'competing',
#  'compile',
#  'complete',
#  'completed',
#  'completely',
#  'completing',
#  'complex',
#  'complexity',
#  'component',
#  'components',
#  'composition',
#  'comprehend',
#  'comprehensible',
#  'comprehension',
#  'comprehensive',
#  'compression',
#  'computer',
#  'computerdevice',
#  'concept',
#  'conceptions',
#  'concepts',
#  'conceptual',
#  'conceptualizing',
#  'concern',
#  'concerned',
#  'concerning',
#  'concerns',
#  'concert',
#  'conclude',
#  'concluded',
#  'concludes',
#  'conclusion',
#  'conclusions',
#  'concretely',
#  'concurrent',
#  'condensation',
#  'condense',
#  'condenses',
#  'condition',
#  'conditions',
#  'conduct',
#  'conducting',
#  'conduction',
#  'conductor',
#  'cone',
#  'confidence',
#  'confirm',
#  'confused',
#  'confusing',
#  'congregate',
#  'connect',
#  'connected',
#  'connecting',
#  'connection',
#  'connections',
#  'connects',
#  'consensus',
#  'consensusbuilding',
#  'consequently',
#  'conserved',
#  'consider',
#  'considered',
#  'considering',
#  'considers',
#  'consist',
#  'consistent',
#  'consists',
#  'consolidate',
#  'constant',
#  'constantly',
#  'constellation',
#  'constellations',
#  'constitutes',
#  'constraints',
#  'construct',
#  'constructed',
#  'constructing',
#  'construction',
#  'constructive',
#  'consumer',
#  'contact',
#  'contain',
#  'container',
#  'containers',
#  'containing',
#  'contains',
#  'contamination',
#  'contents',
#  'contentspecific',
#  'context',
#  'contexts',
#  'continent',
#  'continents',
#  'continually',
#  'continue',
#  'continued',
#  'continues',
#  'continuum',
#  'contrast',
#  'contribute',
#  'contributed',
#  'contributes',
#  'contributing',
#  'contributions',
#  'contrived',
#  'control',
#  'controlled',
#  'controls',
#  'controversial',
#  'controversy',
#  'convection',
#  'convene',
#  'convenience',
#  'conveniently',
#  'convening',
#  'convention',
#  'conventions',
#  'converge',
#  'conversation',
#  'conversations',
#  'convey',
#  'conveys',
#  'convince',
#  'convinced',
#  'cook',
#  'cooking',
#  'cool',
#  'cooler',
#  'cooling',
#  'cools',
#  'coordinate',
#  'coordinating',
#  'copied',
#  'copies',
#  'copper',
#  'copy',
#  'core',
#  'corn',
#  'corner',
#  'corp',
#  'correct',
#  'correctly',
#  'correlational',
#  'correspond',
#  'corresponding',
#  'cosmetic',
#  'cosmeticpersonal',
#  'cost',
#  'costs',
#  'cotton',
#  'could',
#  'count',
#  'counterpart',
#  'counting',
#  'countless',
#  'countries',
#  'country',
#  'couple',
#  'course',
#  'covered',
#  'covering',
#  'coverings',
#  'crack',
#  'cracked',
#  'create',
#  'created',
#  'creating',
#  'criteria',
#  'critical',
#  'criticism',
#  'criticizing',
#  'critiquing',
#  'crooked',
#  'crop',
#  'crops',
#  'cross',
#  'crosscurricular',
#  'crosscutting',
#  'crucial',
#  'crust',
#  'crustaceans',
#  'crutches',
#  'crystals',
#  'csw',
#  'cube',
#  'cubes',
#  'cue',
#  'culminate',
#  'cultivate',
#  'cultivation',
#  'cultural',
#  'culturally',
#  'culture',
#  'cultures',
#  'cup',
#  'cups',
#  'curiosities',
#  'curiosity',
#  'curious',
#  'current',
#  'currently',
#  'curvy',
#  'cut',
#  'cuts',
#  'cutting',
#  'cycle',
#  'cycling',
#  'daily',
#  'damage',
#  'damaged',
#  'damages',
#  'damaging',
#  'dance',
#  'dancing',
#  ...]

# %% [markdown]
# # 4.1 More quick analysis options
# 1. concordance
# 2. similar words
# 3. dispersion plots

# %%
OPSE_tokens.concordance('remember', lines = 50)
# Out:
# Displaying 16 of 16 matches:
#  beyond minutes pronounced results remember share data students start day deve
#  meet scientists circle around dqb remember backdrop dqb could classroom conse
# nsensus model poster tell students remember goal discussion figure areas agree
# ng diagram write short explanation remember label diagram someone else could u
# riences learned ask family members remember first experienced hazard learned h
# odels try show see also try anyone remember looking something different perspe
# ass ready consensus discussion say remember goal discussion figure areas agree
# sbuilding discussion tell students remember goal discussion figure areas agree
#  meet scientists circle around dqb remember posters initial consensus model re
# fine criteria constraints solution remember words mean take moment turn talk p
# r unusually low say something like remember reservoir really high march super
#  unusually high say something like remember recent flood got place experiencin
# rsation similar ones shown drawing remember represent phone white box object s
# or knowledge experiences leveraged remember let words representations students
#  another pedro project slide k say remember question started considering first
# ing emerging multilingual students remember use words students use whenever po

# %%
OPSE_tokens.similar("students")
# Out:
# ideas question model students share phenomena brainstorm models
# knowledge display prompts student using develop initial class
# investigations look observations noticings

# %%
OPSE_tokens.dispersion_plot(["students","teacher", "diverse", "diversity", "teacher", "student"])

# %% [markdown]
# # 4.2 n-grams and colocations
# 1. bigrams
# 2. trigrams

# %%
equity_text_tokens_bigrams = list(nltk.bigrams(OPSEwords))
equity_text_tokens_bigrams
# Out:
# [('lesson', 'something'),
#  ('something', 'act'),
#  ('act', 'like'),
#  ('like', 'mirror'),
#  ('mirror', 'window'),
#  ('window', 'time'),
#  ('time', 'lesson'),
#  ('lesson', 'anchoring'),
#  ('anchoring', 'phenomenon'),
#  ('phenomenon', 'days'),
#  ('days', 'watch'),
#  ('watch', 'puzzling'),
#  ('puzzling', 'video'),
#  ('video', 'music'),
#  ('music', 'student'),
#  ('student', 'see'),
#  ('see', 'reflection'),
#  ('reflection', 'seems'),
#  ('seems', 'mirror'),
#  ('mirror', 'student'),
#  ('student', 'see'),
#  ('see', 'teacher'),
#  ('teacher', 'side'),
#  ('side', 'mirror'),
#  ('mirror', 'teacher'),
#  ('teacher', 'see'),
#  ('see', 'student'),
#  ('student', 'wonder'),
#  ('wonder', 'something'),
#  ('something', 'act'),
#  ('act', 'like'),
#  ('like', 'mirror'),
#  ('mirror', 'window'),
#  ('window', 'time'),
#  ('time', 'investigate'),
#  ('investigate', 'scenario'),
#  ('scenario', 'using'),
#  ('using', 'box'),
#  ('box', 'model'),
#  ('model', 'maps'),
#  ('maps', 'system'),
#  ('system', 'video'),
#  ('video', 'develop'),
#  ('develop', 'initial'),
#  ('initial', 'class'),
#  ('class', 'consensus'),
#  ('consensus', 'model'),
#  ('model', 'explain'),
#  ('explain', 'oneway'),
#  ('oneway', 'mirror'),
#  ('mirror', 'phenomenon'),
#  ('phenomenon', 'identify'),
#  ('identify', 'related'),
#  ('related', 'phenomena'),
#  ('phenomena', 'could'),
#  ('could', 'help'),
#  ('help', 'us'),
#  ('us', 'explain'),
#  ('explain', 'share'),
#  ('share', 'questions'),
#  ('questions', 'oneway'),
#  ('oneway', 'mirror'),
#  ('mirror', 'helps'),
#  ('helps', 'us'),
#  ('us', 'form'),
#  ('form', 'driving'),
#  ('driving', 'question'),
#  ('question', 'board'),
#  ('board', 'brainstorm'),
#  ('brainstorm', 'investigations'),
#  ('investigations', 'data'),
#  ('data', 'need'),
#  ('need', 'answer'),
#  ('answer', 'questions'),
#  ('questions', 'building'),
#  ('building', 'toward'),
#  ('toward', 'ngss'),
#  ('ngss', 'students'),
#  ('students', 'develop'),
#  ('develop', 'model'),
#  ('model', 'identify'),
#  ('identify', 'important'),
#  ('important', 'parts'),
#  ('parts', 'system'),
#  ('system', 'parts'),
#  ('parts', 'interact'),
#  ('interact', 'could'),
#  ('could', 'cause'),
#  ('cause', 'object'),
#  ('object', 'look'),
#  ('look', 'different'),
#  ('different', 'different'),
#  ('different', 'light'),
#  ('light', 'conditions'),
#  ('conditions', 'ask'),
#  ('ask', 'questions'),
#  ('questions', 'arise'),
#  ('arise', 'observations'),
#  ('observations', 'phenomenon'),
#  ('phenomenon', 'object'),
#  ('object', 'appears'),
#  ('appears', 'different'),
#  ('different', 'depending'),
#  ('depending', 'light'),
#  ('light', 'conditions'),
#  ('conditions', 'within'),
#  ('within', 'defined'),
#  ('defined', 'system'),
#  ('system', 'students'),
#  ('students', 'figure'),
#  ('figure', 'materials'),
#  ('materials', 'reflective'),
#  ('reflective', 'seethrough'),
#  ('seethrough', 'time'),
#  ('time', 'whether'),
#  ('whether', 'material'),
#  ('material', 'reflective'),
#  ('reflective', 'seethrough'),
#  ('seethrough', 'may'),
#  ('may', 'related'),
#  ('related', 'light'),
#  ('light', 'lesson'),
#  ('lesson', 'learning'),
#  ('learning', 'plan'),
#  ('plan', 'snapshot'),
#  ('snapshot', 'part'),
#  ('part', 'duration'),
#  ('duration', 'summary'),
#  ('summary', 'slide'),
#  ('slide', 'materials'),
#  ('materials', 'min'),
#  ('min', 'introduce'),
#  ('introduce', 'puzzling'),
#  ('puzzling', 'phenomenon'),
#  ('phenomenon', 'play'),
#  ('play', 'music'),
#  ('music', 'lesson'),
#  ('lesson', 'video'),
#  ('video', 'showing'),
#  ('showing', 'student'),
#  ('student', 'see'),
#  ('see', 'reflection'),
#  ('reflection', 'oneway'),
#  ('oneway', 'mirror'),
#  ('mirror', 'teacher'),
#  ('teacher', 'side'),
#  ('side', 'see'),
#  ('see', 'oneway'),
#  ('oneway', 'mirror'),
#  ('mirror', 'students'),
#  ('students', 'record'),
#  ('record', 'noticings'),
#  ('noticings', 'wonderings'),
#  ('wonderings', 'computer'),
#  ('computer', 'projector'),
#  ('projector', 'music'),
#  ('music', 'lesson'),
#  ('lesson', 'video'),
#  ('video', 'min'),
#  ('min', 'share'),
#  ('share', 'noticings'),
#  ('noticings', 'wonderings'),
#  ('wonderings', 'video'),
#  ('video', 'share'),
#  ('share', 'noticings'),
#  ('noticings', 'wonderings'),
#  ('wonderings', 'video'),
#  ('video', 'partner'),
#  ('partner', 'lead'),
#  ('lead', 'class'),
#  ('class', 'discussion'),
#  ('discussion', 'record'),
#  ('record', 'observations'),
#  ('observations', 'questions'),
#  ('questions', 'class'),
#  ('class', 'chart'),
#  ('chart', 'b'),
#  ('b', 'notice'),
#  ('notice', 'wonder'),
#  ('wonder', 'chart'),
#  ('chart', 'prepared'),
#  ('prepared', 'advance'),
#  ('advance', 'markers'),
#  ('markers', 'min'),
#  ('min', 'identify'),
#  ('identify', 'parts'),
#  ('parts', 'interactions'),
#  ('interactions', 'diagram'),
#  ('diagram', 'thinking'),
#  ('thinking', 'partner'),
#  ('partner', 'talk'),
#  ('talk', 'class'),
#  ('class', 'discussion'),
#  ('discussion', 'coconstruct'),
#  ('coconstruct', 'list'),
#  ('list', 'important'),
#  ('important', 'parts'),
#  ('parts', 'video'),
#  ('video', 'phenomenon'),
#  ('phenomenon', 'diagram'),
#  ('diagram', 'interactions'),
#  ('interactions', 'included'),
#  ('included', 'initial'),
#  ('initial', 'explanations'),
#  ('explanations', 'ce'),
#  ('ce', 'initial'),
#  ('initial', 'diagram'),
#  ('diagram', 'explain'),
#  ('explain', 'phenomenon'),
#  ('phenomenon', 'optional'),
#  ('optional', 'parts'),
#  ('parts', 'chart'),
#  ('chart', 'prepared'),
#  ('prepared', 'advance'),
#  ('advance', 'markers'),
#  ('markers', 'min'),
#  ('min', 'compare'),
#  ('compare', 'diagrams'),
#  ('diagrams', 'partner'),
#  ('partner', 'arrange'),
#  ('arrange', 'students'),
#  ('students', 'partners'),
#  ('partners', 'share'),
#  ('share', 'diagrams'),
#  ('diagrams', 'note'),
#  ('note', 'similarities'),
#  ('similarities', 'differences'),
#  ('differences', 'f'),
#  ('f', 'initial'),
#  ('initial', 'diagram'),
#  ('diagram', 'explain'),
#  ('explain', 'phenomenon'),
#  ('phenomenon', 'optional'),
#  ('optional', 'min'),
#  ('min', 'navigation'),
#  ('navigation', 'brainstorm'),
#  ('brainstorm', 'ideas'),
#  ('ideas', 'making'),
#  ('making', 'scale'),
#  ('scale', 'model'),
#  ('model', 'represents'),
#  ('represents', 'system'),
#  ('system', 'video'),
#  ('video', 'investigate'),
#  ('investigate', 'phenomenon'),
#  ('phenomenon', 'classroom'),
#  ('classroom', 'g'),
#  ('g', 'end'),
#  ('end', 'day'),
#  ('day', 'min'),
#  ('min', 'navigation'),
#  ('navigation', 'introduce'),
#  ('introduce', 'box'),
#  ('box', 'model'),
#  ('model', 'elicit'),
#  ('elicit', 'prior'),
#  ('prior', 'experiences'),
#  ('experiences', 'scale'),
#  ('scale', 'models'),
#  ('models', 'h'),
#  ('h', 'box'),
#  ('box', 'model'),
#  ('model', 'setup'),
#  ('setup', 'picture'),
#  ('picture', 'mat'),
#  ('mat', 'set'),
#  ('set', 'oneway'),
#  ('oneway', 'mirror'),
#  ('mirror', 'film'),
#  ('film', 'flashlight'),
#  ('flashlight', 'toys'),
#  ('toys', 'min'),
#  ('min', 'map'),
#  ('map', 'box'),
#  ('box', 'model'),
#  ('model', 'video'),
#  ('video', 'guide'),
#  ('guide', 'students'),
#  ('students', 'mapping'),
#  ('mapping', 'parts'),
#  ('parts', 'box'),
#  ('box', 'model'),
#  ('model', 'important'),
#  ('important', 'parts'),
#  ('parts', 'video'),
#  ('video', 'use'),
#  ('use', 'mapping'),
#  ('mapping', 'highlight'),
#  ('highlight', 'benefits'),
#  ('benefits', 'limitations'),
#  ('limitations', 'using'),
#  ('using', 'box'),
#  ('box', 'model'),
#  ('model', 'mapping'),
#  ('mapping', 'model'),
#  ('model', 'chart'),
#  ('chart', 'prepared'),
#  ('prepared', 'advance'),
#  ('advance', 'parts'),
#  ('parts', 'chart'),
#  ('chart', 'prepared'),
#  ('prepared', 'advance'),
#  ('advance', 'markers'),
#  ('markers', 'min'),
#  ('min', 'carry'),
#  ('carry', 'box'),
#  ('box', 'model'),
#  ('model', 'investigation'),
#  ('investigation', 'give'),
#  ('give', 'students'),
#  ('students', 'time'),
#  ('time', 'explore'),
#  ('explore', 'box'),
#  ('box', 'model'),
#  ('model', 'add'),
#  ('add', 'noticings'),
#  ('noticings', 'wonderings'),
#  ('wonderings', 'chart'),
#  ('chart', 'j'),
#  ('j', 'box'),
#  ('box', 'model'),
#  ('model', 'setup'),
#  ('setup', 'picture'),
#  ('picture', 'mat'),
#  ('mat', 'set'),
#  ('set', 'oneway'),
#  ('oneway', 'mirror'),
#  ('mirror', 'film'),
#  ('film', 'flashlight'),
#  ('flashlight', 'toys'),
#  ('toys', 'min'),
#  ('min', 'share'),
#  ('share', 'observations'),
#  ('observations', 'box'),
#  ('box', 'model'),
#  ('model', 'investigation'),
#  ('investigation', 'facilitate'),
#  ('facilitate', 'class'),
#  ('class', 'discussion'),
#  ('discussion', 'connect'),
#  ('connect', 'students'),
#  ('students', 'noticed'),
#  ('noticed', 'wondered'),
#  ('wondered', 'box'),
#  ('box', 'model'),
#  ('model', 'investigation'),
#  ('investigation', 'saw'),
#  ('saw', 'video'),
#  ('video', 'evaluate'),
#  ('evaluate', 'box'),
#  ('box', 'model'),
#  ('model', 'kl'),
#  ('kl', 'communicating'),
#  ('communicating', 'scientific'),
#  ('scientific', 'ways'),
#  ('ways', 'handout'),
#  ('handout', 'notice'),
#  ('notice', 'wonder'),
#  ('wonder', 'chart'),
#  ('chart', 'prepared'),
#  ('prepared', 'advance'),
#  ('advance', 'markers'),
#  ('markers', 'min'),
#  ('min', 'navigation'),
#  ('navigation', 'ask'),
#  ('ask', 'students'),
#  ('students', 'complete'),
#  ('complete', 'exit'),
#  ('exit', 'ticket'),
#  ('ticket', 'preparation'),
#  ('preparation', 'consensus'),
#  ('consensus', 'discussion'),
#  ('discussion', 'index'),
#  ('index', 'card'),
#  ('card', 'end'),
#  ('end', 'day'),
#  ('day', 'min'),
#  ('min', 'form'),
#  ('form', 'scientists'),
#  ('scientists', 'circle'),
#  ('circle', 'discuss'),
#  ('discuss', 'classroom'),
#  ('classroom', 'norms'),
#  ('norms', 'arrange'),
#  ('arrange', 'classroom'),
#  ('classroom', 'students'),
#  ('students', 'scientists'),
#  ('scientists', 'circle'),
#  ('circle', 'developing'),
#  ('developing', 'classroom'),
#  ('classroom', 'consensus'),
#  ('consensus', 'model'),
#  ('model', 'develop'),
#  ('develop', 'explicit'),
#  ('explicit', 'shared'),
#  ('shared', 'norms'),
#  ('norms', 'learning'),
#  ('learning', 'community'),
#  ('community', 'n'),
#  ('n', 'science'),
#  ('science', 'classroom'),
#  ('classroom', 'norms'),
#  ('norms', 'min'),
#  ('min', 'develop'),
#  ('develop', 'initial'),
#  ('initial', 'class'),
#  ('class', 'consensus'),
#  ('consensus', 'model'),
#  ('model', 'stay'),
#  ('stay', 'scientists'),
#  ('scientists', 'circle'),
#  ('circle', 'students'),
#  ('students', 'share'),
#  ('share', 'diagrams'),
#  ('diagrams', 'facilitate'),
#  ('facilitate', 'consensus'),
#  ('consensus', 'discussion'),
#  ('discussion', 'develop'),
#  ('develop', 'initial'),
#  ('initial', 'class'),
#  ('class', 'consensus'),
#  ('consensus', 'model'),
#  ('model', 'oq'),
#  ('oq', 'initial'),
#  ('initial', 'class'),
#  ('class', 'consensus'),
#  ('consensus', 'model'),
#  ('model', 'prepared'),
#  ('prepared', 'advance'),
#  ('advance', 'markers'),
#  ('markers', 'min'),
#  ('min', 'brainstorm'),
#  ('brainstorm', 'related'),
#  ('related', 'phenomena'),
#  ('phenomena', 'assign'),
#  ('assign', 'selfdocumentation'),
#  ('selfdocumentation', 'generate'),
#  ('generate', 'class'),
#  ('class', 'list'),
#  ('list', 'possible'),
#  ('possible', 'related'),
#  ('related', 'phenomena'),
#  ('phenomena', 'experiences'),
#  ('experiences', 'assign'),
#  ('assign', 'home'),
#  ('home', 'learning'),
#  ('learning', 'students'),
#  ('students', 'document'),
#  ('document', 'related'),
#  ('related', 'phenomena'),
#  ('phenomena', 'lives'),
#  ('lives', 'next'),
#  ('next', 'days'),
#  ('days', 'rs'),
#  ('rs', 'related'),
#  ('related', 'phenomena'),
#  ('phenomena', 'list'),
#  ('list', 'prepared'),
#  ('prepared', 'advance'),
#  ('advance', 'markers'),
#  ('markers', 'end'),
#  ('end', 'day'),
#  ('day', 'min'),
#  ('min', 'write'),
#  ('write', 'questions'),
#  ('questions', 'driving'),
#  ('driving', 'question'),
#  ('question', 'board'),
#  ('board', 'students'),
#  ('students', 'individually'),
#  ('individually', 'generate'),
#  ('generate', 'questions'),
#  ('questions', 'phenomenon'),
#  ('phenomenon', 'preparation'),
#  ('preparation', 'building'),
#  ('building', 'dqb'),
#  ('dqb', 'tu'),
#  ('tu', 'sticky'),
#  ('sticky', 'notes'),
#  ('notes', 'marker'),
#  ('marker', 'min'),
#  ('min', 'develop'),
#  ('develop', 'driving'),
#  ('driving', 'question'),
#  ('question', 'board'),
#  ('board', 'share'),
#  ('share', 'questions'),
#  ('questions', 'build'),
#  ('build', 'dqb'),
#  ('dqb', 'causing'),
#  ('causing', 'phenomenon'),
#  ('phenomenon', 'observed'),
#  ('observed', 'lesson'),
#  ('lesson', 'vw'),
#  ('vw', 'driving'),
#  ('driving', 'question'),
#  ('question', 'board'),
#  ('board', 'overlaid'),
#  ('overlaid', 'initial'),
#  ('initial', 'class'),
#  ('class', 'consensus'),
#  ('consensus', 'model'),
#  ('model', 'min'),
#  ('min', 'develop'),
#  ('develop', 'ideas'),
#  ('ideas', 'future'),
#  ('future', 'investigation'),
#  ('investigation', 'students'),
#  ('students', 'use'),
#  ('use', 'dqb'),
#  ('dqb', 'develop'),
#  ('develop', 'list'),
#  ('list', 'investigations'),
#  ('investigations', 'could'),
#  ('could', 'conduct'),
#  ('conduct', 'answer'),
#  ('answer', 'questions'),
#  ('questions', 'explain'),
#  ('explain', 'oneway'),
#  ('oneway', 'mirror'),
#  ('mirror', 'phenomenon'),
#  ('phenomenon', 'x'),
#  ('x', 'ideas'),
#  ('ideas', 'investigations'),
#  ('investigations', 'chart'),
#  ('chart', 'prepared'),
#  ('prepared', 'advance'),
#  ('advance', 'markers'),
#  ('markers', 'min'),
#  ('min', 'decide'),
#  ('decide', 'go'),
#  ('go', 'next'),
#  ('next', 'students'),
#  ('students', 'predict'),
#  ('predict', 'would'),
#  ('would', 'happen'),
#  ('happen', 'switch'),
#  ('switch', 'light'),
#  ('light', 'room'),
#  ('room', 'box'),
#  ('box', 'model'),
#  ('model', 'yz'),
#  ('yz', 'end'),
#  ('end', 'day'),
#  ('day', 'lesson'),
#  ('lesson', 'materials'),
#  ('materials', 'list'),
#  ('list', 'per'),
#  ('per', 'student'),
#  ('student', 'per'),
#  ('per', 'group'),
#  ('group', 'per'),
#  ('per', 'class'),
#  ('class', 'lesson'),
#  ('lesson', 'materials'),
#  ('materials', 'science'),
#  ('science', 'notebook'),
#  ('notebook', 'initial'),
#  ('initial', 'diagram'),
#  ('diagram', 'explain'),
#  ('explain', 'phenomenon'),
#  ('phenomenon', 'optional'),
#  ('optional', 'communicating'),
#  ('communicating', 'scientific'),
#  ('scientific', 'ways'),
#  ('ways', 'handout'),
#  ('handout', 'index'),
#  ('index', 'card'),
#  ('card', 'science'),
#  ('science', 'classroom'),
#  ('classroom', 'norms'),
#  ('norms', 'sticky'),
#  ('sticky', 'notes'),
#  ('notes', 'marker'),
#  ('marker', 'box'),
#  ('box', 'model'),
#  ('model', 'setup'),
#  ('setup', 'picture'),
#  ('picture', 'mat'),
#  ('mat', 'set'),
#  ('set', 'oneway'),
#  ('oneway', 'mirror'),
#  ('mirror', 'film'),
#  ('film', 'flashlight'),
#  ('flashlight', 'toys'),
#  ('toys', 'computer'),
#  ('computer', 'projector'),
#  ('projector', 'music'),
#  ('music', 'lesson'),
#  ('lesson', 'video'),
#  ('video', 'notice'),
#  ('notice', 'wonder'),
#  ('wonder', 'chart'),
#  ('chart', 'prepared'),
#  ('prepared', 'advance'),
#  ('advance', 'markers'),
#  ('markers', 'parts'),
#  ('parts', 'chart'),
#  ('chart', 'prepared'),
#  ('prepared', 'advance'),
#  ('advance', 'mapping'),
#  ('mapping', 'model'),
#  ('model', 'chart'),
#  ('chart', 'prepared'),
#  ('prepared', 'advance'),
#  ('advance', 'initial'),
#  ('initial', 'class'),
#  ('class', 'consensus'),
#  ('consensus', 'model'),
#  ('model', 'prepared'),
#  ('prepared', 'advance'),
#  ('advance', 'related'),
#  ('related', 'phenomena'),
#  ('phenomena', 'list'),
#  ('list', 'prepared'),
#  ('prepared', 'advance'),
#  ('advance', 'driving'),
#  ('driving', 'question'),
#  ('question', 'board'),
#  ('board', 'overlaid'),
#  ('overlaid', 'initial'),
#  ('initial', 'class'),
#  ('class', 'consensus'),
#  ('consensus', 'model'),
#  ('model', 'ideas'),
#  ('ideas', 'investigations'),
#  ('investigations', 'chart'),
#  ('chart', 'prepared'),
#  ('prepared', 'advance'),
#  ('advance', 'materials'),
#  ('materials', 'preparation'),
#  ('preparation', 'minutes'),
#  ('minutes', 'review'),
#  ('review', 'teacher'),
#  ('teacher', 'guide'),
#  ('guide', 'slides'),
#  ('slides', 'teacher'),
#  ('teacher', 'references'),
#  ('references', 'keys'),
#  ('keys', 'applicable'),
#  ('applicable', 'make'),
#  ('make', 'copies'),
#  ('copies', 'handouts'),
#  ('handouts', 'ensure'),
#  ('ensure', 'sufficient'),
#  ('sufficient', 'copies'),
#  ('copies', 'student'),
#  ('student', 'references'),
#  ('references', 'readings'),
#  ('readings', 'procedures'),
#  ('procedures', 'available'),
#  ('available', 'check'),
#  ('check', 'music'),
#  ('music', 'lesson'),
#  ('lesson', 'video'),
#  ('video', 'clip'),
#  ('clip', 'https'),
#  ('https', 'ensure'),
#  ('ensure', 'plays'),
#  ('plays', 'device'),
#  ('device', 'viewed'),
#  ('viewed', 'whole'),
#  ('whole', 'class'),
#  ('class', 'use'),
#  ('use', 'box'),
#  ('box', 'model'),
#  ('model', 'assembly'),
#  ('assembly', 'instructions'),
#  ('instructions', 'build'),
#  ('build', 'box'),
#  ('box', 'models'),
#  ('models', 'larger'),
#  ('larger', 'class'),
#  ('class', 'may'),
#  ('may', 'want'),
#  ('want', 'build'),
#  ('build', 'ensure'),
#  ('ensure', 'smaller'),
#  ('smaller', 'group'),
#  ('group', 'sizes'),
#  ('sizes', 'box'),
#  ('box', 'model'),
#  ('model', 'takes'),
#  ('takes', 'approximately'),
#  ('approximately', 'minutes'),
#  ('minutes', 'assemble'),
#  ('assemble', 'though'),
#  ('though', 'first'),
#  ('first', 'one'),
#  ('one', 'may'),
#  ('may', 'take'),
#  ('take', 'longer'),
#  ('longer', 'learn'),
#  ('learn', 'procedures'),
#  ('procedures', 'built'),
#  ('built', 'models'),
#  ('models', 'used'),
#  ('used', 'future'),
#  ('future', 'edit'),
#  ('edit', 'science'),
#  ('science', 'classroom'),
#  ('classroom', 'norms'),
#  ('norms', 'slide'),
#  ('slide', 'n'),
#  ('n', 'necessary'),
#  ('necessary', 'include'),
#  ('include', 'norms'),
#  ('norms', 'want'),
#  ('want', 'adopt'),
#  ('adopt', 'classroom'),
#  ('classroom', 'also'),
#  ('also', 'introduce'),
#  ('introduce', 'communicating'),
#  ('communicating', 'scientific'),
#  ('scientific', 'ways'),
#  ('ways', 'sentence'),
#  ('sentence', 'starters'),
#  ('starters', 'provide'),
#  ('provide', 'handout'),
#  ('handout', 'students'),
#  ('students', 'tape'),
#  ('tape', 'science'),
#  ('science', 'notebook'),
#  ('notebook', 'post'),
#  ('post', 'classroom'),
#  ('classroom', 'reference'),
#  ('reference', 'chart'),
#  ('chart', 'prepare'),
#  ('prepare', 'following'),
#  ('following', 'spaces'),
#  ('spaces', 'charts'),
#  ('charts', 'used'),
#  ('used', 'throughout'),
#  ('throughout', 'unit'),
#  ('unit', 'day'),
#  ('day', 'notice'),
#  ('notice', 'wonder'),
#  ('wonder', 'chart'),
#  ('chart', 'parts'),
#  ('parts', 'chart'),
#  ('chart', 'day'),
#  ('day', 'mapping'),
#  ('mapping', 'model'),
#  ('model', 'chart'),
#  ('chart', 'chart'),
#  ('chart', 'paper'),
#  ('paper', 'whiteboard'),
#  ('whiteboard', 'project'),
#  ('project', 'slide'),
#  ('slide', 'whiteboard'),
#  ('whiteboard', 'day'),
#  ('day', 'initial'),
#  ('initial', 'class'),
#  ('class', 'consensus'),
#  ('consensus', 'model'),
#  ('model', 'chart'),
#  ('chart', 'paper'),
#  ('paper', 'related'),
#  ('related', 'phenomena'),
#  ('phenomena', 'list'),
#  ('list', 'day'),
#  ('day', 'ideas'),
#  ('ideas', 'investigations'),
#  ('investigations', 'chart'),
#  ('chart', 'also'),
#  ('also', 'prior'),
#  ('prior', 'day'),
#  ('day', 'determine'),
#  ('determine', 'set'),
#  ('set', 'dqb'),
#  ('dqb', 'students'),
#  ('students', 'gather'),
#  ('gather', 'around'),
#  ('around', 'use'),
#  ('use', 'initial'),
#  ('initial', 'class'),
#  ('class', 'consensus'),
#  ('consensus', 'model'),
#  ('model', 'backdrop'),
#  ('backdrop', 'dqb'),
#  ('dqb', 'day'),
#  ('day', 'box'),
#  ('box', 'model'),
#  ('model', 'investigation'),
#  ('investigation', 'group'),
#  ('group', 'size'),
#  ('size', 'depend'),
#  ('depend', 'class'),
#  ('class', 'size'),
#  ('size', 'number'),
#  ('number', 'models'),
#  ('models', 'build'),
#  ('build', 'setup'),
#  ('setup', 'see'),
#  ('see', 'box'),
#  ('box', 'model'),
#  ('model', 'assembly'),
#  ('assembly', 'instructions'),
#  ('instructions', 'building'),
#  ('building', 'instructions'),
#  ('instructions', 'models'),
#  ('models', 'assembled'),
#  ('assembled', 'store'),
#  ('store', 'location'),
#  ('location', 'students'),
#  ('students', 'see'),
#  ('see', 'day'),
#  ('day', 'ready'),
#  ('ready', 'students'),
#  ('students', 'work'),
#  ('work', 'models'),
#  ('models', 'arrange'),
#  ('arrange', 'around'),
#  ('around', 'classroom'),
#  ('classroom', 'facilitate'),
#  ('facilitate', 'smallgroup'),
#  ('smallgroup', 'work'),
#  ('work', 'box'),
#  ('box', 'model'),
#  ('model', 'setup'),
#  ('setup', 'completely'),
#  ('completely', 'assembled'),
#  ('assembled', 'investigation'),
#  ('investigation', 'oneway'),
#  ('oneway', 'mirror'),
#  ('mirror', 'film'),
#  ('film', 'already'),
#  ('already', 'inserted'),
#  ('inserted', 'box'),
#  ('box', 'check'),
#  ('check', 'batteries'),
#  ('batteries', 'flashlights'),
#  ('flashlights', 'replace'),
#  ('replace', 'needed'),
#  ('needed', 'notes'),
#  ('notes', 'lab'),
#  ('lab', 'viewing'),
#  ('viewing', 'holes'),
#  ('holes', 'may'),
#  ('may', 'allow'),
#  ('allow', 'light'),
#  ('light', 'box'),
#  ('box', 'diminish'),
#  ('diminish', 'desired'),
#  ('desired', 'effect'),
#  ('effect', 'dim'),
#  ('dim', 'classroom'),
#  ('classroom', 'lights'),
#  ('lights', 'minimize'),
#  ('minimize', 'problem'),
#  ('problem', 'storage'),
#  ('storage', 'box'),
#  ('box', 'models'),
#  ('models', 'used'),
#  ('used', 'lesson'),
#  ('lesson', 'lesson'),
#  ('lesson', 'going'),
#  ('going', 'going'),
#  ('going', 'going'),
#  ('going', 'first'),
#  ('first', 'lesson'),
#  ('lesson', 'elicits'),
#  ('elicits', 'initial'),
#  ('initial', 'ideas'),
#  ('ideas', 'causes'),
#  ('causes', 'us'),
#  ('us', 'see'),
#  ('see', 'different'),
#  ('different', 'things'),
#  ('things', 'material'),
#  ('material', 'lesson'),
#  ('lesson', 'sequenced'),
#  ('sequenced', 'elicit'),
#  ('elicit', 'initial'),
#  ('initial', 'ideas'),
#  ('ideas', 'conditions'),
#  ('conditions', 'sight'),
#  ('sight', 'ie'),
#  ('ie', 'need'),
#  ('need', 'order'),
#  ('order', 'see'),
#  ('see', 'different'),
#  ('different', 'ways'),
#  ('ways', 'light'),
#  ('light', 'interacts'),
#  ('interacts', 'materials'),
#  ('materials', 'many'),
#  ('many', 'students'),
#  ('students', 'curious'),
#  ('curious', 'material'),
#  ('material', 'act'),
#  ('act', 'mirror'),
#  ('mirror', 'window'),
#  ('window', 'time'),
#  ('time', 'deepen'),
#  ('deepen', 'understanding'),
#  ('understanding', 'anchoring'),
#  ('anchoring', 'phenomenon'),
#  ('phenomenon', 'using'),
#  ('using', 'scale'),
#  ('scale', 'model'),
#  ('model', 'help'),
#  ('help', 'explain'),
#  ('explain', 'happening'),
#  ('happening', 'real'),
#  ('real', 'world'),
#  ('world', 'curiosities'),
#  ('curiosities', 'seed'),
#  ('seed', 'initial'),
#  ('initial', 'questions'),
#  ('questions', 'future'),
#  ('future', 'investigations'),
#  ('investigations', 'positioning'),
#  ('positioning', 'light'),
#  ('light', 'two'),
#  ('two', 'rooms'),
#  ('rooms', 'interactions'),
#  ('interactions', 'oneway'),
#  ('oneway', 'mirror'),
#  ('mirror', 'compared'),
#  ('compared', 'regular'),
#  ('regular', 'mirror'),
#  ('mirror', 'regular'),
#  ('regular', 'piece'),
#  ('piece', 'glass'),
#  ('glass', 'structure'),
#  ('structure', 'oneway'),
#  ('oneway', 'mirror'),
#  ('mirror', 'compared'),
#  ('compared', 'regular'),
#  ('regular', 'mirror'),
#  ('mirror', 'piece'),
#  ('piece', 'glass'),
#  ('glass', 'students'),
#  ('students', 'also'),
#  ('also', 'delve'),
#  ('delve', 'see'),
#  ('see', 'objects'),
#  ('objects', 'eye'),
#  ('eye', 'processes'),
#  ('processes', 'light'),
#  ('light', 'inputs'),
#  ('inputs', 'different'),
#  ('different', 'intensities'),
#  ('intensities', 'brightness'),
#  ('brightness', 'day'),
#  ('day', 'refers'),
#  ('refers', 'material'),
#  ('material', 'starting'),
#  ('starting', 'day'),
#  ('day', 'refer'),
#  ('refer', 'name'),
#  ('name', 'adopted'),
#  ('adopted', 'class'),
#  ('class', 'eg'),
#  ('eg', 'lesson'),
#  ('lesson', 'builds'),
#  ('builds', 'dci'),
#  ('dci', 'electromagnetic'),
#  ('electromagnetic', 'radiation'),
#  ('radiation', 'object'),
#  ('object', 'seen'),
#  ('seen', 'light'),
#  ('light', 'reflected'),
#  ('reflected', 'surface'),
#  ('surface', 'enters'),
#  ('enters', 'eyes'),
#  ('eyes', 'dci'),
#  ('dci', 'focused'),
#  ('focused', 'moving'),
#  ('moving', 'students'),
#  ('students', 'toward'),
#  ('toward', 'pol'),
#  ('pol', 'model'),
#  ('model', 'traces'),
#  ('traces', 'path'),
#  ('path', 'light'),
#  ('light', 'source'),
#  ('source', 'object'),
#  ('object', 'reflecting'),
#  ('reflecting', 'object'),
#  ('object', 'eyes'),
#  ('eyes', 'drawn'),
#  ('drawn', 'students'),
#  ('students', 'may'),
#  ('may', 'use'),
#  ('use', 'arrows'),
#  ('arrows', 'point'),
#  ('point', 'away'),
#  ('away', 'source'),
#  ('source', 'point'),
#  ('point', 'away'),
#  ('away', 'objects'),
#  ('objects', 'reflect'),
#  ('reflect', 'light'),
#  ('light', 'point'),
#  ('point', 'toward'),
#  ('toward', 'eyes'),
#  ('eyes', 'contrast'),
#  ('contrast', 'common'),
#  ...]

# %%
equity_text_tokens_trigrams = list(nltk.trigrams(OPSEwords))
equity_text_tokens_trigrams
# Out:
# [('lesson', 'something', 'act'),
#  ('something', 'act', 'like'),
#  ('act', 'like', 'mirror'),
#  ('like', 'mirror', 'window'),
#  ('mirror', 'window', 'time'),
#  ('window', 'time', 'lesson'),
#  ('time', 'lesson', 'anchoring'),
#  ('lesson', 'anchoring', 'phenomenon'),
#  ('anchoring', 'phenomenon', 'days'),
#  ('phenomenon', 'days', 'watch'),
#  ('days', 'watch', 'puzzling'),
#  ('watch', 'puzzling', 'video'),
#  ('puzzling', 'video', 'music'),
#  ('video', 'music', 'student'),
#  ('music', 'student', 'see'),
#  ('student', 'see', 'reflection'),
#  ('see', 'reflection', 'seems'),
#  ('reflection', 'seems', 'mirror'),
#  ('seems', 'mirror', 'student'),
#  ('mirror', 'student', 'see'),
#  ('student', 'see', 'teacher'),
#  ('see', 'teacher', 'side'),
#  ('teacher', 'side', 'mirror'),
#  ('side', 'mirror', 'teacher'),
#  ('mirror', 'teacher', 'see'),
#  ('teacher', 'see', 'student'),
#  ('see', 'student', 'wonder'),
#  ('student', 'wonder', 'something'),
#  ('wonder', 'something', 'act'),
#  ('something', 'act', 'like'),
#  ('act', 'like', 'mirror'),
#  ('like', 'mirror', 'window'),
#  ('mirror', 'window', 'time'),
#  ('window', 'time', 'investigate'),
#  ('time', 'investigate', 'scenario'),
#  ('investigate', 'scenario', 'using'),
#  ('scenario', 'using', 'box'),
#  ('using', 'box', 'model'),
#  ('box', 'model', 'maps'),
#  ('model', 'maps', 'system'),
#  ('maps', 'system', 'video'),
#  ('system', 'video', 'develop'),
#  ('video', 'develop', 'initial'),
#  ('develop', 'initial', 'class'),
#  ('initial', 'class', 'consensus'),
#  ('class', 'consensus', 'model'),
#  ('consensus', 'model', 'explain'),
#  ('model', 'explain', 'oneway'),
#  ('explain', 'oneway', 'mirror'),
#  ('oneway', 'mirror', 'phenomenon'),
#  ('mirror', 'phenomenon', 'identify'),
#  ('phenomenon', 'identify', 'related'),
#  ('identify', 'related', 'phenomena'),
#  ('related', 'phenomena', 'could'),
#  ('phenomena', 'could', 'help'),
#  ('could', 'help', 'us'),
#  ('help', 'us', 'explain'),
#  ('us', 'explain', 'share'),
#  ('explain', 'share', 'questions'),
#  ('share', 'questions', 'oneway'),
#  ('questions', 'oneway', 'mirror'),
#  ('oneway', 'mirror', 'helps'),
#  ('mirror', 'helps', 'us'),
#  ('helps', 'us', 'form'),
#  ('us', 'form', 'driving'),
#  ('form', 'driving', 'question'),
#  ('driving', 'question', 'board'),
#  ('question', 'board', 'brainstorm'),
#  ('board', 'brainstorm', 'investigations'),
#  ('brainstorm', 'investigations', 'data'),
#  ('investigations', 'data', 'need'),
#  ('data', 'need', 'answer'),
#  ('need', 'answer', 'questions'),
#  ('answer', 'questions', 'building'),
#  ('questions', 'building', 'toward'),
#  ('building', 'toward', 'ngss'),
#  ('toward', 'ngss', 'students'),
#  ('ngss', 'students', 'develop'),
#  ('students', 'develop', 'model'),
#  ('develop', 'model', 'identify'),
#  ('model', 'identify', 'important'),
#  ('identify', 'important', 'parts'),
#  ('important', 'parts', 'system'),
#  ('parts', 'system', 'parts'),
#  ('system', 'parts', 'interact'),
#  ('parts', 'interact', 'could'),
#  ('interact', 'could', 'cause'),
#  ('could', 'cause', 'object'),
#  ('cause', 'object', 'look'),
#  ('object', 'look', 'different'),
#  ('look', 'different', 'different'),
#  ('different', 'different', 'light'),
#  ('different', 'light', 'conditions'),
#  ('light', 'conditions', 'ask'),
#  ('conditions', 'ask', 'questions'),
#  ('ask', 'questions', 'arise'),
#  ('questions', 'arise', 'observations'),
#  ('arise', 'observations', 'phenomenon'),
#  ('observations', 'phenomenon', 'object'),
#  ('phenomenon', 'object', 'appears'),
#  ('object', 'appears', 'different'),
#  ('appears', 'different', 'depending'),
#  ('different', 'depending', 'light'),
#  ('depending', 'light', 'conditions'),
#  ('light', 'conditions', 'within'),
#  ('conditions', 'within', 'defined'),
#  ('within', 'defined', 'system'),
#  ('defined', 'system', 'students'),
#  ('system', 'students', 'figure'),
#  ('students', 'figure', 'materials'),
#  ('figure', 'materials', 'reflective'),
#  ('materials', 'reflective', 'seethrough'),
#  ('reflective', 'seethrough', 'time'),
#  ('seethrough', 'time', 'whether'),
#  ('time', 'whether', 'material'),
#  ('whether', 'material', 'reflective'),
#  ('material', 'reflective', 'seethrough'),
#  ('reflective', 'seethrough', 'may'),
#  ('seethrough', 'may', 'related'),
#  ('may', 'related', 'light'),
#  ('related', 'light', 'lesson'),
#  ('light', 'lesson', 'learning'),
#  ('lesson', 'learning', 'plan'),
#  ('learning', 'plan', 'snapshot'),
#  ('plan', 'snapshot', 'part'),
#  ('snapshot', 'part', 'duration'),
#  ('part', 'duration', 'summary'),
#  ('duration', 'summary', 'slide'),
#  ('summary', 'slide', 'materials'),
#  ('slide', 'materials', 'min'),
#  ('materials', 'min', 'introduce'),
#  ('min', 'introduce', 'puzzling'),
#  ('introduce', 'puzzling', 'phenomenon'),
#  ('puzzling', 'phenomenon', 'play'),
#  ('phenomenon', 'play', 'music'),
#  ('play', 'music', 'lesson'),
#  ('music', 'lesson', 'video'),
#  ('lesson', 'video', 'showing'),
#  ('video', 'showing', 'student'),
#  ('showing', 'student', 'see'),
#  ('student', 'see', 'reflection'),
#  ('see', 'reflection', 'oneway'),
#  ('reflection', 'oneway', 'mirror'),
#  ('oneway', 'mirror', 'teacher'),
#  ('mirror', 'teacher', 'side'),
#  ('teacher', 'side', 'see'),
#  ('side', 'see', 'oneway'),
#  ('see', 'oneway', 'mirror'),
#  ('oneway', 'mirror', 'students'),
#  ('mirror', 'students', 'record'),
#  ('students', 'record', 'noticings'),
#  ('record', 'noticings', 'wonderings'),
#  ('noticings', 'wonderings', 'computer'),
#  ('wonderings', 'computer', 'projector'),
#  ('computer', 'projector', 'music'),
#  ('projector', 'music', 'lesson'),
#  ('music', 'lesson', 'video'),
#  ('lesson', 'video', 'min'),
#  ('video', 'min', 'share'),
#  ('min', 'share', 'noticings'),
#  ('share', 'noticings', 'wonderings'),
#  ('noticings', 'wonderings', 'video'),
#  ('wonderings', 'video', 'share'),
#  ('video', 'share', 'noticings'),
#  ('share', 'noticings', 'wonderings'),
#  ('noticings', 'wonderings', 'video'),
#  ('wonderings', 'video', 'partner'),
#  ('video', 'partner', 'lead'),
#  ('partner', 'lead', 'class'),
#  ('lead', 'class', 'discussion'),
#  ('class', 'discussion', 'record'),
#  ('discussion', 'record', 'observations'),
#  ('record', 'observations', 'questions'),
#  ('observations', 'questions', 'class'),
#  ('questions', 'class', 'chart'),
#  ('class', 'chart', 'b'),
#  ('chart', 'b', 'notice'),
#  ('b', 'notice', 'wonder'),
#  ('notice', 'wonder', 'chart'),
#  ('wonder', 'chart', 'prepared'),
#  ('chart', 'prepared', 'advance'),
#  ('prepared', 'advance', 'markers'),
#  ('advance', 'markers', 'min'),
#  ('markers', 'min', 'identify'),
#  ('min', 'identify', 'parts'),
#  ('identify', 'parts', 'interactions'),
#  ('parts', 'interactions', 'diagram'),
#  ('interactions', 'diagram', 'thinking'),
#  ('diagram', 'thinking', 'partner'),
#  ('thinking', 'partner', 'talk'),
#  ('partner', 'talk', 'class'),
#  ('talk', 'class', 'discussion'),
#  ('class', 'discussion', 'coconstruct'),
#  ('discussion', 'coconstruct', 'list'),
#  ('coconstruct', 'list', 'important'),
#  ('list', 'important', 'parts'),
#  ('important', 'parts', 'video'),
#  ('parts', 'video', 'phenomenon'),
#  ('video', 'phenomenon', 'diagram'),
#  ('phenomenon', 'diagram', 'interactions'),
#  ('diagram', 'interactions', 'included'),
#  ('interactions', 'included', 'initial'),
#  ('included', 'initial', 'explanations'),
#  ('initial', 'explanations', 'ce'),
#  ('explanations', 'ce', 'initial'),
#  ('ce', 'initial', 'diagram'),
#  ('initial', 'diagram', 'explain'),
#  ('diagram', 'explain', 'phenomenon'),
#  ('explain', 'phenomenon', 'optional'),
#  ('phenomenon', 'optional', 'parts'),
#  ('optional', 'parts', 'chart'),
#  ('parts', 'chart', 'prepared'),
#  ('chart', 'prepared', 'advance'),
#  ('prepared', 'advance', 'markers'),
#  ('advance', 'markers', 'min'),
#  ('markers', 'min', 'compare'),
#  ('min', 'compare', 'diagrams'),
#  ('compare', 'diagrams', 'partner'),
#  ('diagrams', 'partner', 'arrange'),
#  ('partner', 'arrange', 'students'),
#  ('arrange', 'students', 'partners'),
#  ('students', 'partners', 'share'),
#  ('partners', 'share', 'diagrams'),
#  ('share', 'diagrams', 'note'),
#  ('diagrams', 'note', 'similarities'),
#  ('note', 'similarities', 'differences'),
#  ('similarities', 'differences', 'f'),
#  ('differences', 'f', 'initial'),
#  ('f', 'initial', 'diagram'),
#  ('initial', 'diagram', 'explain'),
#  ('diagram', 'explain', 'phenomenon'),
#  ('explain', 'phenomenon', 'optional'),
#  ('phenomenon', 'optional', 'min'),
#  ('optional', 'min', 'navigation'),
#  ('min', 'navigation', 'brainstorm'),
#  ('navigation', 'brainstorm', 'ideas'),
#  ('brainstorm', 'ideas', 'making'),
#  ('ideas', 'making', 'scale'),
#  ('making', 'scale', 'model'),
#  ('scale', 'model', 'represents'),
#  ('model', 'represents', 'system'),
#  ('represents', 'system', 'video'),
#  ('system', 'video', 'investigate'),
#  ('video', 'investigate', 'phenomenon'),
#  ('investigate', 'phenomenon', 'classroom'),
#  ('phenomenon', 'classroom', 'g'),
#  ('classroom', 'g', 'end'),
#  ('g', 'end', 'day'),
#  ('end', 'day', 'min'),
#  ('day', 'min', 'navigation'),
#  ('min', 'navigation', 'introduce'),
#  ('navigation', 'introduce', 'box'),
#  ('introduce', 'box', 'model'),
#  ('box', 'model', 'elicit'),
#  ('model', 'elicit', 'prior'),
#  ('elicit', 'prior', 'experiences'),
#  ('prior', 'experiences', 'scale'),
#  ('experiences', 'scale', 'models'),
#  ('scale', 'models', 'h'),
#  ('models', 'h', 'box'),
#  ('h', 'box', 'model'),
#  ('box', 'model', 'setup'),
#  ('model', 'setup', 'picture'),
#  ('setup', 'picture', 'mat'),
#  ('picture', 'mat', 'set'),
#  ('mat', 'set', 'oneway'),
#  ('set', 'oneway', 'mirror'),
#  ('oneway', 'mirror', 'film'),
#  ('mirror', 'film', 'flashlight'),
#  ('film', 'flashlight', 'toys'),
#  ('flashlight', 'toys', 'min'),
#  ('toys', 'min', 'map'),
#  ('min', 'map', 'box'),
#  ('map', 'box', 'model'),
#  ('box', 'model', 'video'),
#  ('model', 'video', 'guide'),
#  ('video', 'guide', 'students'),
#  ('guide', 'students', 'mapping'),
#  ('students', 'mapping', 'parts'),
#  ('mapping', 'parts', 'box'),
#  ('parts', 'box', 'model'),
#  ('box', 'model', 'important'),
#  ('model', 'important', 'parts'),
#  ('important', 'parts', 'video'),
#  ('parts', 'video', 'use'),
#  ('video', 'use', 'mapping'),
#  ('use', 'mapping', 'highlight'),
#  ('mapping', 'highlight', 'benefits'),
#  ('highlight', 'benefits', 'limitations'),
#  ('benefits', 'limitations', 'using'),
#  ('limitations', 'using', 'box'),
#  ('using', 'box', 'model'),
#  ('box', 'model', 'mapping'),
#  ('model', 'mapping', 'model'),
#  ('mapping', 'model', 'chart'),
#  ('model', 'chart', 'prepared'),
#  ('chart', 'prepared', 'advance'),
#  ('prepared', 'advance', 'parts'),
#  ('advance', 'parts', 'chart'),
#  ('parts', 'chart', 'prepared'),
#  ('chart', 'prepared', 'advance'),
#  ('prepared', 'advance', 'markers'),
#  ('advance', 'markers', 'min'),
#  ('markers', 'min', 'carry'),
#  ('min', 'carry', 'box'),
#  ('carry', 'box', 'model'),
#  ('box', 'model', 'investigation'),
#  ('model', 'investigation', 'give'),
#  ('investigation', 'give', 'students'),
#  ('give', 'students', 'time'),
#  ('students', 'time', 'explore'),
#  ('time', 'explore', 'box'),
#  ('explore', 'box', 'model'),
#  ('box', 'model', 'add'),
#  ('model', 'add', 'noticings'),
#  ('add', 'noticings', 'wonderings'),
#  ('noticings', 'wonderings', 'chart'),
#  ('wonderings', 'chart', 'j'),
#  ('chart', 'j', 'box'),
#  ('j', 'box', 'model'),
#  ('box', 'model', 'setup'),
#  ('model', 'setup', 'picture'),
#  ('setup', 'picture', 'mat'),
#  ('picture', 'mat', 'set'),
#  ('mat', 'set', 'oneway'),
#  ('set', 'oneway', 'mirror'),
#  ('oneway', 'mirror', 'film'),
#  ('mirror', 'film', 'flashlight'),
#  ('film', 'flashlight', 'toys'),
#  ('flashlight', 'toys', 'min'),
#  ('toys', 'min', 'share'),
#  ('min', 'share', 'observations'),
#  ('share', 'observations', 'box'),
#  ('observations', 'box', 'model'),
#  ('box', 'model', 'investigation'),
#  ('model', 'investigation', 'facilitate'),
#  ('investigation', 'facilitate', 'class'),
#  ('facilitate', 'class', 'discussion'),
#  ('class', 'discussion', 'connect'),
#  ('discussion', 'connect', 'students'),
#  ('connect', 'students', 'noticed'),
#  ('students', 'noticed', 'wondered'),
#  ('noticed', 'wondered', 'box'),
#  ('wondered', 'box', 'model'),
#  ('box', 'model', 'investigation'),
#  ('model', 'investigation', 'saw'),
#  ('investigation', 'saw', 'video'),
#  ('saw', 'video', 'evaluate'),
#  ('video', 'evaluate', 'box'),
#  ('evaluate', 'box', 'model'),
#  ('box', 'model', 'kl'),
#  ('model', 'kl', 'communicating'),
#  ('kl', 'communicating', 'scientific'),
#  ('communicating', 'scientific', 'ways'),
#  ('scientific', 'ways', 'handout'),
#  ('ways', 'handout', 'notice'),
#  ('handout', 'notice', 'wonder'),
#  ('notice', 'wonder', 'chart'),
#  ('wonder', 'chart', 'prepared'),
#  ('chart', 'prepared', 'advance'),
#  ('prepared', 'advance', 'markers'),
#  ('advance', 'markers', 'min'),
#  ('markers', 'min', 'navigation'),
#  ('min', 'navigation', 'ask'),
#  ('navigation', 'ask', 'students'),
#  ('ask', 'students', 'complete'),
#  ('students', 'complete', 'exit'),
#  ('complete', 'exit', 'ticket'),
#  ('exit', 'ticket', 'preparation'),
#  ('ticket', 'preparation', 'consensus'),
#  ('preparation', 'consensus', 'discussion'),
#  ('consensus', 'discussion', 'index'),
#  ('discussion', 'index', 'card'),
#  ('index', 'card', 'end'),
#  ('card', 'end', 'day'),
#  ('end', 'day', 'min'),
#  ('day', 'min', 'form'),
#  ('min', 'form', 'scientists'),
#  ('form', 'scientists', 'circle'),
#  ('scientists', 'circle', 'discuss'),
#  ('circle', 'discuss', 'classroom'),
#  ('discuss', 'classroom', 'norms'),
#  ('classroom', 'norms', 'arrange'),
#  ('norms', 'arrange', 'classroom'),
#  ('arrange', 'classroom', 'students'),
#  ('classroom', 'students', 'scientists'),
#  ('students', 'scientists', 'circle'),
#  ('scientists', 'circle', 'developing'),
#  ('circle', 'developing', 'classroom'),
#  ('developing', 'classroom', 'consensus'),
#  ('classroom', 'consensus', 'model'),
#  ('consensus', 'model', 'develop'),
#  ('model', 'develop', 'explicit'),
#  ('develop', 'explicit', 'shared'),
#  ('explicit', 'shared', 'norms'),
#  ('shared', 'norms', 'learning'),
#  ('norms', 'learning', 'community'),
#  ('learning', 'community', 'n'),
#  ('community', 'n', 'science'),
#  ('n', 'science', 'classroom'),
#  ('science', 'classroom', 'norms'),
#  ('classroom', 'norms', 'min'),
#  ('norms', 'min', 'develop'),
#  ('min', 'develop', 'initial'),
#  ('develop', 'initial', 'class'),
#  ('initial', 'class', 'consensus'),
#  ('class', 'consensus', 'model'),
#  ('consensus', 'model', 'stay'),
#  ('model', 'stay', 'scientists'),
#  ('stay', 'scientists', 'circle'),
#  ('scientists', 'circle', 'students'),
#  ('circle', 'students', 'share'),
#  ('students', 'share', 'diagrams'),
#  ('share', 'diagrams', 'facilitate'),
#  ('diagrams', 'facilitate', 'consensus'),
#  ('facilitate', 'consensus', 'discussion'),
#  ('consensus', 'discussion', 'develop'),
#  ('discussion', 'develop', 'initial'),
#  ('develop', 'initial', 'class'),
#  ('initial', 'class', 'consensus'),
#  ('class', 'consensus', 'model'),
#  ('consensus', 'model', 'oq'),
#  ('model', 'oq', 'initial'),
#  ('oq', 'initial', 'class'),
#  ('initial', 'class', 'consensus'),
#  ('class', 'consensus', 'model'),
#  ('consensus', 'model', 'prepared'),
#  ('model', 'prepared', 'advance'),
#  ('prepared', 'advance', 'markers'),
#  ('advance', 'markers', 'min'),
#  ('markers', 'min', 'brainstorm'),
#  ('min', 'brainstorm', 'related'),
#  ('brainstorm', 'related', 'phenomena'),
#  ('related', 'phenomena', 'assign'),
#  ('phenomena', 'assign', 'selfdocumentation'),
#  ('assign', 'selfdocumentation', 'generate'),
#  ('selfdocumentation', 'generate', 'class'),
#  ('generate', 'class', 'list'),
#  ('class', 'list', 'possible'),
#  ('list', 'possible', 'related'),
#  ('possible', 'related', 'phenomena'),
#  ('related', 'phenomena', 'experiences'),
#  ('phenomena', 'experiences', 'assign'),
#  ('experiences', 'assign', 'home'),
#  ('assign', 'home', 'learning'),
#  ('home', 'learning', 'students'),
#  ('learning', 'students', 'document'),
#  ('students', 'document', 'related'),
#  ('document', 'related', 'phenomena'),
#  ('related', 'phenomena', 'lives'),
#  ('phenomena', 'lives', 'next'),
#  ('lives', 'next', 'days'),
#  ('next', 'days', 'rs'),
#  ('days', 'rs', 'related'),
#  ('rs', 'related', 'phenomena'),
#  ('related', 'phenomena', 'list'),
#  ('phenomena', 'list', 'prepared'),
#  ('list', 'prepared', 'advance'),
#  ('prepared', 'advance', 'markers'),
#  ('advance', 'markers', 'end'),
#  ('markers', 'end', 'day'),
#  ('end', 'day', 'min'),
#  ('day', 'min', 'write'),
#  ('min', 'write', 'questions'),
#  ('write', 'questions', 'driving'),
#  ('questions', 'driving', 'question'),
#  ('driving', 'question', 'board'),
#  ('question', 'board', 'students'),
#  ('board', 'students', 'individually'),
#  ('students', 'individually', 'generate'),
#  ('individually', 'generate', 'questions'),
#  ('generate', 'questions', 'phenomenon'),
#  ('questions', 'phenomenon', 'preparation'),
#  ('phenomenon', 'preparation', 'building'),
#  ('preparation', 'building', 'dqb'),
#  ('building', 'dqb', 'tu'),
#  ('dqb', 'tu', 'sticky'),
#  ('tu', 'sticky', 'notes'),
#  ('sticky', 'notes', 'marker'),
#  ('notes', 'marker', 'min'),
#  ('marker', 'min', 'develop'),
#  ('min', 'develop', 'driving'),
#  ('develop', 'driving', 'question'),
#  ('driving', 'question', 'board'),
#  ('question', 'board', 'share'),
#  ('board', 'share', 'questions'),
#  ('share', 'questions', 'build'),
#  ('questions', 'build', 'dqb'),
#  ('build', 'dqb', 'causing'),
#  ('dqb', 'causing', 'phenomenon'),
#  ('causing', 'phenomenon', 'observed'),
#  ('phenomenon', 'observed', 'lesson'),
#  ('observed', 'lesson', 'vw'),
#  ('lesson', 'vw', 'driving'),
#  ('vw', 'driving', 'question'),
#  ('driving', 'question', 'board'),
#  ('question', 'board', 'overlaid'),
#  ('board', 'overlaid', 'initial'),
#  ('overlaid', 'initial', 'class'),
#  ('initial', 'class', 'consensus'),
#  ('class', 'consensus', 'model'),
#  ('consensus', 'model', 'min'),
#  ('model', 'min', 'develop'),
#  ('min', 'develop', 'ideas'),
#  ('develop', 'ideas', 'future'),
#  ('ideas', 'future', 'investigation'),
#  ('future', 'investigation', 'students'),
#  ('investigation', 'students', 'use'),
#  ('students', 'use', 'dqb'),
#  ('use', 'dqb', 'develop'),
#  ('dqb', 'develop', 'list'),
#  ('develop', 'list', 'investigations'),
#  ('list', 'investigations', 'could'),
#  ('investigations', 'could', 'conduct'),
#  ('could', 'conduct', 'answer'),
#  ('conduct', 'answer', 'questions'),
#  ('answer', 'questions', 'explain'),
#  ('questions', 'explain', 'oneway'),
#  ('explain', 'oneway', 'mirror'),
#  ('oneway', 'mirror', 'phenomenon'),
#  ('mirror', 'phenomenon', 'x'),
#  ('phenomenon', 'x', 'ideas'),
#  ('x', 'ideas', 'investigations'),
#  ('ideas', 'investigations', 'chart'),
#  ('investigations', 'chart', 'prepared'),
#  ('chart', 'prepared', 'advance'),
#  ('prepared', 'advance', 'markers'),
#  ('advance', 'markers', 'min'),
#  ('markers', 'min', 'decide'),
#  ('min', 'decide', 'go'),
#  ('decide', 'go', 'next'),
#  ('go', 'next', 'students'),
#  ('next', 'students', 'predict'),
#  ('students', 'predict', 'would'),
#  ('predict', 'would', 'happen'),
#  ('would', 'happen', 'switch'),
#  ('happen', 'switch', 'light'),
#  ('switch', 'light', 'room'),
#  ('light', 'room', 'box'),
#  ('room', 'box', 'model'),
#  ('box', 'model', 'yz'),
#  ('model', 'yz', 'end'),
#  ('yz', 'end', 'day'),
#  ('end', 'day', 'lesson'),
#  ('day', 'lesson', 'materials'),
#  ('lesson', 'materials', 'list'),
#  ('materials', 'list', 'per'),
#  ('list', 'per', 'student'),
#  ('per', 'student', 'per'),
#  ('student', 'per', 'group'),
#  ('per', 'group', 'per'),
#  ('group', 'per', 'class'),
#  ('per', 'class', 'lesson'),
#  ('class', 'lesson', 'materials'),
#  ('lesson', 'materials', 'science'),
#  ('materials', 'science', 'notebook'),
#  ('science', 'notebook', 'initial'),
#  ('notebook', 'initial', 'diagram'),
#  ('initial', 'diagram', 'explain'),
#  ('diagram', 'explain', 'phenomenon'),
#  ('explain', 'phenomenon', 'optional'),
#  ('phenomenon', 'optional', 'communicating'),
#  ('optional', 'communicating', 'scientific'),
#  ('communicating', 'scientific', 'ways'),
#  ('scientific', 'ways', 'handout'),
#  ('ways', 'handout', 'index'),
#  ('handout', 'index', 'card'),
#  ('index', 'card', 'science'),
#  ('card', 'science', 'classroom'),
#  ('science', 'classroom', 'norms'),
#  ('classroom', 'norms', 'sticky'),
#  ('norms', 'sticky', 'notes'),
#  ('sticky', 'notes', 'marker'),
#  ('notes', 'marker', 'box'),
#  ('marker', 'box', 'model'),
#  ('box', 'model', 'setup'),
#  ('model', 'setup', 'picture'),
#  ('setup', 'picture', 'mat'),
#  ('picture', 'mat', 'set'),
#  ('mat', 'set', 'oneway'),
#  ('set', 'oneway', 'mirror'),
#  ('oneway', 'mirror', 'film'),
#  ('mirror', 'film', 'flashlight'),
#  ('film', 'flashlight', 'toys'),
#  ('flashlight', 'toys', 'computer'),
#  ('toys', 'computer', 'projector'),
#  ('computer', 'projector', 'music'),
#  ('projector', 'music', 'lesson'),
#  ('music', 'lesson', 'video'),
#  ('lesson', 'video', 'notice'),
#  ('video', 'notice', 'wonder'),
#  ('notice', 'wonder', 'chart'),
#  ('wonder', 'chart', 'prepared'),
#  ('chart', 'prepared', 'advance'),
#  ('prepared', 'advance', 'markers'),
#  ('advance', 'markers', 'parts'),
#  ('markers', 'parts', 'chart'),
#  ('parts', 'chart', 'prepared'),
#  ('chart', 'prepared', 'advance'),
#  ('prepared', 'advance', 'mapping'),
#  ('advance', 'mapping', 'model'),
#  ('mapping', 'model', 'chart'),
#  ('model', 'chart', 'prepared'),
#  ('chart', 'prepared', 'advance'),
#  ('prepared', 'advance', 'initial'),
#  ('advance', 'initial', 'class'),
#  ('initial', 'class', 'consensus'),
#  ('class', 'consensus', 'model'),
#  ('consensus', 'model', 'prepared'),
#  ('model', 'prepared', 'advance'),
#  ('prepared', 'advance', 'related'),
#  ('advance', 'related', 'phenomena'),
#  ('related', 'phenomena', 'list'),
#  ('phenomena', 'list', 'prepared'),
#  ('list', 'prepared', 'advance'),
#  ('prepared', 'advance', 'driving'),
#  ('advance', 'driving', 'question'),
#  ('driving', 'question', 'board'),
#  ('question', 'board', 'overlaid'),
#  ('board', 'overlaid', 'initial'),
#  ('overlaid', 'initial', 'class'),
#  ('initial', 'class', 'consensus'),
#  ('class', 'consensus', 'model'),
#  ('consensus', 'model', 'ideas'),
#  ('model', 'ideas', 'investigations'),
#  ('ideas', 'investigations', 'chart'),
#  ('investigations', 'chart', 'prepared'),
#  ('chart', 'prepared', 'advance'),
#  ('prepared', 'advance', 'materials'),
#  ('advance', 'materials', 'preparation'),
#  ('materials', 'preparation', 'minutes'),
#  ('preparation', 'minutes', 'review'),
#  ('minutes', 'review', 'teacher'),
#  ('review', 'teacher', 'guide'),
#  ('teacher', 'guide', 'slides'),
#  ('guide', 'slides', 'teacher'),
#  ('slides', 'teacher', 'references'),
#  ('teacher', 'references', 'keys'),
#  ('references', 'keys', 'applicable'),
#  ('keys', 'applicable', 'make'),
#  ('applicable', 'make', 'copies'),
#  ('make', 'copies', 'handouts'),
#  ('copies', 'handouts', 'ensure'),
#  ('handouts', 'ensure', 'sufficient'),
#  ('ensure', 'sufficient', 'copies'),
#  ('sufficient', 'copies', 'student'),
#  ('copies', 'student', 'references'),
#  ('student', 'references', 'readings'),
#  ('references', 'readings', 'procedures'),
#  ('readings', 'procedures', 'available'),
#  ('procedures', 'available', 'check'),
#  ('available', 'check', 'music'),
#  ('check', 'music', 'lesson'),
#  ('music', 'lesson', 'video'),
#  ('lesson', 'video', 'clip'),
#  ('video', 'clip', 'https'),
#  ('clip', 'https', 'ensure'),
#  ('https', 'ensure', 'plays'),
#  ('ensure', 'plays', 'device'),
#  ('plays', 'device', 'viewed'),
#  ('device', 'viewed', 'whole'),
#  ('viewed', 'whole', 'class'),
#  ('whole', 'class', 'use'),
#  ('class', 'use', 'box'),
#  ('use', 'box', 'model'),
#  ('box', 'model', 'assembly'),
#  ('model', 'assembly', 'instructions'),
#  ('assembly', 'instructions', 'build'),
#  ('instructions', 'build', 'box'),
#  ('build', 'box', 'models'),
#  ('box', 'models', 'larger'),
#  ('models', 'larger', 'class'),
#  ('larger', 'class', 'may'),
#  ('class', 'may', 'want'),
#  ('may', 'want', 'build'),
#  ('want', 'build', 'ensure'),
#  ('build', 'ensure', 'smaller'),
#  ('ensure', 'smaller', 'group'),
#  ('smaller', 'group', 'sizes'),
#  ('group', 'sizes', 'box'),
#  ('sizes', 'box', 'model'),
#  ('box', 'model', 'takes'),
#  ('model', 'takes', 'approximately'),
#  ('takes', 'approximately', 'minutes'),
#  ('approximately', 'minutes', 'assemble'),
#  ('minutes', 'assemble', 'though'),
#  ('assemble', 'though', 'first'),
#  ('though', 'first', 'one'),
#  ('first', 'one', 'may'),
#  ('one', 'may', 'take'),
#  ('may', 'take', 'longer'),
#  ('take', 'longer', 'learn'),
#  ('longer', 'learn', 'procedures'),
#  ('learn', 'procedures', 'built'),
#  ('procedures', 'built', 'models'),
#  ('built', 'models', 'used'),
#  ('models', 'used', 'future'),
#  ('used', 'future', 'edit'),
#  ('future', 'edit', 'science'),
#  ('edit', 'science', 'classroom'),
#  ('science', 'classroom', 'norms'),
#  ('classroom', 'norms', 'slide'),
#  ('norms', 'slide', 'n'),
#  ('slide', 'n', 'necessary'),
#  ('n', 'necessary', 'include'),
#  ('necessary', 'include', 'norms'),
#  ('include', 'norms', 'want'),
#  ('norms', 'want', 'adopt'),
#  ('want', 'adopt', 'classroom'),
#  ('adopt', 'classroom', 'also'),
#  ('classroom', 'also', 'introduce'),
#  ('also', 'introduce', 'communicating'),
#  ('introduce', 'communicating', 'scientific'),
#  ('communicating', 'scientific', 'ways'),
#  ('scientific', 'ways', 'sentence'),
#  ('ways', 'sentence', 'starters'),
#  ('sentence', 'starters', 'provide'),
#  ('starters', 'provide', 'handout'),
#  ('provide', 'handout', 'students'),
#  ('handout', 'students', 'tape'),
#  ('students', 'tape', 'science'),
#  ('tape', 'science', 'notebook'),
#  ('science', 'notebook', 'post'),
#  ('notebook', 'post', 'classroom'),
#  ('post', 'classroom', 'reference'),
#  ('classroom', 'reference', 'chart'),
#  ('reference', 'chart', 'prepare'),
#  ('chart', 'prepare', 'following'),
#  ('prepare', 'following', 'spaces'),
#  ('following', 'spaces', 'charts'),
#  ('spaces', 'charts', 'used'),
#  ('charts', 'used', 'throughout'),
#  ('used', 'throughout', 'unit'),
#  ('throughout', 'unit', 'day'),
#  ('unit', 'day', 'notice'),
#  ('day', 'notice', 'wonder'),
#  ('notice', 'wonder', 'chart'),
#  ('wonder', 'chart', 'parts'),
#  ('chart', 'parts', 'chart'),
#  ('parts', 'chart', 'day'),
#  ('chart', 'day', 'mapping'),
#  ('day', 'mapping', 'model'),
#  ('mapping', 'model', 'chart'),
#  ('model', 'chart', 'chart'),
#  ('chart', 'chart', 'paper'),
#  ('chart', 'paper', 'whiteboard'),
#  ('paper', 'whiteboard', 'project'),
#  ('whiteboard', 'project', 'slide'),
#  ('project', 'slide', 'whiteboard'),
#  ('slide', 'whiteboard', 'day'),
#  ('whiteboard', 'day', 'initial'),
#  ('day', 'initial', 'class'),
#  ('initial', 'class', 'consensus'),
#  ('class', 'consensus', 'model'),
#  ('consensus', 'model', 'chart'),
#  ('model', 'chart', 'paper'),
#  ('chart', 'paper', 'related'),
#  ('paper', 'related', 'phenomena'),
#  ('related', 'phenomena', 'list'),
#  ('phenomena', 'list', 'day'),
#  ('list', 'day', 'ideas'),
#  ('day', 'ideas', 'investigations'),
#  ('ideas', 'investigations', 'chart'),
#  ('investigations', 'chart', 'also'),
#  ('chart', 'also', 'prior'),
#  ('also', 'prior', 'day'),
#  ('prior', 'day', 'determine'),
#  ('day', 'determine', 'set'),
#  ('determine', 'set', 'dqb'),
#  ('set', 'dqb', 'students'),
#  ('dqb', 'students', 'gather'),
#  ('students', 'gather', 'around'),
#  ('gather', 'around', 'use'),
#  ('around', 'use', 'initial'),
#  ('use', 'initial', 'class'),
#  ('initial', 'class', 'consensus'),
#  ('class', 'consensus', 'model'),
#  ('consensus', 'model', 'backdrop'),
#  ('model', 'backdrop', 'dqb'),
#  ('backdrop', 'dqb', 'day'),
#  ('dqb', 'day', 'box'),
#  ('day', 'box', 'model'),
#  ('box', 'model', 'investigation'),
#  ('model', 'investigation', 'group'),
#  ('investigation', 'group', 'size'),
#  ('group', 'size', 'depend'),
#  ('size', 'depend', 'class'),
#  ('depend', 'class', 'size'),
#  ('class', 'size', 'number'),
#  ('size', 'number', 'models'),
#  ('number', 'models', 'build'),
#  ('models', 'build', 'setup'),
#  ('build', 'setup', 'see'),
#  ('setup', 'see', 'box'),
#  ('see', 'box', 'model'),
#  ('box', 'model', 'assembly'),
#  ('model', 'assembly', 'instructions'),
#  ('assembly', 'instructions', 'building'),
#  ('instructions', 'building', 'instructions'),
#  ('building', 'instructions', 'models'),
#  ('instructions', 'models', 'assembled'),
#  ('models', 'assembled', 'store'),
#  ('assembled', 'store', 'location'),
#  ('store', 'location', 'students'),
#  ('location', 'students', 'see'),
#  ('students', 'see', 'day'),
#  ('see', 'day', 'ready'),
#  ('day', 'ready', 'students'),
#  ('ready', 'students', 'work'),
#  ('students', 'work', 'models'),
#  ('work', 'models', 'arrange'),
#  ('models', 'arrange', 'around'),
#  ('arrange', 'around', 'classroom'),
#  ('around', 'classroom', 'facilitate'),
#  ('classroom', 'facilitate', 'smallgroup'),
#  ('facilitate', 'smallgroup', 'work'),
#  ('smallgroup', 'work', 'box'),
#  ('work', 'box', 'model'),
#  ('box', 'model', 'setup'),
#  ('model', 'setup', 'completely'),
#  ('setup', 'completely', 'assembled'),
#  ('completely', 'assembled', 'investigation'),
#  ('assembled', 'investigation', 'oneway'),
#  ('investigation', 'oneway', 'mirror'),
#  ('oneway', 'mirror', 'film'),
#  ('mirror', 'film', 'already'),
#  ('film', 'already', 'inserted'),
#  ('already', 'inserted', 'box'),
#  ('inserted', 'box', 'check'),
#  ('box', 'check', 'batteries'),
#  ('check', 'batteries', 'flashlights'),
#  ('batteries', 'flashlights', 'replace'),
#  ('flashlights', 'replace', 'needed'),
#  ('replace', 'needed', 'notes'),
#  ('needed', 'notes', 'lab'),
#  ('notes', 'lab', 'viewing'),
#  ('lab', 'viewing', 'holes'),
#  ('viewing', 'holes', 'may'),
#  ('holes', 'may', 'allow'),
#  ('may', 'allow', 'light'),
#  ('allow', 'light', 'box'),
#  ('light', 'box', 'diminish'),
#  ('box', 'diminish', 'desired'),
#  ('diminish', 'desired', 'effect'),
#  ('desired', 'effect', 'dim'),
#  ('effect', 'dim', 'classroom'),
#  ('dim', 'classroom', 'lights'),
#  ('classroom', 'lights', 'minimize'),
#  ('lights', 'minimize', 'problem'),
#  ('minimize', 'problem', 'storage'),
#  ('problem', 'storage', 'box'),
#  ('storage', 'box', 'models'),
#  ('box', 'models', 'used'),
#  ('models', 'used', 'lesson'),
#  ('used', 'lesson', 'lesson'),
#  ('lesson', 'lesson', 'going'),
#  ('lesson', 'going', 'going'),
#  ('going', 'going', 'going'),
#  ('going', 'going', 'first'),
#  ('going', 'first', 'lesson'),
#  ('first', 'lesson', 'elicits'),
#  ('lesson', 'elicits', 'initial'),
#  ('elicits', 'initial', 'ideas'),
#  ('initial', 'ideas', 'causes'),
#  ('ideas', 'causes', 'us'),
#  ('causes', 'us', 'see'),
#  ('us', 'see', 'different'),
#  ('see', 'different', 'things'),
#  ('different', 'things', 'material'),
#  ('things', 'material', 'lesson'),
#  ('material', 'lesson', 'sequenced'),
#  ('lesson', 'sequenced', 'elicit'),
#  ('sequenced', 'elicit', 'initial'),
#  ('elicit', 'initial', 'ideas'),
#  ('initial', 'ideas', 'conditions'),
#  ('ideas', 'conditions', 'sight'),
#  ('conditions', 'sight', 'ie'),
#  ('sight', 'ie', 'need'),
#  ('ie', 'need', 'order'),
#  ('need', 'order', 'see'),
#  ('order', 'see', 'different'),
#  ('see', 'different', 'ways'),
#  ('different', 'ways', 'light'),
#  ('ways', 'light', 'interacts'),
#  ('light', 'interacts', 'materials'),
#  ('interacts', 'materials', 'many'),
#  ('materials', 'many', 'students'),
#  ('many', 'students', 'curious'),
#  ('students', 'curious', 'material'),
#  ('curious', 'material', 'act'),
#  ('material', 'act', 'mirror'),
#  ('act', 'mirror', 'window'),
#  ('mirror', 'window', 'time'),
#  ('window', 'time', 'deepen'),
#  ('time', 'deepen', 'understanding'),
#  ('deepen', 'understanding', 'anchoring'),
#  ('understanding', 'anchoring', 'phenomenon'),
#  ('anchoring', 'phenomenon', 'using'),
#  ('phenomenon', 'using', 'scale'),
#  ('using', 'scale', 'model'),
#  ('scale', 'model', 'help'),
#  ('model', 'help', 'explain'),
#  ('help', 'explain', 'happening'),
#  ('explain', 'happening', 'real'),
#  ('happening', 'real', 'world'),
#  ('real', 'world', 'curiosities'),
#  ('world', 'curiosities', 'seed'),
#  ('curiosities', 'seed', 'initial'),
#  ('seed', 'initial', 'questions'),
#  ('initial', 'questions', 'future'),
#  ('questions', 'future', 'investigations'),
#  ('future', 'investigations', 'positioning'),
#  ('investigations', 'positioning', 'light'),
#  ('positioning', 'light', 'two'),
#  ('light', 'two', 'rooms'),
#  ('two', 'rooms', 'interactions'),
#  ('rooms', 'interactions', 'oneway'),
#  ('interactions', 'oneway', 'mirror'),
#  ('oneway', 'mirror', 'compared'),
#  ('mirror', 'compared', 'regular'),
#  ('compared', 'regular', 'mirror'),
#  ('regular', 'mirror', 'regular'),
#  ('mirror', 'regular', 'piece'),
#  ('regular', 'piece', 'glass'),
#  ('piece', 'glass', 'structure'),
#  ('glass', 'structure', 'oneway'),
#  ('structure', 'oneway', 'mirror'),
#  ('oneway', 'mirror', 'compared'),
#  ('mirror', 'compared', 'regular'),
#  ('compared', 'regular', 'mirror'),
#  ('regular', 'mirror', 'piece'),
#  ('mirror', 'piece', 'glass'),
#  ('piece', 'glass', 'students'),
#  ('glass', 'students', 'also'),
#  ('students', 'also', 'delve'),
#  ('also', 'delve', 'see'),
#  ('delve', 'see', 'objects'),
#  ('see', 'objects', 'eye'),
#  ('objects', 'eye', 'processes'),
#  ('eye', 'processes', 'light'),
#  ('processes', 'light', 'inputs'),
#  ('light', 'inputs', 'different'),
#  ('inputs', 'different', 'intensities'),
#  ('different', 'intensities', 'brightness'),
#  ('intensities', 'brightness', 'day'),
#  ('brightness', 'day', 'refers'),
#  ('day', 'refers', 'material'),
#  ('refers', 'material', 'starting'),
#  ('material', 'starting', 'day'),
#  ('starting', 'day', 'refer'),
#  ('day', 'refer', 'name'),
#  ('refer', 'name', 'adopted'),
#  ('name', 'adopted', 'class'),
#  ('adopted', 'class', 'eg'),
#  ('class', 'eg', 'lesson'),
#  ('eg', 'lesson', 'builds'),
#  ('lesson', 'builds', 'dci'),
#  ('builds', 'dci', 'electromagnetic'),
#  ('dci', 'electromagnetic', 'radiation'),
#  ('electromagnetic', 'radiation', 'object'),
#  ('radiation', 'object', 'seen'),
#  ('object', 'seen', 'light'),
#  ('seen', 'light', 'reflected'),
#  ('light', 'reflected', 'surface'),
#  ('reflected', 'surface', 'enters'),
#  ('surface', 'enters', 'eyes'),
#  ('enters', 'eyes', 'dci'),
#  ('eyes', 'dci', 'focused'),
#  ('dci', 'focused', 'moving'),
#  ('focused', 'moving', 'students'),
#  ('moving', 'students', 'toward'),
#  ('students', 'toward', 'pol'),
#  ('toward', 'pol', 'model'),
#  ('pol', 'model', 'traces'),
#  ('model', 'traces', 'path'),
#  ('traces', 'path', 'light'),
#  ('path', 'light', 'source'),
#  ('light', 'source', 'object'),
#  ('source', 'object', 'reflecting'),
#  ('object', 'reflecting', 'object'),
#  ('reflecting', 'object', 'eyes'),
#  ('object', 'eyes', 'drawn'),
#  ('eyes', 'drawn', 'students'),
#  ('drawn', 'students', 'may'),
#  ('students', 'may', 'use'),
#  ('may', 'use', 'arrows'),
#  ('use', 'arrows', 'point'),
#  ('arrows', 'point', 'away'),
#  ('point', 'away', 'source'),
#  ('away', 'source', 'point'),
#  ('source', 'point', 'away'),
#  ('point', 'away', 'objects'),
#  ('away', 'objects', 'reflect'),
#  ('objects', 'reflect', 'light'),
#  ('reflect', 'light', 'point'),
#  ('light', 'point', 'toward'),
#  ('point', 'toward', 'eyes'),
#  ('toward', 'eyes', 'contrast'),
#  ('eyes', 'contrast', 'common'),
#  ('contrast', 'common', 'students'),
#  ...]

# %%
finder = nltk.collocations.BigramCollocationFinder.from_words(OPSEwords)
finder.ngram_fd.tabulate(25)
# Out:
#         ('chart', 'paper')   ('related', 'phenomena')     ('consensus', 'model')    ('driving', 'question')      ('question', 'board')      ('students', 'share')        ('sticky', 'notes')    ('attending', 'equity')       ('initial', 'model')       ('display', 'slide')    ('science', 'notebook')     ('develop', 'initial')       ('min', 'materials')        ('ask', 'students')             ('end', 'day')          ('mt', 'everest') ('supporting', 'students')      ('initial', 'models')       ('paper', 'markers')            ('oil', 'palm')   ('scientists', 'circle')             ('help', 'us')       ('give', 'students')     ('remind', 'students')   ('materials', 'science')
#                        201                        199                        176                        175                        158                        148                        145                        139                        138                        130                        128                        121                        121                        112                        106                        106                         96                         95                         95                         87                         84                         83                         81                         75                         73

# %% [markdown]
# The following code will allow you to write the contents of a variable to a text file instead of just to memory.

# %%
OPSE_tokens.similar("share")
# Out:
# develop use record look bring brainstorm write make consider initial
# identify ask may generate work create questions add dqb begin

# %%
OPSE_tokens.common_contexts(["students", "ask"])
# Out:
# questions_written slide_students group_students

# %% [markdown]
# #5.0 Sentiment Analysis
# 1. Movie transcript database

# %% [markdown]
# # 6.0 Further Usage

# %% [markdown]
# TESTING

# %%
# load data
filename = '/content/drive/MyDrive/pdfs/OPSEMERGEDCleanv3.txt'
file = open(filename, 'rt', encoding='utf-8', errors='replace')


#file = open(filename, 'rt', encoding='utf-8', errors='ignore')
#file = open(filename, 'rt', encoding='latin-1')
#file = open(filename, 'rt')
text = file.read()
file.close()
# split into words
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
# convert to lower case
tokens = [w.lower() for w in tokens]
# remove punctuation from each word
import string
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]
# remove remaining tokens that are not alphabetic
words = [word for word in stripped if word.isalpha()]
# filter out stop words
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]
print(words[:100])
# Out:
# ['lesson', 'something', 'act', 'like', 'mirror', 'window', 'time', 'lesson', 'anchoring', 'phenomenon', 'days', 'watch', 'puzzling', 'video', 'music', 'student', 'see', 'reflection', 'seems', 'mirror', 'student', 'see', 'teacher', 'side', 'mirror', 'teacher', 'see', 'student', 'wonder', 'something', 'act', 'like', 'mirror', 'window', 'time', 'investigate', 'scenario', 'using', 'box', 'model', 'maps', 'system', 'video', 'develop', 'initial', 'class', 'consensus', 'model', 'explain', 'oneway', 'mirror', 'phenomenon', 'identify', 'related', 'phenomena', 'could', 'help', 'us', 'explain', 'share', 'questions', 'oneway', 'mirror', 'helps', 'us', 'form', 'driving', 'question', 'board', 'brainstorm', 'investigations', 'data', 'need', 'answer', 'questions', 'building', 'toward', 'ngss', 'students', 'develop', 'model', 'identify', 'important', 'parts', 'system', 'parts', 'interact', 'could', 'cause', 'object', 'look', 'different', 'different', 'light', 'conditions', 'ask', 'questions', 'arise', 'observations', 'phenomenon']

# %% [markdown]
# len(words)

# %%
len(words)
# Out:
# 72769

# %%
sorted(set(words))

# %%
nltk.draw.dispersion.dispersion_plot(OPSEwords, words, ignore_case=False, title='Lexical Dispersion Plot')
# Out:
# <Axes: title={'center': 'Lexical Dispersion Plot'}, xlabel='Word Offset'>

# %%
fig = plt.figure(figsize = (10,4))
plt.gcf().subplots_adjust(bottom=0.15) # to avoid x-ticks cut-off
#OPSE_tokens.dispersion_plot(["students","teacher", "diverse", "diversity", "teacher", "student"])
#OPSE_tokens.plot(10)
nltk.draw.dispersion.dispersion_plot(OPSEwords, words, ignore_case=False, title='Lexical Dispersion Plot')
#nltk.draw.dispersion_plot(OPSEwords, words, ignore_case=False, title='Lexical Dispersion Plot')
plt.show()
fig.savefig('freqDist7.png', bbox_inches = "tight")

# %%
plt.ion()
OPSE_tokens.plot(10)
plt.savefig('img_common.png')
plt.ioff()
plt.show()

# %%
import nltk
from nltk import word_tokenize
import matplotlib.pyplot as plt


text1 = OPSE_tokens

fig = plt.figure()
dplot = text1.dispersion_plot(["students"])
# save the figure
fig.savefig('dispersion_plot1.png')

# %% [markdown]
# # Testing out a Corpus TIMIT Acoustic-Phonetic Continuous Speech Corpus

# %%
import nltk
nltk.download('timit')
files = nltk.corpus.timit.fileids()
#from nltk.corpus import timit
#timit.sents()
#files = timit.fileids()
files

# %% [markdown]
# # Working with Different File Types
# 1. CSV files
# 2. PDF files
# 3. TXT files

# %% [markdown]
# # Text files

# %%
# load data
filename = '/content/OPSEMERGED.txt'
textfile = open(filename, 'rt', encoding='utf-8', errors='replace')

text = textfile.read()
textfile.close()
text

# %% [markdown]
# # Importing csv files

# %%
import csv
input_file = open("lexicon.csv", "rb") [1]
for row in csv.reader(input_file): [2]
print(row)
['sleep', 'sli:p', 'v.i', 'a condition of body and mind ...']
['walk', 'wo:k', 'v.intr', 'progress by lifting and setting down each foot ...']
['wake', 'weik', 'intrans', 'cease to sleep']

# %% [markdown]
# # Importing file from github repo

# %%
# Import requests module
import requests

# Specify the URL of the github repo
url = "https://github.com/audeering/opensmile"

# Append "/archive/refs/heads/main.zip" to the URL
link = url + "/archive/refs/heads/master.zip"

# Send a GET request to the link and get the response
response = requests.get(link, stream=True)

# Check if the response status code is 200
if response.status_code == 200:
    # Open a file in binary mode and write the content of the response
    with open("opensmile.zip", "wb") as f:
        # Write the file in chunks using iter_content()
        for chunk in response.iter_content(chunk_size=1024):
            f.write(chunk)
    # Close the file
    f.close()
    # Unzip the file using any tool of your choice
else:
    # Raise an exception or handle the error
    raise Exception("Request failed with status code {}".format(response.status_code))
